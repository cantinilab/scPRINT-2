# %% [markdown]
# <!-- scprint2-nb-header:begin -->
# # Gene regulatory network inference with scPRINT-2
#
# End-to-end GRN inference: load reference networks (human interactome, CellMap), run scPRINT-2 on a dataset, benchmark against multiple ground truths with BenGRN, and plot the scores.
#
# ## Contents
#
# - [(OPTIONAL) Loading the human interactome gene network](#optional-loading-the-human-interactome-gene-network)
# - [(OPTIONAL) loading the cellmap gene network](#optional-loading-the-cellmap-gene-network)
# - [(OPTIONAL) comparison of ground truth gene networks](#optional-comparison-of-ground-truth-gene-networks)
#   - [Use scPRINT-2 to generate a gene network](#use-scprint-2-to-generate-a-gene-network)
# - [run on multiple cell types in a dataset and test using our ground truths](#run-on-multiple-cell-types-in-a-dataset-and-test-using-our-ground-truths)
#   - [gathering multiple scores](#gathering-multiple-scores)
# - [Plot of the scores](#plot-of-the-scores)
#
# > _Run `notebooks/prepare_scprint2.ipynb` once before any other example notebook._
#
# <!-- scprint2-nb-header:end -->

# %%
import pandas as pd

from bengrn import get_GT_db, get_perturb_gt, get_sroy_gt, BenGRN, FILEDIR

from grnndata import read_h5ad
import numpy as np
import tqdm
import os

#! lamin init --storage ./lamin-intro --schema bionty

import scanpy as sc

from scprint2 import scPRINT2
from scprint2.tasks import GNInfer
from scdataloader import Preprocessor

from bengrn import BenGRN
import scanpy as sc
from anndata.utils import make_index_unique

from bengrn.base import train_classifier
from bengrn import compute_genie3
from grnndata import utils as grnutils
import scipy.sparse

from scdataloader.utils import load_genes
import anndata as ad
import bionty as bt
from grnndata import from_adata_and_longform

import torch

torch.set_float32_matmul_precision("medium")

# %load_ext autoreload
# %autoreload 2

LOC = "/pasteur/appa/scratch/jkalfon/data/spcrint_data"  #
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
# ----> 3 from bengrn import get_GT_db, get_perturb_gt, get_sroy_gt, BenGRN, FILEDIR
#       5 from grnndata import read_h5ad
#       6 import numpy as np
#
# File ~/benGRN/bengrn/__init__.py:5
#       1 from importlib.metadata import version
#       3 __version__ = version("benGRN")
# ----> 5 from .base import *
#
# File ~/benGRN/bengrn/base.py:21
#      19 import numpy as np
#      20 import pandas as pd
# ---> 21 import scanpy as sc
#      22 import scipy.stats
#      23 import tqdm
#
# File ~/scPRINT/.venv/lib/python3.11/site-packages/scanpy/__init__.py:22
#      17     except ModuleNotFoundError:
#      18         raise RuntimeError(
#      19             "scanpy is not correctly installed. Please install it, e.g. with pip."
#      20         )
# ---> 22 from ._utils import check_versions
#      24 check_versions()
#      25 del check_versions
#
# File ~/scPRINT/.venv/lib/python3.11/site-packages/scanpy/_utils/__init__.py:27
#      25 import h5py
#      26 import numpy as np
# ---> 27 from anndata import __version__ as anndata_version
#      28 from packaging.version import Version
#      29 from scipy import sparse
#
# File ~/scPRINT/.venv/lib/python3.11/site-packages/anndata/__init__.py:27
#      25 from ._core.merge import concat
#      26 from ._core.raw import Raw
# ---> 27 from ._io import (
#      28     read_csv,
#      29     read_excel,
#      30     read_h5ad,
#      31     read_hdf,
#      32     read_loom,
#      33     read_mtx,
#      34     read_text,
#      35     read_umi_tools,
#      36     read_zarr,
#      37 )
#      38 from ._warnings import (
#      39     ExperimentalFeatureWarning,
#      40     ImplicitModificationWarning,
#      41     OldFormatWarning,
#      42     WriteWarning,
#      43 )
#      45 # Experimental needs to be imported last
#
# File ~/scPRINT/.venv/lib/python3.11/site-packages/anndata/_io/__init__.py:3
#       1 from __future__ import annotations
# ----> 3 from .h5ad import read_h5ad, write_h5ad
#       4 from .read import (
#       5     read_csv,
#       6     read_excel,
#    (...)
#      12     read_zarr,
#      13 )
#      14 from .write import write_csvs, write_loom
#
# File ~/scPRINT/.venv/lib/python3.11/site-packages/anndata/_io/h5ad.py:25
#      19 from .._core.sparse_dataset import BaseCompressedSparseDataset
#      20 from ..compat import (
#      21     _clean_uns,
#      22     _decode_structured_array,
#      23     _from_fixed_length_strings,
#      24 )
# ---> 25 from ..experimental import read_dispatched
#      26 from .specs import read_elem, write_elem
#      27 from .specs.registry import IOSpec, write_spec
#
# File ~/scPRINT/.venv/lib/python3.11/site-packages/anndata/experimental/__init__.py:12
#      10 from .merge import concat_on_disk
#      11 from .multi_files import AnnCollection
# ---> 12 from .pytorch import AnnLoader
#      14 # Sphinx can’t find data docstrings when objects are re-exported
#      15 InMemoryElem = _InMemoryElem
#
# File ~/scPRINT/.venv/lib/python3.11/site-packages/anndata/experimental/pytorch/__init__.py:3
#       1 from __future__ import annotations
# ----> 3 from ._annloader import AnnLoader
#       5 __all__ = ["AnnLoader"]
#
# File ~/scPRINT/.venv/lib/python3.11/site-packages/anndata/experimental/pytorch/_annloader.py:18
#      15     from collections.abc import Sequence
#      17 try:
# ---> 18     import torch
#      19     from torch.utils.data import BatchSampler, DataLoader, Sampler
#      20 except ImportError:
#
# File ~/scPRINT/.venv/lib/python3.11/site-packages/torch/__init__.py:2668
#    2664 from torch.func import vmap as vmap
#    2667 if not TYPE_CHECKING:
# -> 2668     from torch import _meta_registrations
#    2670 # Enable CUDA Sanitizer
#    2671 if "TORCH_CUDA_SANITIZER" in os.environ:
#
# File ~/scPRINT/.venv/lib/python3.11/site-packages/torch/_meta_registrations.py:13
#      11 import torch._prims_common as utils
#      12 from torch import SymBool, SymFloat, Tensor
# ---> 13 from torch._decomp import (
#      14     _add_op_to_registry,
#      15     _convert_out_params,
#      16     global_decomposition_table,
#      17     meta_table,
#      18 )
#      19 from torch._ops import OpOverload
#      20 from torch._prims import (
#      21     _prim_elementwise_meta,
#      22     ELEMENTWISE_PRIM_TYPE_PROMOTION_KIND,
#      23     view_of,
#      24 )
#
# File ~/scPRINT/.venv/lib/python3.11/site-packages/torch/_decomp/__init__.py:276
#     272             decompositions.pop(op, None)
#     275 # populate the table
# --> 276 import torch._decomp.decompositions
#     277 import torch._refs
#     280 def core_aten_decompositions() -> "CustomDecompTable":
#
# File ~/scPRINT/.venv/lib/python3.11/site-packages/torch/_decomp/decompositions.py:16
#      14 import torch
#      15 import torch._meta_registrations
# ---> 16 import torch._prims as prims
#      17 import torch._prims_common as utils
#      18 import torch.nn.functional as F
#
# File ~/scPRINT/.venv/lib/python3.11/site-packages/torch/_prims/__init__.py:525
#     517     raise NotImplementedError
#     520 #
#     521 # Elementwise unary operations
#     522 #
# --> 525 abs = _make_elementwise_unary_prim(
#     526     "abs",
#     527     impl_aten=torch.abs,
#     528     doc="",
#     529     type_promotion=ELEMENTWISE_PRIM_TYPE_PROMOTION_KIND.COMPLEX_TO_FLOAT,
#     530 )
#     532 acos = _make_elementwise_unary_prim(
#     533     "acos",
#     534     impl_aten=torch.acos,
#     535     doc="",
#     536     type_promotion=ELEMENTWISE_PRIM_TYPE_PROMOTION_KIND.DEFAULT,
#     537 )
#     539 acosh = _make_elementwise_unary_prim(
#     540     "acosh",
#     541     impl_aten=torch.acosh,
#     542     doc="",
#     543     type_promotion=ELEMENTWISE_PRIM_TYPE_PROMOTION_KIND.DEFAULT,
#     544 )
#
# File ~/scPRINT/.venv/lib/python3.11/site-packages/torch/_prims/__init__.py:493, in _make_elementwise_unary_prim(name, type_promotion, **kwargs)
#     486 def _make_elementwise_unary_prim(
#     487     name: str, *, type_promotion: ELEMENTWISE_PRIM_TYPE_PROMOTION_KIND, **kwargs
#     488 ):
#     489     """
#     490     Creates an elementwise unary prim.
#     491     """
# --> 493     return _make_prim(
#     494         schema=f"{name}(Tensor self) -> Tensor",
#     495         meta=partial(_prim_elementwise_meta, type_promotion=type_promotion),
#     496         return_type=RETURN_TYPE.NEW,
#     497         **kwargs,
#     498     )
#
# File ~/scPRINT/.venv/lib/python3.11/site-packages/torch/_prims/__init__.py:321, in _make_prim(schema, return_type, meta, impl_aten, doc, tags, use_old_custom_ops_api, register_conj_neg_fallthrough)
#     315 else:
#     316     mutates_args = [
#     317         arg.name
#     318         for arg in cpp_schema.arguments
#     319         if arg.alias_info is not None and arg.alias_info.is_write
#     320     ]
# --> 321     prim_def = torch.library.custom_op(
#     322         "prims::" + name,
#     323         _prim_impl,
#     324         mutates_args=tuple(mutates_args),
#     325         schema=schema,
#     326     )
#     327     prim_def.register_fake(meta)
#     329     # all view ops get conj/neg fallthroughs
#
# File ~/scPRINT/.venv/lib/python3.11/site-packages/torch/_library/custom_ops.py:174, in custom_op(name, fn, mutates_args, device_types, schema, tags)
#     172 if fn is None:
#     173     return inner
# --> 174 return inner(fn)
#
# File ~/scPRINT/.venv/lib/python3.11/site-packages/torch/_library/custom_ops.py:155, in custom_op.<locals>.inner(fn)
#     152     schema_str = schema
#     154 namespace, opname = name.split("::")
# --> 155 result = CustomOpDef(namespace, opname, schema_str, fn, tags)
#     156 if schema is not None:
#     157     # Check that schema's alias annotations match those of `mutates_args`.
#     158     expected = set()
#
# File ~/scPRINT/.venv/lib/python3.11/site-packages/torch/_library/custom_ops.py:213, in CustomOpDef.__init__(self, namespace, name, schema, fn, tags)
#     210 self._autocast_cpu_dtype: Optional[_dtype] = None
#     212 self._lib = get_library_allowing_overwrite(self._namespace, self._name)
# --> 213 self._register_to_dispatcher(self._tags)
#     214 self._disabled_kernel: set = set()
#     215 OPDEFS[self._qualname] = self
#
# File ~/scPRINT/.venv/lib/python3.11/site-packages/torch/_library/custom_ops.py:634, in CustomOpDef._register_to_dispatcher(self, tags)
#     626         raise RuntimeError(
#     627             f"There was no fake impl registered for {self}. "
#     628             f"This is necessary for torch.compile/export/fx tracing to work. "
#     629             f"Please use `{self._init_fn.__name__}.register_fake` to add an "
#     630             f"fake impl."
#     631         )
#     632     return self._abstract_fn(*args, **kwargs)
# --> 634 lib._register_fake(self._name, fake_impl, _stacklevel=4)
#     636 autograd_impl = autograd.make_autograd_impl(self._opoverload, self)
#     637 lib.impl(self._name, autograd_impl, "Autograd", with_keyset=True)
#
# File ~/scPRINT/.venv/lib/python3.11/site-packages/torch/library.py:198, in Library._register_fake(self, op_name, fn, _stacklevel, allow_override)
#     195     _library.utils.warn_deploy()
#     196     return
# --> 198 source = torch._library.utils.get_source(_stacklevel + 1)
#     199 frame = sys._getframe(_stacklevel)
#     200 caller_module = inspect.getmodule(frame)
#
# File ~/scPRINT/.venv/lib/python3.11/site-packages/torch/_library/utils.py:54, in get_source(stacklevel)
#      45 def get_source(stacklevel: int) -> str:
#      46     """Get a string that represents the caller.
#      47
#      48     Example: "/path/to/foo.py:42"
#    (...)
#      52     etc.
#      53     """
# ---> 54     frame = inspect.getframeinfo(sys._getframe(stacklevel))
#      55     source = f"{frame.filename}:{frame.lineno}"
#      56     return source
#
# File ~/.local/share/uv/python/cpython-3.11.11-linux-x86_64-gnu/lib/python3.11/inspect.py:1688, in getframeinfo(frame, context)
#    1686 start = lineno - 1 - context//2
#    1687 try:
# -> 1688     lines, lnum = findsource(frame)
#    1689 except OSError:
#    1690     lines = index = None
#
# File ~/.local/share/uv/python/cpython-3.11.11-linux-x86_64-gnu/lib/python3.11/inspect.py:1071, in findsource(object)
#    1068     if not (file.startswith('<') and file.endswith('>')):
#    1069         raise OSError('source code not available')
# -> 1071 module = getmodule(object, file)
#    1072 if module:
#    1073     lines = linecache.getlines(file, module.__dict__)
#
# File ~/.local/share/uv/python/cpython-3.11.11-linux-x86_64-gnu/lib/python3.11/inspect.py:994, in getmodule(object, _filename)
#     992     continue
#     993 _filesbymodname[modname] = f
# --> 994 f = getabsfile(module)
#     995 # Always map to the name the module knows itself by
#     996 modulesbyfile[f] = modulesbyfile[
#     997     os.path.realpath(f)] = module.__name__
#
# File ~/.local/share/uv/python/cpython-3.11.11-linux-x86_64-gnu/lib/python3.11/inspect.py:963, in getabsfile(object, _filename)
#     958 """Return an absolute path to the source or compiled file for an object.
#     959
#     960 The idea is for each object to have a unique origin, so this routine
#     961 normalizes the result as much as possible."""
#     962 if _filename is None:
# --> 963     _filename = getsourcefile(object) or getfile(object)
#     964 return os.path.normcase(os.path.abspath(_filename))
#
# File ~/.local/share/uv/python/cpython-3.11.11-linux-x86_64-gnu/lib/python3.11/inspect.py:945, in getsourcefile(object)
#     942 elif any(filename.endswith(s) for s in
#     943              importlib.machinery.EXTENSION_SUFFIXES):
#     944     return None
# --> 945 if os.path.exists(filename):
#     946     return filename
#     947 # only return a non-existent filename if the module has a PEP 302 loader
#
# File <frozen genericpath>:19, in exists(path)
#
# KeyboardInterrupt:

# %% [markdown]
# # (OPTIONAL) Loading the human interactome gene network

# %%
! wget --no-check-certificate -O $LOC/RF2-PPI.gz https://conglab.swmed.edu/humanPPI/downloads/RF2-PPI_scores.gz
! wget --no-check-certificate -O $LOC/DCA_scores.gz https://conglab.swmed.edu/humanPPI/downloads/DCA_scores.gz
! wget --no-check-certificate -O $LOC/AF_scores.gz https://conglab.swmed.edu/humanPPI/downloads/AF_scores.gz
# Out:
# --2025-11-12 23:10:51--  https://conglab.swmed.edu/humanPPI/downloads/RF2-PPI_scores.gz
# Resolving maestro-squid.maestro.pasteur.fr (maestro-squid.maestro.pasteur.fr)... 192.168.148.66
# Connecting to maestro-squid.maestro.pasteur.fr (maestro-squid.maestro.pasteur.fr)|192.168.148.66|:3128... connected.
# WARNING: The certificate of ‘conglab.swmed.edu’ is not trusted.
# WARNING: The certificate of ‘conglab.swmed.edu’ hasn't got a known issuer.
# Proxy request sent, awaiting response...
# 200 OK
# Length: 443540479 (423M) [application/x-gzip]
# Saving to: ‘/pasteur/appa/scratch/jkalfon/data/spcrint_data/RF2-PPI.gz’
#
#
#           /pasteur/   0%[                    ]       0  --.-KB/s
#          /pasteur/a   0%[                    ]  46.78K   191KB/s
#         /pasteur/ap   0%[                    ] 210.84K   431KB/s
#        /pasteur/app   0%[                    ] 867.09K  1.15MB/s
#       /pasteur/appa   0%[                    ]   3.42M  3.50MB/s
#      /pasteur/appa/   2%[                    ]   9.36M  7.90MB/s
#     /pasteur/appa/s   3%[                    ]  15.29M  11.0MB/s
#    /pasteur/appa/sc   4%[                    ]  18.32M  11.5MB/s
#   /pasteur/appa/scr   5%[>                   ]  24.16M  13.1MB/s
#  /pasteur/appa/scra   7%[>                   ]  30.14M  14.4MB/s
# /pasteur/appa/scrat   8%[>                   ]  35.99M  15.4MB/s
# pasteur/appa/scratc   9%[>                   ]  41.93M  16.2MB/s
# asteur/appa/scratch  11%[=>                  ]  47.77M  16.8MB/s
# steur/appa/scratch/  12%[=>                  ]  53.69M  17.4MB/s    eta 21s
# teur/appa/scratch/j  14%[=>                  ]  59.55M  17.9MB/s    eta 21s
# eur/appa/scratch/jk  15%[==>                 ]  65.41M  18.3MB/s    eta 21s
# ur/appa/scratch/jka  16%[==>                 ]  71.32M  18.6MB/s    eta 21s
# r/appa/scratch/jkal  18%[==>                 ]  77.24M  20.1MB/s    eta 18s
# /appa/scratch/jkalf  19%[==>                 ]  83.17M  22.4MB/s    eta 18s
# appa/scratch/jkalfo  21%[===>                ]  89.04M  23.5MB/s    eta 18s
# ppa/scratch/jkalfon  22%[===>                ]  94.95M  23.3MB/s    eta 18s
# pa/scratch/jkalfon/  23%[===>                ] 100.78M  23.8MB/s    eta 16s
# a/scratch/jkalfon/d  25%[====>               ] 106.76M  23.4MB/s    eta 16s
# /scratch/jkalfon/da  26%[====>               ] 112.53M  23.8MB/s    eta 16s
# scratch/jkalfon/dat  28%[====>               ] 118.48M  23.8MB/s    eta 16s
# cratch/jkalfon/data  29%[====>               ] 124.30M  23.4MB/s    eta 15s
# ratch/jkalfon/data/  30%[=====>              ] 130.28M  23.8MB/s    eta 15s
# atch/jkalfon/data/s  32%[=====>              ] 136.09M  23.8MB/s    eta 15s
# tch/jkalfon/data/sp  33%[=====>              ] 142.06M  23.4MB/s    eta 15s
# ch/jkalfon/data/spc  34%[=====>              ] 147.93M  23.8MB/s    eta 13s
# h/jkalfon/data/spcr  36%[======>             ] 153.88M  23.8MB/s    eta 13s
# /jkalfon/data/spcri  37%[======>             ] 159.74M  23.4MB/s    eta 13s
# jkalfon/data/spcrin  39%[======>             ] 165.66M  23.8MB/s    eta 13s
# kalfon/data/spcrint  40%[=======>            ] 171.46M  23.7MB/s    eta 12s
# alfon/data/spcrint_  41%[=======>            ] 177.44M  23.4MB/s    eta 12s
# lfon/data/spcrint_d  43%[=======>            ] 183.22M  23.8MB/s    eta 12s
# fon/data/spcrint_da  44%[=======>            ] 189.20M  23.8MB/s    eta 12s
# on/data/spcrint_dat  46%[========>           ] 194.98M  23.4MB/s    eta 11s
# n/data/spcrint_data  47%[========>           ] 200.95M  23.3MB/s    eta 11s
# /data/spcrint_data/  48%[========>           ] 206.79M  23.7MB/s    eta 11s
# data/spcrint_data/R  50%[=========>          ] 212.41M  23.3MB/s    eta 11s
# ata/spcrint_data/RF  51%[=========>          ] 218.34M  23.3MB/s    eta 11s
# ta/spcrint_data/RF2  52%[=========>          ] 224.17M  23.7MB/s    eta 9s
# a/spcrint_data/RF2-  54%[=========>          ] 230.16M  23.7MB/s    eta 9s
# /spcrint_data/RF2-P  55%[==========>         ] 236.11M  23.3MB/s    eta 9s
# spcrint_data/RF2-PP  57%[==========>         ] 241.96M  23.7MB/s    eta 9s
# pcrint_data/RF2-PPI  58%[==========>         ] 247.92M  23.7MB/s    eta 8s
# crint_data/RF2-PPI.  59%[==========>         ] 253.76M  23.3MB/s    eta 8s
# rint_data/RF2-PPI.g  61%[===========>        ] 259.72M  23.4MB/s    eta 8s
# int_data/RF2-PPI.gz  62%[===========>        ] 265.58M  23.8MB/s    eta 8s
# nt_data/RF2-PPI.gz   64%[===========>        ] 271.47M  23.3MB/s    eta 7s
# t_data/RF2-PPI.gz    65%[============>       ] 277.34M  23.3MB/s    eta 7s
# _data/RF2-PPI.gz     66%[============>       ] 283.25M  23.4MB/s    eta 7s
# data/RF2-PPI.gz      68%[============>       ] 289.12M  23.7MB/s    eta 7s
# ata/RF2-PPI.gz       69%[============>       ] 295.00M  23.8MB/s    eta 6s
# ta/RF2-PPI.gz        71%[=============>      ] 300.95M  23.4MB/s    eta 6s
# a/RF2-PPI.gz         72%[=============>      ] 306.82M  23.5MB/s    eta 6s
# /RF2-PPI.gz          73%[=============>      ] 312.76M  23.3MB/s    eta 6s
# RF2-PPI.gz           75%[==============>     ] 318.64M  23.8MB/s    eta 5s
# F2-PPI.gz            76%[==============>     ] 324.51M  23.8MB/s    eta 5s
# 2-PPI.gz             78%[==============>     ] 330.41M  23.3MB/s    eta 5s
# -PPI.gz              79%[==============>     ] 336.30M  23.4MB/s    eta 5s
# PPI.gz               80%[===============>    ] 342.24M  23.3MB/s    eta 4s
# PI.gz                82%[===============>    ] 348.14M  23.8MB/s    eta 4s
# I.gz                 83%[===============>    ] 354.07M  23.4MB/s    eta 4s
# .gz                  85%[================>   ] 359.92M  23.3MB/s    eta 4s
# gz                   86%[================>   ] 365.86M  23.8MB/s    eta 3s
# z                    87%[================>   ] 371.69M  23.4MB/s    eta 3s
#                      89%[================>   ] 377.65M  23.4MB/s    eta 3s
#                   /  90%[=================>  ] 383.42M  23.8MB/s    eta 3s
#                  /p  92%[=================>  ] 389.35M  24.1MB/s    eta 3s
#                 /pa  93%[=================>  ] 394.23M  23.7MB/s    eta 1s
#                /pas  94%[=================>  ] 398.15M  23.4MB/s    eta 1s
#               /past  95%[==================> ] 404.01M  23.8MB/s    eta 1s

# %%
res = pd.read_csv(
    LOC + "/RF2-PPI.gz",
    sep="\t",
    skiprows=7,
    header=None,  # nrows=100_000_000
)
res.columns = ["Pair", "RF2-PPI_interaction_probability", "Source"]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 res = pd.read_csv(
#       2     LOC + "/RF2-PPI.gz",
#       3     sep="\t",
#       4     skiprows=7,
#       5     header=None,  # nrows=100_000_000
#       6 )
#       7 res.columns = ["Pair", "RF2-PPI_interaction_probability", "Source"]
#
# File ~/scPRINT/.venv/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/scPRINT/.venv/lib/python3.11/site-packages/pandas/io/parsers/readers.py:626, in _read(filepath_or_buffer, kwds)
#     623     return parser
#     625 with parser:
# --> 626     return parser.read(nrows)
#
# File ~/scPRINT/.venv/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1923, in TextFileReader.read(self, nrows)
#    1916 nrows = validate_integer("nrows", nrows)
#    1917 try:
#    1918     # error: "ParserBase" has no attribute "read"
#    1919     (
#    1920         index,
#    1921         columns,
#    1922         col_dict,
# -> 1923     ) = self._engine.read(  # type: ignore[attr-defined]
#    1924         nrows
#    1925     )
#    1926 except Exception:
#    1927     self.close()
#
# File ~/scPRINT/.venv/lib/python3.11/site-packages/pandas/io/parsers/c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File parsers.pyx:838, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File parsers.pyx:905, in pandas._libs.parsers.TextReader._read_rows()
#
# File parsers.pyx:874, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File parsers.pyx:2053, in pandas._libs.parsers.raise_parser_error()
#
# File ~/.local/share/uv/python/cpython-3.11.11-linux-x86_64-gnu/lib/python3.11/_compression.py:68, in DecompressReader.readinto(self, b)
#      66 def readinto(self, b):
#      67     with memoryview(b) as view, view.cast("B") as byte_view:
# ---> 68         data = self.read(len(byte_view))
#      69         byte_view[:len(data)] = data
#      70     return len(data)
#
# File ~/.local/share/uv/python/cpython-3.11.11-linux-x86_64-gnu/lib/python3.11/gzip.py:507, in _GzipReader.read(self, size)
#     504 # Read a chunk of data from the file
#     505 buf = self._fp.read(io.DEFAULT_BUFFER_SIZE)
# --> 507 uncompress = self._decompressor.decompress(buf, size)
#     508 if self._decompressor.unconsumed_tail != b"":
#     509     self._fp.prepend(self._decompressor.unconsumed_tail)
#
# KeyboardInterrupt:

# %%
import bionty as bt

# %%
sns.histplot(res["RF2-PPI_interaction_probability"])

# %%
prot_to_gene = {
    i["uniprotkb_id"]: i["gene_symbol"]
    for k, i in bt.Protein.public().to_dataframe().iterrows()
}
genes = []
for i in res.Pair:
    a, b = i.split("_")
    genes.append([prot_to_gene.get(a, ""), prot_to_gene.get(b, "")])

res[["geneA", "geneB"]] = genes

# %%
res = res[~res["geneA"].isna() & ~res["geneB"].isna()]

# %%
res.to_parquet(LOC + "/RF2-PPI.parquet")

# %%
res = pd.read_parquet(LOC + "/RF2-PPI.parquet")

# %%
THRESHOLD = 0.5

# %%
humaninter_s = set(
    res[res["RF2-PPI_interaction_probability"] > THRESHOLD]["geneA"]
    .str.cat(res[res["RF2-PPI_interaction_probability"] > THRESHOLD]["geneB"], sep="_")
    .tolist()
)

# %%
len(humaninter_s)
# Out:
# 364278

# %% [markdown]
# # (OPTIONAL) loading the cellmap gene network

# %%
# getting U2OS cell map data
import json

try:
    import ndex2
except ImportError:
    os.system("uv pip install ndex2")
    import ndex2
from ndex2.cx2 import RawCX2NetworkFactory, CX2NetworkXFactory
from ndex2.cx2 import CX2NetworkPandasDataFrameFactory

# Create NDEx2 python client
client = ndex2.client.Ndex2()

# Create CX2Network factory
factory = RawCX2NetworkFactory()

client_resp = client.get_network_as_cx2_stream("95bc75d5-d1d1-11ee-8a40-005056ae23aa")

# Convert downloaded network to CX2Network object
net_cx = factory.get_cx2network(json.loads(client_resp.content))

# Display information about network and output 1st 100 characters of CX2
print("Name: " + net_cx.get_name())
print("Number of nodes: " + str(len(net_cx.get_nodes())))
print("Number of edges: " + str(len(net_cx.get_edges())))

# Creating an instance of CX2NetworkPandasDataFrameFactory
factory = CX2NetworkPandasDataFrameFactory()

# Converting CX2Network to DataFrame
cellmap = factory.get_dataframe(net_cx)
# Out:
# Name: U2OS AP-MS network
# Number of nodes: 7543
# Number of edges: 36842

# %%
cellmap_s = set([s + "_" + t for s, t in cellmap.iloc[:, [2, 4]].values])

# %% [markdown]
# # (OPTIONAL) comparison of ground truth gene networks

# %%
gwps = get_perturb_gt(
    filename_adata="/pasteur/appa/homes/jkalfon/benGRN/data/ess_perturb_sc.h5ad",
    filename_bh="/pasteur/appa/homes/jkalfon/benGRN/data/BH-corrected.csv.gz",
)
gwps.var.index = gwps.var.gene_name
gwps = gwps.extract_links()

# %%
omni = get_GT_db("omnipath")
collectri = get_GT_db("collectri")

# %%
omni_s = set([s + "_" + t for s, t in omni.iloc[:, :2].values])
collectri_s = set([s + "_" + t for s, t in collectri.iloc[:, :2].values])
gwps_s = set([s + "_" + t for s, t in gwps.iloc[:, :2].values])

# %%
print("number of edges in gwps: ", len(gwps_s))
print("number of edges in omni: ", len(omni_s))
print("number of edges in collectri: ", len(collectri_s))
print("number of edges in humaninter: ", len(humaninter_s))
print("number of edges in cellmap: ", len(cellmap_s))
# Out:
# number of edges in gwps:  1115036
# number of edges in omni:  273556
# number of edges in collectri:  41595
# number of edges in humaninter:  765411
# number of edges in cellmap:  36842

# %%
cellmap_s
# Out:
# {'ASPH_SLC38A1',
#  'NEMP1_GLRB',
#  'WASHC3_ATP6V0D1',
#  'EFNB2_USP32',
#  'ERAP1_UBTF',
#  'ZFPL1_RAB3GAP1',
#  'SPINT2_OSMR',
#  'VENTX_PON2',
#  'VENTX_PGLS',
#  'CLGN_JMJD8',
#  'FGL1_LIMCH1',
#  'ZNF346_YTHDC1',
#  'CHRM4_SLC25A24',
#  'CD40_SMG8',
#  'LPAR1_ACSL4',
#  'CTSV_LRRC15',
#  'LRRC49_SANBR',
#  'MRPS23_GYS1',
#  'PTPN4_SVIL',
#  'NEUROG3_RBM23',
#  'VENTX_PPCS',
#  'FOSL2_C1D',
#  'BBS1_BBS5',
#  'SNAP91_BRCA1',
#  'CDC20_SKP2',
#  'TMEM31_UCHL5',
#  'PYCR3_BCL7C',
#  'ITM2C_CYRIB',
#  'NIPAL1_TRPM4',
#  'HTR2C_TBC1D15',
#  'TTC9C_USO1',
#  'GAB2_PLS3',
#  'BRK1_ABI3',
#  'SPSB2_USP11',
#  'ANKRD46_ATRN',
#  'EGFL8_EGFL7',
#  'SURF6_SCAF8',
#  'UCHL5_INO80C',
#  'MED17_MED9',
#  'PSG3_TMEM214',
#  'FBXO6_IGF1R',
#  'IGF2BP3_MRPL10',
#  'CTSV_CTSL',
#  'RBMX2_SPOUT1',
#  'CCT7_TXNDC9',
#  'CTNNBIP1_CTNNA2',
#  'LPAR1_EXOC6B',
#  'NDUFC2_NDUFB1',
#  'GPR12_ATL3',
#  'TLE2_CCT5',
#  'CCT7_KLHDC8B',
#  'S1PR3_NIBAN2',
#  'GPR17_ECHDC1',
#  'PSMA5_PSMB7',
#  'PLOD3_VPS33B',
#  'YWHAB_RAI14',
#  'LPAR1_SKP2',
#  'ANAPC5_CDC27',
#  'ACVR1_MED24',
#  'KCTD17_EGFL7',
#  'SLC2A12_ACY1',
#  'FOSL2_PHC2',
#  'ARPC5_ARPC1A',
#  'ADIPOQ_MUL1',
#  'PIGT_ABHD10',
#  'CLGN_TGFBR1',
#  'RAB27A_SYTL1',
#  'ECD_SGPL1',
#  'IL12RB1_ITGA2',
#  'MED21_CCNC',
#  'S1PR1_SCAMP2',
#  'GYPA_VAC14',
#  'PNMA2_FYTTD1',
#  'CCDC22_PSPC1',
#  'NPTN_TBCD',
#  'CDK5RAP3_MAOA',
#  'TNFRSF6B_KEAP1',
#  'CD53_RBM38',
#  'SNIP1_PNN',
#  'HPN_TRNT1',
#  'FGF17_FGF8',
#  'HSPB8_MAPKAP1',
#  'BMP4_S100A14',
#  'BCL2L11_MCL1',
#  'WDR83_ZNF830',
#  'PRKACB_GLUL',
#  'TTC1_QPRT',
#  'LLGL2_RAD18',
#  'LRRC46_TBP',
#  'CSNK2B_GPATCH2',
#  'FAM234B_FRMD5',
#  'ZNRD2_TTLL5',
#  'CXCR3_CUX1',
#  'RNF10_TAF1C',
#  'PKP2_ANXA8L1',
#  'FBXL16_ARMT1',
#  'CLGN_MSMO1',
#  'SMPD2_VPS4B',
#  'MYCBP_ECM1',
#  'KXD1_NUCB2',
#  'CREB3L2_ZFP36L2',
#  'NUP50_KPNA2',
#  'YBX2_MRPL9',
#  'CREB3L2_HOMER3',
#  'TUBB_ARL2',
#  'SNRPF_EFTUD2',
#  'UTP14A_RPL11',
#  'FTL_DYRK4',
#  'NPTN_UFL1',
#  'SAAL1_GOSR1',
#  'VAPB_LRRC57',
#  'ERF_MAPK3',
#  'EFNB1_FAM114A2',
#  'BZW2_ENDOD1',
#  'ARL13B_IFT56',
#  'PNMA2_PLEKHA7',
#  'ZNRD2_SNX33',
#  'CD28_TMEM192',
#  'ITM2C_SPR',
#  'WNT4_TOMM40',
#  'SDC2_EXOC3',
#  'CD40_COG6',
#  'CLGN_ADAM10',
#  'TMEM63A_AK6',
#  'NPPB_BCAP31',
#  'ITM2C_LOC102724560',
#  'CSNK2B_PHRF1',
#  'LHFPL2_DAAM1',
#  'DYNLL2_MTPAP',
#  'HEATR3_DGKE',
#  'SAAL1_TMED4',
#  'SLC30A2_NKIRAS2',
#  'SYF2_LRRC57',
#  'HAVCR2_IKBKG',
#  'CYP1A1_MYCBP2',
#  'NAT14_PLAA',
#  'KPNA1_ERCC1',
#  'SMPD2_UPP1',
#  'TLE1_TLE3',
#  'SYN3_WRNIP1',
#  'THY1_CREG1',
#  'XXYLT1_SLC9A1',
#  'SINHCAF_ING2',
#  'GDPD5_RETSAT',
#  'SMPD2_ATP6V1F',
#  'ELL3_CCNT1',
#  'DBNL_HERC2',
#  'PDCD2L_PRMT3',
#  'TMEM88_SLC30A5',
#  'LGALS9_TAGLN',
#  'EAF1_ERCC3',
#  'TMEM9_EXOC8',
#  'FASLG_RUSF1',
#  'DYNLL1_BLTP3B',
#  'MRPL13_PTCD1',
#  'SEPTIN7_SEPTIN8',
#  'SEC11C_PDE12',
#  'TWF2_VPS29',
#  'KANSL3_NHLRC2',
#  'NUP43_TP53RK',
#  'MRAP2_PODXL',
#  'LCN6_DCBLD2',
#  'LPAR1_COMT',
#  'CAMKV_AFF4',
#  'LRRC57_UNC119B',
#  'EHHADH_TRIM41',
#  'PPP2R1A_STRIP2',
#  'NTN5_TCF25',
#  'VAPB_RAB3GAP1',
#  'DNAJA2_APOOL',
#  'LGALS1_PTPRJ',
#  'ILVBL_USP34',
#  'FANCD2OS_DIS3',
#  'VTN_MRPS18C',
#  'HPN_ELMO2',
#  'ZNF346_YTHDC2',
#  'COL10A1_BIRC6',
#  'TYROBP_RETREG3',
#  'CREB3L2_KIF1B',
#  'SYT2_AHCYL1',
#  'POLR2M_POLR2A',
#  'SZRD1_GLYR1',
#  'MRPS23_MRPS26',
#  'LDLRAD1_DHRS13',
#  'DYNLL1_CIZ1',
#  'INHA_INHBA',
#  'RSPO1_MYH2',
#  'LYAR_PRR11',
#  'SFXN3_ACSL1',
#  'SCN3B_GOLM1',
#  'TEX28_TMCC2',
#  'RAB11B_RAB11FIP3',
#  'USP46_MIF',
#  'C1QTNF9_UGGT2',
#  'REXO4_LIG3',
#  'CHRNB1_WLS',
#  'PTX3_OFD1',
#  'CNOT11_CNOT1',
#  'STX7_FAM234A',
#  'ADGRG5_TMX4',
#  'FBXO2_AMOTL2',
#  'PCDHGA5_KLHL13',
#  'BCL2L11_SERPINA1',
#  'PSMA5_PSMA6',
#  'SLC39A4_GOLM1',
#  'C3orf18_SPAG9',
#  'FADS3_ABCC1',
#  'FPR1_PIK3R4',
#  'RACK1_ZNF598',
#  'DND1_TAGLN',
#  'PKP2_EVPL',
#  'MAPK9_WDR62',
#  'LYZ_RPL10A',
#  'CD40_PLXNB2',
#  'WNT10B_UBE2Z',
#  'KLHDC2_CUL5',
#  'ELL3_MLLT1',
#  'CLGN_PROCR',
#  'PEX7_CISD2',
#  'PCDHAC2_ST7',
#  'RAMP3_ALDH18A1',
#  'RAE1_TSC22D1',
#  'CCT3_DTL',
#  'RNF10_UTP11',
#  'CLGN_SLC38A9',
#  'CX3CL1_SPRR3',
#  'KXD1_TFIP11',
#  'FPR1_PPP4R1',
#  'LYPD3_PTPN1',
#  'CXCR3_CAMK1D',
#  'GPR17_ACAD8',
#  'OPALIN_HSD17B14',
#  'YWHAB_CEP112',
#  'RBBP5_KMT2B',
#  'UPK2_SLC2A4',
#  'ZNF467_ACSF3',
#  'LAMTOR5_SLC38A9',
#  'AZU1_CYB5A',
#  'CCDC22_VPS33B',
#  'CSGALNACT2_RHBDF2',
#  'AHSP_TEPSIN',
#  'SNRPF_SART1',
#  'NXPH1_ADAM10',
#  'C10orf88_CLTCL1',
#  'DHX8_CBX2',
#  'GAB2_HEBP1',
#  'NPTN_NBEAL2',
#  'FTL_SH3RF2',
#  'TGIF2LY_AHCYL1',
#  'PPP2R1A_TIPRL',
#  'BORCS8_SNAPIN',
#  'CA10_KANK1',
#  'FPR1_PDS5B',
#  'DNAJC30_VENTX',
#  'ETV6_HSPA8',
#  'AFG2B_AIRIM',
#  'STAMBP_OTUD4',
#  'SSTR2_H1-4',
#  'EIF4E_EIF4G1',
#  'KLHDC2_PTOV1',
#  'MRM1_RRS1',
#  'CD40_TRAF1',
#  'PSMB8_PSMD2',
#  'CD27_PAPSS1',
#  'GDPD5_GOLT1B',
#  'NPPB_PSAP',
#  'LLGL2_ZCCHC9',
#  'BRICD5_PLAU',
#  'RAMP3_HSD17B7',
#  'ERF_ELMO2',
#  'PIGT_RANBP9',
#  'LIN28A_ZCCHC3',
#  'SCRN1_TAB1',
#  'SMPD2_PITHD1',
#  'HMGA1_REXO4',
#  'MYCBP_PNP',
#  'RPL22_AGTPBP1',
#  'C1orf174_HELZ2',
#  'S1PR3_SPTLC2',
#  'EGFL7_CEP131',
#  'KIAA1191_RPRD1B',
#  'LLGL2_ESF1',
#  'STX18_NBAS',
#  'NUF2_SPC24',
#  'CREB3L2_RFX7',
#  'DNAJA2_IFT122',
#  'RSRP1_SERPINB1',
#  'SNRPF_GEMIN6',
#  'CXCR3_SETX',
#  'CLDND1_B4GALT4',
#  'HMGA1_POLRMT',
#  'EMID1_LTBP4',
#  'IFT57_IFT56',
#  'PYM1_RBMS2',
#  'LCN6_TMEM177',
#  'DNAJC11_ARMC1',
#  'SCN2B_HEATR6',
#  'CENPH_B4GAT1',
#  'LPAR1_MTX1',
#  'SSTR2_ARHGAP29',
#  'EPHA1_ARMC9',
#  'PPP2R2B_SIL1',
#  'GRB2_MVB12A',
#  'CUEDC1_TOM1L2',
#  'HTR1E_FANCD2',
#  'LIN7B_PALS2',
#  'ZCCHC10_IQCA1',
#  'CLGN_TCTN3',
#  'MRPL49_CAND2',
#  'LRRC8B_CDH2',
#  'SCARB2_LGALS1',
#  'EMILIN3_RANBP9',
#  'TRDN_ZFPL1',
#  'PPP4R2_LMCD1',
#  'AKIRIN2_AKIRIN1',
#  'RNF10_DLGAP5',
#  'DDX28_AKR1A1',
#  'SLC1A1_SPPL3',
#  'IGSF8_EIF2B5',
#  'NPTN_INPP5K',
#  'ACKR3_ITCH',
#  'CDH23_NGLY1',
#  'VENTX_SLK',
#  'MAD2L1BP_KIF20A',
#  'TMED9_TMED10',
#  'NOA1_MRPS12',
#  'TBC1D15_B4GALT7',
#  'ZNF346_RPL4',
#  'YWHAQ_PAK4',
#  'RPS3_ASCC2',
#  'TMEM171_RNF166',
#  'SPATA25_TAF3',
#  'MRPL42_RPL13',
#  'TCEAL9_TGM5',
#  'MEAF6_ZC3H18',
#  'FBXO6_DNASE2',
#  'KCTD17_SLC1A3',
#  'OAS1_TJP2',
#  'NXPH3_SUFU',
#  'PPP2R3A_NQO2',
#  'SCN3B_ABCD3',
#  'FAAP24_FANCM',
#  'VENTX_ARPC1A',
#  'PNMA2_ARHGAP23',
#  'DHX38_PPIL4',
#  'TMEM31_DSG4',
#  'SFRP4_SAMD1',
#  'REXO4_CCDC80',
#  'CHRNB2_RAB3GAP2',
#  'SMPD2_PLS3',
#  'POLR2M_HSPA8',
#  'SNX4_HBA1',
#  'GPN3_POLR3K',
#  'PATE1_LRP12',
#  'CHST8_ARL10',
#  'GLIPR1L2_GID8',
#  'MCRIP2_SNX3',
#  'MAGEB2_ZNF787',
#  'RSL1D1_IMP3',
#  'SLC30A2_ADGRB1',
#  'EDA_TRIM44',
#  'ABT1_SURF6',
#  'YWHAQ_RAF1',
#  'PCDH20_MAP7D3',
#  'VENTX_FAH',
#  'CEACAM8_CLIP2',
#  'EGFL7_FBN2',
#  'PNMA2_CTU1',
#  'SMPD2_GGPS1',
#  'ZNRD2_DCAF4',
#  'HTR1E_B4GAT1',
#  'HDAC1_ZNF609',
#  'PNMA2_POLRMT',
#  'RBPMS_HEXB',
#  'MRPL12_MRPL55',
#  'TMEM192_EIF2B2',
#  'VIPR1_ATP5PB',
#  'CCNC_MED29',
#  'PATE1_MET',
#  'PLEKHN1_MON1B',
#  'WIF1_MAPK13',
#  'MRPL12_MRPL47',
#  'IZUMO1_CDC16',
#  'CD226_EIF2B4',
#  'DNAJB8_RNF213',
#  'PPM1B_PAXX',
#  'L3HYPDH_LDHC',
#  'CAVIN1_XPC',
#  'MED4_MED29',
#  'TSEN15_PPP1R7',
#  'SNIP1_BUD13',
#  'NOTCH2_PLAT',
#  'NDUFB5_NDUFB10',
#  'DUOXA2_PANK4',
#  'PNMA2_PEAK1',
#  'KRR1_DHX57',
#  'SLC25A40_HIGD1A',
#  'FAM170A_MCM3AP',
#  'RPL17_SMARCA5',
#  'SSBP4_LDB2',
#  'MCL1_PRKAG1',
#  'C1QC_SIL1',
#  'LGALS3_ENPP4',
#  'RRP8_ESF1',
#  'ZNF512B_MTA2',
#  'FAM167A_CDC42BPA',
#  'AP3M1_AP3S1',
#  'DNAJC25_UFSP2',
#  'HTR2C_CELSR2',
#  'GPR12_SCAMP4',
#  'ABHD10_ACOT9',
#  'RPL19_DDX55',
#  'ZCCHC10_UTP20',
#  'ITM2C_TRMT10C',
#  'TBC1D15_UBR5',
#  'NDRG2_TMEM70',
#  'PSMD2_RNF10',
#  'VSIG4_ERBB2',
#  'NPTN_SNX8',
#  'SNIP1_BCLAF1',
#  'PEX7_ARPIN',
#  'SKP1_LPIN1',
#  'RPS19_USP16',
#  'KPNA2_MTA3',
#  'PNN_MKLN1',
#  'INAVA_CYTH1',
#  'DNAJB2_RNF115',
#  'LCN6_SLC25A33',
#  'LYPD1_SKIC3',
#  'DDX28_DPP3',
#  'DND1_SEC23IP',
#  'RHOA_GLB1',
#  'FBXO2_SORL1',
#  'TMEM31_PSMC6',
#  'SSTR2_EIF2B5',
#  'PURG_AGMAT',
#  'SAAL1_GHITM',
#  'DYNLL2_KANK3',
#  'SMPD2_ALOX12B',
#  'ZCRB1_CBX2',
#  'DBN1_SH3BGRL2',
#  'C1QTNF1_COL12A1',
#  'AHSP_HBA1',
#  'DUSP14_EPB41L1',
#  'DDX28_RRM2B',
#  'TSSC4_PLK1',
#  'CACNG5_GRN',
#  'CLINT1_SDR9C7',
#  'CDKN2AIPNL_KPNA1',
#  'SPPL2B_NECTIN1',
#  'FBXW11_NUAK1',
#  'DNAJC25_ARAP3',
#  'ATP6V1G2_TCIRG1',
#  'RBMX2_NOL12',
#  'CNTFR_GHITM',
#  'CHRNA4_CISD2',
#  'RPS19_GLE1',
#  'SNRPE_CDC40',
#  'DIABLO_BIRC2',
#  'LPAR1_MSMO1',
#  'IMPDH1_KLHDC8B',
#  'MRFAP1_MORF4L2',
#  'VENTX_TST',
#  'EIF4E_EIF4ENIF1',
#  'NOTCH2_AURKA',
#  'TLE2_CCT2',
#  'NPPB_DUSP3',
#  'CERKL_LAGE3',
#  'RBBP7_ZNF827',
#  'PRG2_TCF25',
#  'TP53TG5_HAL',
#  'GAB2_YKT6',
#  'SLC7A1_RABL3',
#  'VENTX_FAF1',
#  'MEAF6_RBMX2',
#  'GPR17_ERAP1',
#  'STX18_SNAP47',
#  'ELAC2_UBAC1',
#  'VGLL4_GMPS',
#  'KLK2_MOCS3',
#  'SLC41A3_AMFR',
#  'TMEM9B_CLCN5',
#  'UBA5_OSGEP',
#  'DVL2_HECW2',
#  'EFNB2_DPH6',
#  'NAA10_SUPT5H',
#  'RPL19_YBX2',
#  'C1QTNF9B_BMP5',
#  'H1-1_WDR46',
#  'EVA1C_TENM3',
#  'VSIG1_ATP6AP2',
#  'ATP6V0A4_ATP6V1D',
#  'CRHBP_CCNB2',
#  'CAMKV_AGTPBP1',
#  'GPR17_NCAPD3',
#  'DNAJA2_SLC25A15',
#  'NUF2_ALDH3B1',
#  'PIP4K2A_RANBP10',
#  'CD68_COPS7B',
#  'KRBA1_LTBP4',
#  'FBXW11_HNRNPA2B1',
#  'CCNC_MED14',
#  'SEC23B_ACADVL',
#  'PEX7_FAF1',
#  'HSP90AB1_MGST3',
#  'CCT2_RPTOR',
#  'DDX28_SH3GLB1',
#  'ZYX_SECISBP2L',
#  'LGALS3BP_SHKBP1',
#  'PMPCA_CLUH',
#  'TRAK1_IFT140',
#  'COPS6_COPS5',
#  'CXCR4_NCAPD3',
#  'FBXL16_ACSL4',
#  'UXS1_NOP9',
#  'MRPS18B_MRPS2',
#  'LDLRAD1_PLXDC2',
#  'PCDH20_PCDHB2',
#  'TMEM9B_CLCN3',
#  'CD68_SACS',
#  'GNG2_GNB4',
#  'VSIG1_GALNT16',
#  'LIN28B_PINX1',
#  'LYPD1_UGGT2',
#  'BRK1_PPFIA1',
#  'KRR1_DCAF4',
#  'POLR2L_POLR3B',
#  'RAE1_PDCD6IP',
#  'INSL6_KLHDC2',
#  'KXD1_TRAF7',
#  'RPLP0_PHC2',
#  'TRIM10_ANKRD13A',
#  'MRPS23_ENO3',
#  'VSIG1_COG3',
#  'CREB3L2_WEE1',
#  'LY86_ALDH1L2',
#  'CHCHD4_TIMM10',
#  'SMARCE1_SMARCA2',
#  'SLC30A4_UNC45A',
#  'RPLP0_RRP8',
#  'NPM1_TEFM',
#  'MAPK14_DUSP16',
#  'TRIM10_WIZ',
#  'MRPL16_MRPL18',
#  'SMARCC2_BCL7C',
#  'CACNB3_ACBD3',
#  'SOST_DDHD1',
#  'CLGN_HEXA',
#  'LGALS3_LAMA1',
#  'CLGN_ADCY3',
#  'NIFK_ARGLU1',
#  'FAM98A_BTBD1',
#  'UQCC2_UQCC1',
#  'TMEM59_PTPRS',
#  'RBBP7_MBD2',
#  'LAIR2_P3H2',
#  'BRK1_BLOC1S4',
#  'TMEM98_EFNB1',
#  'MAD2L1_PPIP5K1',
#  'RYBP_RING1',
#  'CCR9_CLCC1',
#  'PSMD10_PSMC2',
#  'ZNF276_ARK2N',
#  'BNIP1_TOR1A',
#  'TOR1A_APBB2',
#  'TMED2_RPUSD4',
#  'EGFL7_SORL1',
#  'PPP4C_ISG15',
#  'GPR182_TBL2',
#  'GNLY_UTP4',
#  'KCNE3_MFAP3L',
#  'P2RY8_RUSF1',
#  'PYM1_ZKSCAN8',
#  'MCEE_FBXO21',
#  'FARSA_CEP97',
#  'ANKRD22_RNF213',
#  'SYNJ2BP_PRPSAP1',
#  'GSDME_PARP14',
#  'YWHAQ_MAPKAP1',
#  'SYT2_CENPB',
#  'TSPAN8_RBM22',
#  'EFNB2_TEX2',
#  'DDX28_NUDT9',
#  'KRR1_UHRF1',
#  'NCK2_WIPF2',
#  'MICB_SLC25A29',
#  'C1QTNF9B_ADAMTS12',
#  'LDLRAD1_LSR',
#  'YWHAB_WWC1',
#  'SLC2A12_FARSA',
#  'CAVIN1_CBX2',
#  'PRR3_ZC3H8',
#  'MAGEB2_CENATAC',
#  'AURKB_SAMHD1',
#  'CLGN_ANO6',
#  'C1QTNF9B_TIMP3',
#  'SAAL1_MYORG',
#  'APLF_HLTF',
#  'RPS10_UTP14A',
#  'DNAJB9_PC',
#  'CIAO2A_HDHD5',
#  'RUVBL1_ACTR6',
#  'COPS3_DCAF4',
#  'CDA_MTMR6',
#  'PEX7_NUP54',
#  'NHERF2_YAP1',
#  'KPNA2_TAF9',
#  'ZNF346_MTHFSD',
#  'POP4_RPP40',
#  'ZCCHC10_TAF4',
#  'KRBA1_RPTOR',
#  'KLK5_PCDHB11',
#  'EIF1AD_NAXD',
#  'YBX2_FBXO33',
#  'NDUFV2_NDUFAB1',
#  'ILVBL_RINT1',
#  'TUBG2_TUBG1',
#  'C1QTNF9_GBA1',
#  'ATP6AP2_TMEM199',
#  'CHRNA4_FAM20B',
#  'EPHA1_RIC1',
#  'TUBB_WDR81',
#  'GPR17_CIP2A',
#  'CETN1_MCM3AP',
#  'YAF2_DCAF1',
#  'LY86_CAMK4',
#  'NAA30_MICALL2',
#  'CD226_COQ5',
#  'ADCYAP1_STK3',
#  'CDK9_AIP',
#  'HHIPL1_FBXO21',
#  'RCCD1_KCTD12',
#  'FBXO6_QSOX1',
#  'RPS19_ERI1',
#  'KLK5_FRAS1',
#  'LARS2_UBTF',
#  'MMP2_COL4A2',
#  'VENTX_TMEM214',
#  'C1QTNF1_COL5A1',
#  'ANAPC16_ANAPC4',
#  'HPN_ASMTL',
#  'VSIG4_PIGW',
#  'FKBP2_TMEM131',
#  'CAMK2D_PUSL1',
#  'GSTT1_MNAT1',
#  'PRPF31_COIL',
#  'MYL12B_MYL9',
#  'VENTX_HS1BP3',
#  'SRPK2_PNN',
#  'SKP1_FBXL19',
#  'DDX28_NANS',
#  'FBXO7_PSMF1',
#  'TSR1_SREK1',
#  'ASB4_OGA',
#  'S1PR3_B4GAT1',
#  'FZD10_P3H4',
#  'HEATR3_DPY19L2',
#  'SLC30A2_CUX1',
#  'MRPL41_MRPL20',
#  'CDC26_BUB1B',
#  'YWHAB_CDK18',
#  'FPR1_PEX1',
#  'SSMEM1_VPS16',
#  'GDPD5_MXRA8',
#  'ELP2_GTF2E1',
#  'PATE1_BMP5',
#  'SIRPD_PCDHB11',
#  'CLGN_ENPP4',
#  'USP4_UBC',
#  'LGALS1_ITGA2',
#  'MRPL27_MRPL10',
#  'RAD23A_UBR5',
#  'TTC9C_DTX3L',
#  'APBA3_TJAP1',
#  'DYNLL2_AMOT',
#  'PRR3_RBMS1',
#  'TMEM9B_NF1',
#  'METTL9_SLC30A1',
#  'MRPL49_CRK',
#  'GPS1_IRF2BP2',
#  'CHID1_F13A1',
#  'RAE1_UBQLN2',
#  'GDPD5_TMPPE',
#  'ITM2C_PGM1',
#  'COQ3_NXT2',
#  'VSIG1_DYM',
#  'C1orf54_NXPE3',
#  'POLR2E_POLR2J',
#  'PCDHGB4_INTS11',
#  'C1QA_TIMM29',
#  'SRPK2_BAZ1B',
#  'YWHAB_SPIRE1',
#  'ECD_PTOV1',
#  'MRPL49_UBE2M',
#  'COPS2_FBXO11',
#  'BCL7A_SS18L1',
#  'FPR1_LRRN1',
#  'CCDC68_ST6GALNAC5',
#  'HSPB8_FAM83H',
#  'MBIP_SEPTIN3',
#  'SNIP1_RBM15',
#  'BCL2L2_CD79A',
#  'COL10A1_HAL',
#  'RNF10_YTHDC2',
#  'FBXO2_LGMN',
#  'CCDC22_PCM1',
#  'GRB2_PTPN1',
#  'LPAR1_ZDHHC5',
#  'VSIG1_FRY',
#  'CHRNB1_ATRN',
#  'CNTFR_CACNA2D1',
#  'OSBPL11_HADH',
#  'RFC5_RFC4',
#  'CERKL_PPM1A',
#  'SMPD2_TTC1',
#  'PACSIN1_TRPV4',
#  'MRPL34_RPL19',
#  'GPSM3_NDUFAF7',
#  'SMPD2_TPP2',
#  'FNTA_CENPF',
#  'ACP5_VGF',
#  'MRPL41_MRPL49',
#  'PCDHGA6_PCDHGB5',
#  'PDGFRB_EPHB4',
#  'ENTPD2_LGALS1',
#  'EEF1A2_TRMT10C',
#  'NOA1_MRPS27',
#  'IGSF8_TMX1',
#  'GRB2_PTPRA',
#  'RPN2_FAM241A',
#  'SSTR2_EIF2B3',
#  'HEATR3_POMGNT1',
#  'CTLA4_USP32',
#  'SOST_PMPCA',
#  'MED21_MED10',
#  'FTL_TBPL1',
#  'MAGEA8_CYBC1',
#  'MAGEB2_FIZ1',
#  'AHSP_ODR4',
#  'FAM9B_RPRD1A',
#  'CDK2_CDK17',
#  'TCIRG1_ATP6V1E2',
#  'DKKL1_FRAS1',
#  'PPP2R2D_MAST4',
#  'FBXW11_GPATCH8',
#  'OLFML2B_SIL1',
#  'DLG3_NEDD4L',
#  'COMTD1_CAMK1D',
#  'VIPR2_TMEM186',
#  'HDAC1_RB1',
#  'TOR3A_SLC38A10',
#  'RGS3_ZKSCAN8',
#  'ARL4C_POLE',
#  'CAVIN1_POLRMT',
#  'ARPC1B_ARPC2',
#  'RPL13_BAZ1B',
#  'LPAR1_TMEM223',
#  'FPR1_EXOC4',
#  'PCDHGB5_CYP51A1',
#  'NDUFA13_ND5',
#  'CAPZA2_PLEKHO1',
#  'LIN28B_PABPC5',
#  'SIGLECL1_IPO8',
#  'PATE1_GLG1',
#  'NAP1L5_NDEL1',
#  'VSIG1_FAM200C',
#  'CSNK1A1_CSNK1A1L',
#  'VSIG1_ISOC1',
#  'TYROBP_PMEPA1',
#  'HSPB8_ALMS1',
#  'SRPRB_SACM1L',
#  'KIAA1191_IST1',
#  'SIRT5_UNK',
#  'GDPD5_GPRC5A',
#  'B3GAT3_SAAL1',
#  'NME3_TRAPPC6B',
#  'ERF_GPS2',
#  'COPS3_APPBP2',
#  'HADHB_SGPL1',
#  'ACKR3_VPS51',
#  'HTR1E_WDFY3',
#  'CMA1_PASK',
#  'NUP43_KLC4',
#  'IL13RA2_CHEK1',
#  'S1PR3_SETX',
#  'APLNR_TMEM41B',
#  'RHOA_FHL1',
#  'PLEKHN1_ELP1',
#  'ILVBL_EPG5',
#  'MRPL12_THOC2',
#  'DLK1_LRRN1',
#  'ARHGAP19_FAXC',
#  'CCNI2_CCP110',
#  'BCL7A_SRCAP',
#  'CD68_UCK2',
#  'INSL6_GID8',
#  'MRPL10_MRPL21',
#  'GPM6A_APOA1',
#  'CSNK2A2_CCNL1',
#  'RNF166_STK4',
#  'GSDME_ALG5',
#  'IKZF1_ARMC8',
#  'HADHB_TMEM14C',
#  'B3GAT3_KIAA2013',
#  'DSN1_MIS12',
#  'SRPRB_CDH4',
#  'MORF4L2_UHRF1',
#  'USP46_DTYMK',
#  'DNAJC25_KNTC1',
#  'ELAVL2_ELAVL4',
#  'BBS1_PPP6R3',
#  'PATE1_IGF1R',
#  'RBBP4_MBD3',
#  'UCHL5_PSMC5',
#  'HEY1_HAL',
#  'EIF3F_EIF3M',
#  'AGO1_WDR33',
#  'TMEM87A_MICA',
#  'LDLRAD1_GPR39',
#  'C16orf87_MIER3',
#  'ADIPOQ_SHARPIN',
#  'SFN_RHEB',
#  'SDC1_DGAT1',
#  'RRP8_CDKN2AIP',
#  'DNASE1L1_NTM',
#  'KLHL15_CACNB1',
#  'AURKB_HEXA',
#  'MRPL49_DDAH1',
#  'EAF1_ELL2',
#  'VENTX_TPP2',
#  'ECD_ASPM',
#  'STBD1_GYG1',
#  'GYPA_SMG1',
#  'COPS3_COPS2',
#  'NPPB_NDUFS6',
#  'C1QC_STRN4',
#  'CHRNA3_SERPINB5',
#  'DDX28_FAHD2B',
#  'FAXC_GEMIN4',
#  'MRPS12_DCHS1',
#  'ESS2_FAM83H',
#  'FANCD2OS_SERPINB8',
#  'HS2ST1_CLCN3',
#  'MRPS34_MRPS2',
#  'THY1_CTSH',
#  'GDPD5_CDH2',
#  'MRPL10_MRPL4',
#  'MOAP1_PNMA2',
#  'PNN_VANGL1',
#  'LDLRAD1_LPCAT4',
#  'CD40_ELMO1',
#  'PIP4K2A_PIP5K1A',
#  'BCAM_LAMA5',
#  'C1orf54_SEMA3B',
#  'ASB9_ELOB',
#  'CLGN_PIGN',
#  'RNF166_LRRFIP2',
#  'C3orf18_EXOC8',
#  'IFT57_TRAF7',
#  'CIAO2A_DYNC2I2',
#  'EFNB2_NF1',
#  'SCCPDH_SAAL1',
#  'SCN2B_COG4',
#  'OASL_RBBP6',
#  'IMPDH1_WDR25',
#  'YWHAQ_KIF1B',
#  'YWHAB_STARD13',
#  'PIP4K2A_RAD18',
#  'PYCR3_RPL23',
#  'PDGFRB_PIK3CA',
#  'FAM187B_RNF185',
#  'FBXW11_YTHDC1',
#  'H2BC1_KAT5',
#  'SPC25_ZWINT',
#  'CLEC4A_PCDHB10',
#  'VSIG4_ALG2',
#  'MSRB2_CYRIB',
#  'RPS19_ZNF316',
#  'SOHLH1_KCTD8',
#  'COPS5_CUL2',
#  'RBBP4_PWWP2A',
#  'DPH6_NPTN',
#  'TBC1D9_TBC1D9B',
#  'GID8_UBE2H',
#  'LYAR_KIF1B',
#  'LIN7B_CASK',
#  'SCN3B_ABCC4',
#  'ARMC6_CLPX',
#  'ABT1_CENPB',
#  'EFNB1_EIF2B3',
#  'NOA1_MRPS17',
#  'CCDC120_ZMYND19',
#  'NCK1_WIPF2',
#  'GSDME_TMEM70',
#  'PCDHAC2_TAF6L',
#  'CCR9_SNX6',
#  'CACNG5_TRRAP',
#  'BTF3L4_TXLNA',
#  'RCCD1_CEP97',
#  'SYT1_GPC4',
#  'FBXO11_KLHL40',
#  'MAGEA8_POLD3',
#  'KLHL10_GET4',
#  'RBBP4_CHAF1A',
#  'CIB2_TSC2',
#  'UTP23_KRI1',
#  'GRAMD1B_CSNK2A3',
#  'SRPK2_YBX3',
#  'KCTD12_NUFIP2',
#  'FAM9B_SNRPA1',
#  'LGALS1_PLXND1',
#  'ZSCAN5A_DDX51',
#  'NCK2_GIT1',
#  'ENTREP3_WWP2',
#  'STARD3NL_ATP5F1B',
#  'MED4_MED25',
#  'RPP25L_PXDN',
#  'VENTX_THUMPD1',
#  'LYPD1_NCOA4',
#  'KLK2_TBRG4',
#  'HMGA1_BCAS2',
#  'DDX28_FAHD2A',
#  'LPAR1_POMK',
#  'PNMA2_INTS6',
#  'MEAF6_NEPRO',
#  'MAGEA10_NCOA2',
#  'DYNLL1_CDR2',
#  'MEAF6_SPATS2',
#  'ZNF704_ADAM10',
#  'SKAP1_THOC1',
#  'AGPAT3_ENDOD1',
#  'GAB2_PPAT',
#  'PPP3CC_PPP3R1',
#  'YWHAB_BRAF',
#  'MRPS34_MRPS18B',
#  'SPANXN3_ATP13A1',
#  'MRPS30_MRPL19',
#  'OLFM4_KLK14',
#  'POC1A_AKIP1',
#  'DYNLL1_PDZRN3',
#  'RBBP4_CHD5',
#  'TSSK1B_BTBD10',
#  'ARL8A_ARL8B',
#  'GZMH_DICER1',
#  'ZC3HC1_AKR1C1',
#  'GAB2_PSME2',
#  'DPYSL4_DPYSL2',
#  'CHCHD4_FAM136A',
#  'DNAJC30_NDUFS6',
#  'GAB2_PNP',
#  'ABT1_ZNF771',
#  'PPP1CC_TANC2',
#  'GAB2_TXNRD2',
#  'C1orf54_EXT1',
#  'IRF2BP1_KLHL12',
#  'YWHAB_UVRAG',
#  'CAVIN1_MACO1',
#  'TSC22D4_TTF2',
#  'SHISA3_PTGES2',
#  'SKP1_FBXO21',
#  'CHTOP_CCDC9B',
#  'CERS2_ARL10',
#  'SNRPF_GEMIN5',
#  'MRPL41_MRPL58',
#  'CLEC11A_LRRC15',
#  'RBMX2_RIOX2',
#  'SCN2B_PLAA',
#  'RSRP1_S100A16',
#  'DNAJC30_GALE',
#  'NMNAT2_RAB14',
#  'ZCCHC10_ZBTB1',
#  'RAMP3_HDHD5',
#  'FOSL2_GTPBP1',
#  'NIFK_ZNF768',
#  'LDLRAD1_SLC27A1',
#  'SAAL1_GOLM2',
#  'TMEM169_CCDC102A',
#  'SSTR2_SDC4',
#  'CHIA_PTGES2',
#  'SNX9_DNM1',
#  'MMP14_DTYMK',
#  'GAB2_UBQLN4',
#  'IFIT5_RBMS3',
#  'PHF20_KANSL3',
#  'HMGA1_NOL8',
#  'PPP3CC_PPP3CB',
#  'KIAA1191_KLC1',
#  'HSPB8_BRCA2',
#  'AZU1_CCDC25',
#  'USP46_GSR',
#  'ARFGAP1_FBXW5',
#  'FAM110B_KCTD8',
#  'GID8_ARMC8',
#  'IL2RG_GRPEL1',
#  'PPP2R2D_PABIR1',
#  'YWHAQ_TJP2',
#  'RPL13_ZCCHC7',
#  'LDLRAD1_MICAL2',
#  'EOLA1_NID1',
#  'RGS3_SEPTIN2',
#  ...}

# %%
gwps_s
# Out:
# {'CAD_TAF2',
#  'ZNF670_KRR1',
#  'TCEA1_PMPCA',
#  'PPP1R12A_CNOT9',
#  'KDM6A_MED19',
#  'RBM14_ERCC2',
#  'KIF5B_RPS27',
#  'ERP44_MED29',
#  'NUP155_GRPEL1',
#  'RPLP1_ESYT1',
#  'RPS19_HSPD1',
#  'SESN2_NELFE',
#  'MEF2C_WDR61',
#  'SNHG32_ZNRD1',
#  'MICOS10_CCT7',
#  'RPL35A_POP5',
#  'PRELID1_PPIH',
#  'IER3IP1_INTS7',
#  'CD53_UHRF1',
#  'SLC25A5_NUP54',
#  'ANKRD28_SETX',
#  'FBL_INTS2',
#  'GNL3L_GPS1',
#  'PRPF8_CCDC6',
#  'RPS23_DIS3',
#  'PRDX1_RUVBL1',
#  'CTAG2_PRKCA',
#  'ANKRD11_VARS',
#  'ZDHHC3_ADSL',
#  'TPR_TYK2',
#  'TMEM147_TBL3',
#  'RPLP0_DDX3X',
#  'ATXN7L3B_RIOK2',
#  'NORAD_GPS1',
#  'EEF2_GFER',
#  'UBE2H_DDX24',
#  'RPS6_TNIP1',
#  'PYURF_NUP133',
#  'CKS1B_TAF1C',
#  'C1orf35_RPL36',
#  'TIMMDC1_ADAL',
#  'EXPH5_PTPN1',
#  'PFDN5_NOP16',
#  'FAM49B_VPS29',
#  'POLR1D_PMPCB',
#  'C11orf58_MED22',
#  'MRPL51_TTC4',
#  'CNOT10_ITGB1BP1',
#  'SRP19_RRS1',
#  'MARCKSL1_DOHH',
#  'MFAP1_WDR76',
#  'RHOC_DNAJC19',
#  'SEC61G_POLR2B',
#  'F11R_ZDHHC7',
#  'TXNRD2_MAX',
#  'RPL32_UBE3D',
#  'TPM4_SMC1A',
#  'RPL10A_LUC7L3',
#  'FAM49B_MAX',
#  'ACAA1_RPTOR',
#  'HMGN2_INTS2',
#  'MTRNR2L8_PRMT1',
#  'AP2S1_EIF2B1',
#  'BTBD1_CAST',
#  'RNPEPL1_DNAJC19',
#  'RPL10_RBBP6',
#  'PTGES3_METAP2',
#  'CCDC58_CHMP6',
#  'COMT_PTPN11',
#  'SNRPE_HARS',
#  'SMIM7_ABCF1',
#  'GSTP1_CUL2',
#  'XRCC5_MRPL22',
#  'CCAR1_HSD17B12',
#  'ELP4_SUPT4H1',
#  'SH3BGRL3_ACTR6',
#  'ENO1_LSM5',
#  'MTDH_CPSF3',
#  'HP1BP3_TBP',
#  'RPL9_ATR',
#  'ANXA3_CSE1L',
#  'CHI3L2_DCAF7',
#  'SUMO2_SBNO1',
#  'DHCR7_TOMM22',
#  'SZRD1_SLC7A5',
#  'CISD3_MED11',
#  'H2AFV_GEMIN4',
#  'DCP1A_TOP1',
#  'CNBP_EIF3A',
#  'MRPS2_SMC1A',
#  'VIM_UMPS',
#  'XPO6_SUPT5H',
#  'SNHG4_SAMM50',
#  'S100A11_MRPS26',
#  'RPS16_CRLF3',
#  'MALAT1_TRRAP',
#  'TUBA1B_DONSON',
#  'PPA1_MED1',
#  'MRPL3_KANSL2',
#  'TESC_ELP2',
#  'CSNK1A1_SUPT20H',
#  'HIST1H2AH_HSD17B12',
#  'CBX3_CEBPZ',
#  'SETD5_MED7',
#  'CYBC1_MAX',
#  'SNHG29_CLASRP',
#  'SPCS2_FAM102B',
#  'MT-ND5_RPL15',
#  'ORC6_ATP1A1',
#  'GFM1_ZC3H13',
#  'UBE2G2_LTV1',
#  'QPRT_TPP2',
#  'ACTN4_METAP2',
#  'MGST1_WDTC1',
#  'MAPK1_TARS',
#  'MT-CO1_UTP20',
#  'RPS28_WNK1',
#  'GSPT1_EXOSC6',
#  'RAB11A_EIF2S1',
#  'RHOBTB3_UQCRB',
#  'USP1_CNOT3',
#  'PPP2CB_CSNK2B',
#  'AP3B1_RRP9',
#  'RHOBTB3_CYC1',
#  'UQCR11_EXOSC2',
#  'ANTKMT_PAF1',
#  'FAM53C_DHX15',
#  'BCL2L12_MRPL20',
#  'GCDH_INTS3',
#  'COX17_POLR2B',
#  'MBOAT7_RPAP2',
#  'TERF2IP_SNRPD1',
#  'ANAPC15_COPS8',
#  'SCLT1_CHMP6',
#  'SLC25A37_LSM10',
#  'HSP90B1_RPL23',
#  'TATDN1_IMP4',
#  'QPRT_SURF6',
#  'S100A11_TAF6',
#  'EBNA1BP2_LSM7',
#  'RPL36_POLR2H',
#  'EBPL_PAM16',
#  'TUSC2_UXT',
#  'VDAC2_SRP9',
#  'VAT1_ZNRD1',
#  'SRSF3_MAX',
#  'ATP5MC2_DNMT1',
#  'ACAT1_ELOB',
#  'ADIPOR1_GTF2H1',
#  'SND1_MRPS14',
#  'SLC25A21_SRP68',
#  'RPL37_MRPL23',
#  'MRPS18C_RPL23',
#  'SNRPD2_HBS1L',
#  'EIF5A_EIF2S1',
#  'RPLP0_RPL14',
#  'F12_DICER1',
#  'DIAPH1_CASP8AP2',
#  'TMED4_POGLUT3',
#  'LSM14A_POLR1A',
#  'BRI3BP_RTCB',
#  'RPL32_NOL11',
#  'PSME3_SRPRB',
#  'MIEN1_WDR12',
#  'SNF8_URB2',
#  'EIF4E_NARS',
#  'C9orf78_CMTR1',
#  'COL18A1_EIF2B1',
#  'COX7C_LRPPRC',
#  'PGRMC2_LSM6',
#  'AGO3_TAF1A',
#  'RCSD1_MED12',
#  'CBX5_RPS26',
#  'MRPL13_EIF3D',
#  'AL034397.3_GEMIN5',
#  'RPS8_STT3B',
#  'MRPL39_DDX20',
#  'CEBPZ_NBAS',
#  'LZIC_MED16',
#  'TBC1D23_FGFR1OP',
#  'IDH3G_SNRPD3',
#  'AC079801.1_EIF5A',
#  'PSMD14_MRPL27',
#  'NDUFC2_SART3',
#  'UQCRB_DONSON',
#  'NDC80_SUPT6H',
#  'AC139493.2_TMEM214',
#  'SUMO3_INTS3',
#  'RALBP1_ATP1A1',
#  'RPS7_MRPS16',
#  'MRPL13_HARS',
#  'PLPBP_TAF13',
#  'MAP1A_RAD21',
#  'AC016074.2_BAG6',
#  'RPL23A_MBIP',
#  'IDH3A_DHX15',
#  'NSD3_UTP23',
#  'THOC1_TARS',
#  'MKLN1_ESF1',
#  'RPL34_PTEN',
#  'HOXB9_MCM7',
#  'DDX23_PSMC1',
#  'RAB32_NUP62',
#  'ATP5IF1_U2SURP',
#  'RPLP1_POGLUT3',
#  'LEPROTL1_MED20',
#  'EIF3E_NBAS',
#  'MRPL51_SRSF1',
#  'ISCU_ZNHIT1',
#  'GATA2_NELFCD',
#  'AHCY_MYH9',
#  'TMSB4X_RPAP2',
#  'CTSH_NOP2',
#  'PAF1_CNOT1',
#  'DBF4_PUM2',
#  'RPL10_USP42',
#  'PDCD11_COPS4',
#  'ZNHIT3_TAF7',
#  'BRD2_YEATS4',
#  'TKT_MED14',
#  'SNHG16_NOL8',
#  'FUCA2_MTOR',
#  'RPL7L1_TSEN15',
#  'TMBIM6_RTRAF',
#  'PSMB6_MED1',
#  'GOLPH3_CMTR1',
#  'RBMX_WDR36',
#  'NDUFS5_LRIF1',
#  'RNASEK_GSK3B',
#  'RAB30-DT_SERINC3',
#  'GPRC5C_COPS6',
#  'ASF1A_DOHH',
#  'SH3GLB1_SUPT6H',
#  'MAP3K2_IMP4',
#  'MKRN2_NFRKB',
#  'MED24_CCDC6',
#  'FASN_VPS72',
#  'PPP1R12A_METAP2',
#  'OAZ1_CNBP',
#  'SEC31A_DERL2',
#  'CSTB_MRPS35',
#  'DYNC1LI1_WDR12',
#  'SURF1_MED8',
#  'TRIP6_RPS6',
#  'PSMD7_ZMAT5',
#  'UBAC1_CYREN',
#  'GMNN_PMPCA',
#  'UQCC1_TRMT112',
#  'DHX40_GTF2H1',
#  'MTX1_EIF2B5',
#  'COPB1_GPN3',
#  'MRPL24_CPSF3',
#  'CUL2_GRPEL1',
#  'PAFAH1B1_NKAPD1',
#  'USP22_LEO1',
#  'TUBB2B_TAF8',
#  'RNASEH2B_MED17',
#  'PPIP5K2_DONSON',
#  'TXNDC17_VPS72',
#  'ATP6V0E1_TTC4',
#  'SYAP1_MAX',
#  'EIF5A_RNF20',
#  'MT-ND3_MRPS10',
#  'XRCC5_BNIP1',
#  'CDC73_RCL1',
#  'NSD2_TOP1',
#  'ETNK1_GTF2H1',
#  'LINC00221_PHB',
#  'NME4_TOP1',
#  'R3HDM4_HSPA9',
#  'GYPB_WAC',
#  'PEF1_GNL2',
#  'SF3B1_EIF4E2',
#  'STAC3_SSRP1',
#  'GNAS_PSMD4',
#  'ZC3H18_RPUSD4',
#  'CIRBP_SSRP1',
#  'MAP2K2_DDX51',
#  'FAM120A_NACA',
#  'CCNI_PAM16',
#  'TKT_INTS2',
#  'ADI1_GTF2A1',
#  'C11orf58_TAF10',
#  'PPA1_ECD',
#  'CAPNS1_ATP1A1',
#  'TBK1_C1QBP',
#  'TIMM13_DBR1',
#  'HLTF_RPS11',
#  'CCAR1_CCAR1',
#  'MT-ND4_NAA15',
#  'RPL15_DR1',
#  'HIST1H4H_NEDD8',
#  'FKBP8_MED10',
#  'PPP2R5C_MED7',
#  'GABARAP_RPL19',
#  'POLR2E_MED12',
#  'COPS9_SFSWAP',
#  'TRIM38_PHB2',
#  'EXO1_CCNC',
#  'STX4_COPS6',
#  'UQCR10_NIFK',
#  'ADA_POLR1A',
#  'NCK1_MRPS33',
#  'EMC2_SUPT5H',
#  'CD63_ILF3',
#  'ZNHIT1_LAMB1',
#  'PDE4DIP_ZMAT2',
#  'TBCA_SLC7A5',
#  'WDR61_TIMM23B',
#  'SNHG6_ALG2',
#  'RPS2_MTREX',
#  'HSD17B10_PDCD11',
#  'RPS6_HHEX',
#  'JUP_BNIP1',
#  'B4GALT3_RBM33',
#  'NEFH_DDX55',
#  'CSTF1_OXA1L',
#  'FAM89A_BTF3',
#  'MAP3K7_MED10',
#  'YRDC_COPS8',
#  'MDN1_MRPL38',
#  'CCAR1_FUNDC2',
#  'UBE2I_MRPL51',
#  'TST_EIF2B4',
#  'RPL37_MED13',
#  'RPS3A_LAMB1',
#  'LSG1_MAX',
#  'MT-CYB_EXOSC8',
#  'MRPS15_MRPL37',
#  'RNF7_FBL',
#  'RPL19_ABT1',
#  'THRAP3_PSMD13',
#  'TMEM219_DOHH',
#  'STAC3_POLR2B',
#  'GYPC_BRIX1',
#  'DTD1_TNPO3',
#  'PSMB6_NFRKB',
#  'ERGIC2_GATA1',
#  'SMIM7_ZMAT2',
#  'GSR_DEPDC5',
#  'PYCARD_PABPC4',
#  'WRNIP1_TIMM44',
#  'EIF5_MRPL16',
#  'HSPA8_PTPN1',
#  'CIAO2B_NCBP1',
#  'MRPL18_GTF2H1',
#  'ITPRID2_EP400',
#  'PTPN11_DBR1',
#  'CCNB1_SRRM1',
#  'NDUFA2_MDN1',
#  'EZR_AAR2',
#  'COX7C_EIF4G2',
#  'TSPAN3_SUPT5H',
#  'COX7A2L_GAB2',
#  'BCLAF1_TIMM9',
#  'LPGAT1_KRR1',
#  'TMEM33_DHX15',
#  'BAG1_MRPS25',
#  'PPM1F_MED6',
#  'UBXN4_WDR75',
#  'ENSA_RPAP2',
#  'BOP1_U2AF2',
#  'PITX1_RBBP6',
#  'PSMA6_SRPRB',
#  'AK1_PRIM2',
#  'LSM12_RRS1',
#  'TMX2_MED12',
#  'SET_IMP4',
#  'RAN_MRPS17',
#  'PIGT_STAG2',
#  'TXN2_WDR82',
#  'SRP9_RPL3',
#  'MKI67_NAA15',
#  'SLU7_CSTF3',
#  'USO1_GBF1',
#  'MAGOH_HEATR1',
#  'PRAME_NUDT21',
#  'R3HCC1_MED12',
#  'ERI3_CHAF1B',
#  'HMGB3_CSNK2B',
#  'PYCR1_SLC25A10',
#  'SRSF10_PSMD7',
#  'AIMP2_GPN3',
#  'ABCF1_CWF19L2',
#  'NCKAP1L_EEF1G',
#  'CAPZA1_DDX6',
#  'RPS15_KLHL17',
#  'ALG5_MED22',
#  'TNPO2_TAF1',
#  'PNISR_DDX52',
#  'OBI1_KDM1A',
#  'SRRM1_RPTOR',
#  'NLN_MED6',
#  'SRD5A3_MED22',
#  'VARS_NAE1',
#  'RAC2_CNOT9',
#  'VDAC3_CASP8AP2',
#  'TMEM101_NSUN4',
#  'ATP5PF_MRPS2',
#  'MTMR14_PCM1',
#  'AIFM1_INO80',
#  'MPZL1_LSM10',
#  'CCT3_HMGB3',
#  'DNAJC2_MED19',
#  'GTSF1_TAF6',
#  'MPP6_TAF1',
#  'HP1BP3_UTP15',
#  'WASF2_PPP2CB',
#  'ECI1_GEMIN4',
#  'COPA_ERCC2',
#  'TBX1_SMC1A',
#  'THYN1_EIF2B3',
#  'CYC1_TFPT',
#  'DHFR_ZNHIT6',
#  'RPL11_NACA',
#  'XRCC1_TTF1',
#  'SURF4_TMED10',
#  'IRF3_DICER1',
#  'SPATS2_PRDM4',
#  'DBI_ESYT2',
#  'VAT1_ARID1A',
#  'DNAJC2_GINS1',
#  'RPLP0_URM1',
#  'IRAK1_C1QBP',
#  'HBD_RPL19',
#  'BOLA3_NBAS',
#  'CKLF_SFPQ',
#  'MSI2_DNAJC19',
#  'EZH2_PSMD7',
#  'ACTL6A_DARS',
#  'HSD17B4_NACA',
#  'CALU_PMPCB',
#  'TSC22D1_MRPL23',
#  'USP15_GNL2',
#  'UGGT1_MED22',
#  'RPL39_UTP20',
#  'SFXN1_EXOSC10',
#  'PSMA6_GALNT6',
#  'CLCA1_SART1',
#  'MT-CO2_PTPN2',
#  'PNISR_SLC39A9',
#  'GTF2F2_RPS11',
#  'SMAGP_MCM10',
#  'GTPBP3_CMTR1',
#  'STAR_NOL11',
#  'DNPH1_PHF5A',
#  'ATP1B3_MED28',
#  'GOLGB1_CCDC86',
#  'MRPS15_FBRSL1',
#  'RPS24_RPL10',
#  'KDM1A_RPL7',
#  'RPL38_MCRIP1',
#  'TIMM17A_METTL3',
#  'LCP1_LETM1',
#  'PDIA6_SEC63',
#  'PNPT1_DGCR8',
#  'GAPDH_RBM17',
#  'MRPL45_TSC1',
#  'ELP6_UXT',
#  'HSPE1_USP22',
#  'YTHDC1_LSM6',
#  'DGKZ_SUPT5H',
#  'SKA2_DDX56',
#  'PHB2_ATP6AP1',
#  'TIMM50_DHX15',
#  'CRELD2_TARDBP',
#  'MAZ_ZNRD1',
#  'FABP5_DDX56',
#  'RANBP1_ILF2',
#  'RANBP1_EXOSC3',
#  'PPP2R1A_MED30',
#  'DENR_SIRT7',
#  'PGD_RNF31',
#  'MYLIP_GNL2',
#  'OPA3_AAR2',
#  'ATP5PO_RPS4X',
#  'TFAM_ATR',
#  'SUCLG1_BCKDHA',
#  'RPS23_IMP4',
#  'GABPB1-AS1_GOLT1B',
#  'NMRAL1_BANP',
#  'ATXN10_DDX18',
#  'EDF1_EDF1',
#  'CTAG2_TFAP4',
#  'UBE2L3_COX7B',
#  'SPTSSA_SLC25A10',
#  'FARS2_VPS72',
#  'GDI2_EP300',
#  'ELOB_SUPT4H1',
#  'PSMC5_DDX21',
#  'ETV4_POP1',
#  'SH3BGRL3_KIF20A',
#  'MT1X_TAF3',
#  'SERP1_INTS2',
#  'AP1S1_SLC35A4',
#  'PNMT_HMX3',
#  'RPS10_PTPN1',
#  'ETFB_RIOK2',
#  'IER3_MBTPS1',
#  'POP5_GFM1',
#  'NT5C3A_DICER1',
#  'PCK2_ZNF706',
#  'POU2F1_KDM1A',
#  'GDE1_MED10',
#  'TMSB4X_SNAPC3',
#  'GTF2I_NAE1',
#  'TAOK1_TEFM',
#  'RPS21_MED22',
#  'CDKN3_MON1A',
#  'PHB_RBM25',
#  'TOMM20_TAF12',
#  'SNHG3_VPS28',
#  'DBI_ATP11B',
#  'CENPB_HBS1L',
#  'SNHG29_NOLC1',
#  'RPL17_TFB1M',
#  'ELOVL5_CSTF3',
#  'MED25_SRP72',
#  'PFDN5_ZRANB2',
#  'MAEA_EIF2B4',
#  'RPL32_ATP1A1',
#  'MCFD2_AARS',
#  'RSF1_NLE1',
#  'VPS13C_TRA2B',
#  'MT-ND1_RPS24',
#  'FSCN1_TRMT112',
#  'PSMD9_SUPT6H',
#  'MPC2_ABCB7',
#  'SMS_CD99',
#  'CDC25A_CAST',
#  'MRPL36_IARS2',
#  'TMUB1_SMC1A',
#  'CD46_VPS29',
#  'B2M_SAFB',
#  'RPL9_STXBP4',
#  'SUPT16H_NDUFV2',
#  'NOP16_BCR',
#  'WDR43_EIF2B3',
#  'OBSL1_ARGLU1',
#  'AKR7A2_NUDCD3',
#  'POLR2F_EIF2B1',
#  'TMEM97_SACM1L',
#  'AIMP1_EEF1G',
#  'CAP1_INTS8',
#  'GNPAT_ADAM10',
#  'RPSA_PRMT1',
#  'LMNB1_TUBB2A',
#  'METRNL_C1orf131',
#  'SRSF4_SRP9',
#  'NEFH_LSM12',
#  'HSP90AA1_IER3IP1',
#  'GCC2_SAE1',
#  'VARS_EXOSC6',
#  'UPF3B_KRR1',
#  'PCYOX1_SFSWAP',
#  'CHD9_RAD51',
#  'RPL15_STARD7',
#  'CYP51A1_MRPL4',
#  'SNX4_DDX5',
#  'NUCB2_TARS',
#  'ZNF512_RIOK1',
#  'BCL2L12_MRPS23',
#  'AGPAT2_UPF1',
#  'MRPL12_METAP2',
#  'DDX1_CIAPIN1',
#  'ATAD2_RARS',
#  'SLC39A1_CASP8AP2',
#  'RPL7A_UXT',
#  'FAM27C_MED12',
#  'MRPS26_C7orf26',
#  'ARID1A_UXT',
#  'TMEM14B_ABT1',
#  'TM9SF3_PSMD4',
#  'BBS4_SMC1A',
#  'YEATS4_MED19',
#  'GALC_ISCA2',
#  'SLC25A6_NDUFA3',
#  'C11orf1_SLC25A10',
#  'GABPB1-AS1_ZFR',
#  'AKR7A2_EXOSC8',
#  'PSMA2_HEATR1',
#  'TP53BP2_EP400',
#  'PPIE_TRMT112',
#  'LYPLA2_TAF1',
#  'RPS18_GFER',
#  'COQ5_RPL31',
#  'NME4_BUB3',
#  'ZNF706_ZNF622',
#  'GARS_NELFE',
#  'MTG2_WDR82',
#  'RRP1B_MED19',
#  'ABHD14B_GTF2E1',
#  'RPS24_TAF11',
#  'NSUN5_POLR2B',
#  'TCHP_MAX',
#  'DNMT3A_CWF19L2',
#  'AGL_QARS',
#  'UHRF1_RPAP3',
#  'EMC1_PHB',
#  'RPS7_INO80B',
#  'MZT2B_MAP2K7',
#  'CIRBP_EIF2B4',
#  'MT-CO2_CDIPT',
#  'VDAC1_FLVCR1',
#  'CHML_NAA25',
#  'SNHG12_NELFE',
#  'RANBP1_COX10',
#  'RPL10_DKC1',
#  'ENO1_ERAL1',
#  'DIAPH1_NFRKB',
#  'RPS24_KEAP1',
#  'HSP90AA1_RNF40',
#  'ACTB_PPP1R11',
#  'CDK4_FBRSL1',
#  'SURF6_TOMM22',
#  'PPCS_EMG1',
#  'ZNF770_CSNK2B',
#  'SRCAP_DHX15',
#  'SNRPA1_RPL36',
#  'SLC4A1AP_INO80',
#  'SNRNP25_SNRNP25',
#  'ZNF330_EEF1G',
#  'MCCC2_ZDHHC7',
#  'CNOT1_KRR1',
#  'MICOS13_RAE1',
#  'GYPB_DDX55',
#  'CAPG_EEFSEC',
#  'COX4I1_PPARGC1B',
#  'JTB_SLC39A9',
#  'PSMA7_ISCA2',
#  'GNL3_WDR36',
#  'VKORC1L1_PRPF40A',
#  'NOL11_GFER',
#  'NSRP1_MTOR',
#  'MED13L_PPA1',
#  'RPL36_ASB6',
#  'RHOG_KANSL3',
#  'METTL2B_NEDD8',
#  'POLD2_FAM136A',
#  'AC139493.2_RACK1',
#  'RPS19_NRBP1',
#  'GYPE_POLR1B',
#  'TMEM38B_TMEM38B',
#  'H2AFZ_FLII',
#  'NDUFB10_ZNF695',
#  'ECI1_DHX15',
#  'MSH2_GATA1',
#  'RBBP5_HPS5',
#  'CYCS_EXOC1',
#  'SNAP29_ARGLU1',
#  'SARS2_NRDE2',
#  'FANCI_KANSL2',
#  'DGUOK_ZBTB44',
#  'MTRNR2L8_RPL3',
#  'RPL23_PDLIM7',
#  'CCNA2_NELFE',
#  'LTV1_WDR5',
#  'NSD2_OXA1L',
#  'SLC25A21_LUC7L3',
#  'BCOR_CXXC1',
#  'ANAPC4_UBAP1',
#  'MRPL20_UQCRB',
#  'IMP3_WDR82',
#  'RPLP2_POLR1D',
#  'UROD_INTS3',
#  'WDR82_TTI1',
#  'TPGS1_PIK3CA',
#  'MRPL15_MRPL18',
#  'IFRD1_GNL3L',
#  'THAP4_RPS4X',
#  'KIN_SPC25',
#  'F12_CPSF6',
#  'POLR2B_TARS',
#  'ZNF429_SRP68',
#  'DPY30_GTF2H1',
#  'CCT3_MCM3',
#  'NIPSNAP1_MYB',
#  'GABARAPL2_RPS14',
#  'NDUFAF2_DDX51',
#  'GMFG_MAU2',
#  'UPF3B_DKC1',
#  'SLC10A4_EP400',
#  'RPL36_MED20',
#  'MECP2_SPINDOC',
#  'SLC39A3_COPS3',
#  'EIF2B1_PNO1',
#  'BOD1L1_GEMIN5',
#  'FUBP1_WDR12',
#  'SDR39U1_SDR39U1',
#  'PFDN1_WDR82',
#  'MLH1_GATA1',
#  'MAP1B_EIF5',
#  'ETHE1_RBBP5',
#  'MCM10_SSRP1',
#  'EPB41L4A-AS1_TTC4',
#  'PRRC2B_DICER1',
#  'SOCS1_EML3',
#  'TPT1_AHCY',
#  'DDIT3_RPS26',
#  'RPL38_DICER1',
#  'ADAMTSL4_DDX51',
#  'METTL5_RPS19BP1',
#  'MFGE8_MCM3',
#  'CCDC167_ZNF143',
#  'SRSF11_SRP72',
#  'MRPS6_EIF2B4',
#  'TMEM209_TAF1D',
#  'PCCB_INTS5',
#  'IDH2_NELFCD',
#  'MRPL38_NCBP2',
#  'CDC16_NUMA1',
#  'CIRBP_TP53RK',
#  'NOLC1_ADSL',
#  'RNF2_TMX2',
#  'USP20_MED17',
#  'CDKN2C_SMC1A',
#  'ING3_NELFCD',
#  'LUC7L2_RNF40',
#  'CNOT7_SSRP1',
#  'DECR1_STAT5B',
#  'PPIC_SSBP1',
#  'HEBP2_YEATS4',
#  'ANXA7_EIF2B3',
#  'NELFE_TAF2',
#  'RPLP0_YEATS4',
#  'RPL24_THEMIS2',
#  'POLK_MED19',
#  'FURIN_GPS2',
#  'SLC25A33_KDM1A',
#  'TBPL1_KDM1A',
#  'CSTB_SLBP',
#  'MT-CO1_PBX2',
#  'RPL7A_YAE1',
#  'TMEM123_BRD8',
#  'TFRC_RPL31',
#  'STX10_SUPT6H',
#  'NDUFC2_ITGB1BP1',
#  'HSPA8_MRPL10',
#  'CLPX_MAX',
#  'HAT1_STT3B',
#  'MRPL41_C1orf131',
#  'SRSF5_BCAS2',
#  'TMEM59_GRPEL1',
#  'TMEM245_QARS',
#  'NLN_SUPT6H',
#  'DDX27_GAB2',
#  'NUDT16L1_GPN3',
#  'OGT_TARS',
#  'NDUFA10_NCBP2',
#  'SLC29A1_MED20',
#  'TAF1D_CWC15',
#  'PITPNA_SUPT6H',
#  'ODC1_POP7',
#  'BNIP3_SMARCC1',
#  'FUBP1_NRDE2',
#  'SNHG1_IPO13',
#  'MRPL55_DDX51',
#  'SNHG29_EIF2B2',
#  'RAC3_ACTR6',
#  'FAM89A_GPN3',
#  'LBR_BUB3',
#  'EIF4EBP1_GTF3C6',
#  'CENPX_VPS29',
#  'EIF4G3_GTF2A1',
#  'TBX19_COX15',
#  'ATOX1_MRPS26',
#  'ZNF431_NELFB',
#  'IDI1_SRRT',
#  'CELF2_ABCE1',
#  'RPL23A_RPL10A',
#  'EIF3A_MRPL38',
#  'HDGFL3_NAE1',
#  'EEF1A1_MTF1',
#  'TMEM99_PHB',
#  'TECR_DHODH',
#  'FAM136A_SP1',
#  'RANBP1_SEC22B',
#  'LARP7_RPLP2',
#  'ALYREF_RPL3',
#  'AZI2_EIF2B4',
#  'CD63_WDR75',
#  'REX1BD_MED7',
#  'GTF2H1_PAF1',
#  'DBI_CMTR1',
#  'ACAT2_NUDCD3',
#  'SKP2_HARS',
#  'NABP1_INTS7',
#  'HK1_CDIPT',
#  'EIF5B_WDR82',
#  'BID_DNAJC19',
#  'STOML2_EIF3G',
#  'NGRN_SSBP1',
#  'ERP44_RTCB',
#  'CYBA_DOHH',
#  'FAM20B_OXA1L',
#  'DDX39B_EXOSC3',
#  'DDX27_FUNDC2',
#  'TUBA1B_UPF2',
#  'DCAF7_SUGT1',
#  'WDR46_DNAJC19',
#  'PDLIM1_OXA1L',
#  'ACP1_CHORDC1',
#  'CCDC59_FCF1',
#  'EPB41L4A-AS1_POP5',
#  'ERP29_DMAP1',
#  'GLCE_PTPN1',
#  'ANP32B_ACTR8',
#  'PCGF6_RIOK1',
#  'RPP30_DNAJA3',
#  'SRPK1_DNAJC17',
#  'IREB2_PRELID3B',
#  'TTC1_DHX15',
#  'GNB1_LMO2',
#  'HIGD1A_CDK9',
#  'AGPAT2_MED19',
#  'SELENOP_TRRAP',
#  'EIF1AX_GPS1',
#  'QPRT_TAF2',
#  'ISCU_TAF10',
#  'XACT_HARS',
#  'SNAP29_TBC1D1',
#  'PDCD4_WDR3',
#  'RPS26_MRPL24',
#  'PNPLA4_NAF1',
#  'MAFG_DHX15',
#  'RPS17_GTF3C3',
#  'CRKL_EXOSC2',
#  'REXO4_RNGTT',
#  'ZNF480_COX15',
#  'MRPL3_POLR2M',
#  'PGLS_GNL3L',
#  'NDUFB7_SRRT',
#  'NFE2_KDM1A',
#  'SELENOF_TBRG4',
#  'AIF1_PPA1',
#  'TMED9_RPAP3',
#  'ARID3A_POGLUT3',
#  'CCDC59_POLR2B',
#  'ACY1_ERCC2',
#  'NDUFS6_RRS1',
#  'HSBP1_MED1',
#  'FRG1_EIF6',
#  'AP2M1_EXOSC6',
#  'RPL36_POLR2B',
#  'BOP1_TOMM22',
#  'SELENOK_EIF5A',
#  'MRPL52_DHX36',
#  'MAP4K4_RPS19BP1',
#  'NUDT4_POGLUT3',
#  'TMEM223_NARS',
#  'SPTLC2_MAX',
#  'TTC17_RPL26',
#  'RPS19_GPATCH1',
#  'REST_DGCR8',
#  'TRAPPC2L_PGAM1',
#  'HNRNPAB_MRPS22',
#  'UBE2T_DYNLL2',
#  'USP7_EXOSC4',
#  'UFL1_SRP9',
#  'ITM2B_MED30',
#  'VAPA_WDR55',
#  'PGRMC1_SACS',
#  'XRCC2_ZMAT5',
#  'RPL13_THOC6',
#  'RALB_TTC27',
#  'HMGB1_SLC7A5',
#  'SRM_TAF8',
#  'PPIC_TOP1',
#  'BAG1_EXOSC4',
#  'MT-ATP8_RPAP3',
#  'FABP5_TAF1',
#  'BRIX1_EEF1G',
#  'ZC3H8_RPS13',
#  'PHGDH_ZNHIT3',
#  'MT-CYB_DAP3',
#  'LAMTOR1_EIF2S1',
#  'QPRT_FARSA',
#  'DENND2D_ATP11B',
#  'GMPR2_TAF2',
#  'AC012146.1_CIAPIN1',
#  'RPL22L1_GPS1',
#  'TFB2M_GEMIN5',
#  'DDX50_CFDP1',
#  'ZBTB7A_TPR',
#  'NUP88_FUNDC2',
#  'RPL22L1_DNMT1',
#  'SNRPC_C12orf45',
#  'BLVRB_GART',
#  'MDK_STARD7',
#  'AC016074.2_MED13',
#  'OS9_SPCS3',
#  'RPL12_TAF2',
#  'EIF4ENIF1_DHDDS',
#  'GNPDA1_RARS',
#  'TACO1_RPS13',
#  'POLR3H_SNRPD1',
#  'OSBPL8_ZBTB17',
#  'BICD1_ZC3H3',
#  'UQCRB_MAU2',
#  'GARS_NOC3L',
#  'C9orf16_BTAF1',
#  'RSL24D1_MRPS33',
#  'PJA2_TARS',
#  'GCAT_ROMO1',
#  'EIF5_RPL7L1',
#  'DNTTIP2_PARP1',
#  'ELAC2_GMPS',
#  'GTF3C2_HBS1L',
#  'MFF_WDR82',
#  'UFM1_QARS',
#  'GPN3_TAF2',
#  'MIR17HG_IARS2',
#  'GAL_OXA1L',
#  'RPL23A_SNRPD3',
#  'CCNH_RPL29',
#  'YRDC_REST',
#  'RPLP2_RCCD1',
#  'HSP90AB1_ADSL',
#  'TMSB4X_NCBP2',
#  'PPP1R18_EIF2B4',
#  'NME4_RNMT',
#  'BOP1_NUDCD3',
#  'NDUFA8_MYBBP1A',
#  'TMEM14A_TOMM22',
#  'MTHFD2_MED30',
#  'MCM3_DHX15',
#  'TPD52L2_GPN3',
#  'MT-CYB_TXNDC17',
#  'GTF3A_INTS4',
#  'FOXK2_NUDT15',
#  'PCK2_NEDD8',
#  'ABHD14B_LSM6',
#  'SLC1A5_RPL31',
#  'HEMGN_UBAP1',
#  'FTL_UPF1',
#  'BTG2_PMF1',
#  'SELENOW_WDHD1',
#  'RPL4_EXOSC3',
#  'TOP1MT_PMPCA',
#  'SUCLG1_DEPDC5',
#  'WDR34_CLTC',
#  'SRSF7_AP2S1',
#  'FDX1_ATP1A1',
#  'PHB_MRPL18',
#  'CCNI_GTF3C2',
#  'TBK1_SFPQ',
#  'FAM217B_PHB',
#  'DDX21_POLR1B',
#  'COL18A1_ASCC3',
#  'MTHFD2_PSMD7',
#  'PHB_GPN3',
#  'SERPINF1_METTL21A',
#  'NAA10_GEMIN5',
#  'CDK2AP1_MED11',
#  'CKB_KDM1A',
#  'DYNC1LI1_MRPL10',
#  'NBN_STXBP4',
#  'RNASEH2C_ERCC2',
#  'COPS2_QARS',
#  'VPS29_ELP5',
#  'RPP25_RPL36',
#  'CEBPB_TAF8',
#  'SCD_PRMT1',
#  'HADH_CWF19L2',
#  'RPS5_RNF40',
#  'RFESD_WDR82',
#  'HNRNPM_C1QBP',
#  'DUS3L_TNPO3',
#  'PPIG_LTV1',
#  'AIDA_MED21',
#  'GALK1_ATP1A1',
#  'ARFRP1_RPL23',
#  'USP1_NCBP2',
#  'RPS27_MNT',
#  'AMZ2_VPS29',
#  'MTRNR2L8_GINS2',
#  'SNHG29_KAT7',
#  'EIF2S3_C12orf45',
#  'TYW3_EIF2B1',
#  'MRPL1_ZCCHC9',
#  'STIP1_ATP11B',
#  'RPL21_CNOT4',
#  'SAE1_DHX15',
#  'NOP53_KRR1',
#  'ABHD3_KIF20A',
#  'PRAME_CRIPT',
#  'MFSD1_ZCRB1',
#  'CDC6_RAD21',
#  'ZNF595_PHB',
#  'MED10_WDR46',
#  'TM2D1_SRRT',
#  'TRIP6_METAP2',
#  'GRN_TMX2',
#  'CASP3_NAA20',
#  'SHARPIN_TFAP4',
#  'COA6_RPS19',
#  'MT-ND2_POGK',
#  'GOLPH3_CSNK2B',
#  'B3GALNT2_DNAJC19',
#  'SNRNP40_ATRIP',
#  ...}

# %%
humaninter_s
# Out:
# {'RB1CC1_MARCHF2',
#  'SLC7A13_B3GALT1',
#  'PDHA1_PDHB',
#  'ALG10B_TMEM69',
#  'CD2BP2_STK40',
#  'IGHV2-70_IGKV1-13',
#  'UNC5C_TMEM138',
#  'HNRNPA0_ZNF580',
#  'EPHA4_FRZB',
#  'REXO1L1P_ANKRD52',
#  'GNMT_DOHH',
#  'CCNA1_CWC27',
#  'OR4A8_PCDHGC4',
#  'RP2_RUSF1',
#  'KNOP1_POLDIP3',
#  'MCU_MYO5C',
#  'GOLGA2_PTK7',
#  'YWHAB_KCNK4',
#  'IGLV3-25_IGHV3-53',
#  'SNRPGP15_CUL4A',
#  'TLR2_DOHH',
#  'BHLHA15_ASCL3',
#  'OR2A42_HACD3',
#  'DEF8_LRIG1',
#  'TAF11L2_CDK9',
#  'WDR77_SCML2',
#  'CIAO1_TWF2',
#  'RABGGTB_GMFB',
#  'AKR7A3_CCT5',
#  'SSU72L5_STK17B',
#  'LRG1_RCN1',
#  'PARD6G_EIF2B3',
#  'SUPV3L1_DPH7',
#  'FNIP1_SLC38A7',
#  'RPL3_DDX25',
#  'MYO1B_PPIL3',
#  'SDCBP2_NOC2L',
#  'PRP4K_ANGEL2',
#  'DTYMK_ADRA1B',
#  'TMEM198_LRTM2',
#  'BPGM_RPH3A',
#  'STK11_PRMT6',
#  'CFHR3_FCN2',
#  'COX10_TMEM201',
#  'DGKE_SVIP',
#  'CXorf66_TMEM123',
#  'CLUAP1_CEP19',
#  'SMN1; SMN2_ISG20',
#  'SAMD5_ELMOD2',
#  'RNF4_NGB',
#  'OR51D1_OR1L6',
#  'MT-CO2_ANKIB1',
#  'PHYHD1_TMEM186',
#  'MORN5_ADGRE2',
#  'KDM1A_SCRT1',
#  'TTC36_TPST2',
#  'MIXL1_RBM8A',
#  'EVPLL_DPEP2',
#  'TM7SF2_AADAC',
#  'SP5_FBXL4',
#  'AQP8_OR4N2',
#  'SNAPIN_LRRC15',
#  'HIGD1A_TMED3',
#  'REG1B_LPAL2',
#  'LRRC32_TSPY26P',
#  'CDIPT_DNAJC4',
#  'ZNHIT2_TEX264',
#  'CANT1_PLSCR2',
#  'MRPL54_IMMP1L',
#  'ERI2_ASB13',
#  'RPA2_H2BC14',
#  'HCLS1_USP8',
#  'PPP2R5A_IWS1',
#  'LRRC26_OR5D16',
#  'ATAD5_GDAP2',
#  'TNNC1_JOSD1',
#  'INS-IGF2_OR1J1',
#  'SLC16A14_OR2M2',
#  'FBXO48_ETFRF1',
#  'SLC66A2_PIGM',
#  'TLR4_BSG',
#  'UGP2_RBM38',
#  'VHL_HSPB8',
#  'MYLK4_DTWD1',
#  'CTDSP2_HTATSF1',
#  'TRIM24_FAM117B',
#  'OGFOD1_CABLES2',
#  'RBFA_MRPL44',
#  'RAC3_CETN1',
#  'NDUFAF6_KIAA0319L',
#  'NUAK1_FKBP9P1',
#  'OR2T3_OR4Q3',
#  'FARP2_TECPR1',
#  'STK16_PARPBP',
#  'COG2_NEPRO',
#  'PDCL2_MLH3',
#  'CEBPD_RBM11',
#  'CLIC1_HAGH',
#  'P2RY6_COQ10B',
#  'BIRC5_BNIP2',
#  'NEUROD6_NEUROG2',
#  'LRRC74B_MCAT',
#  'LYRM1_CYB5RL',
#  'KRT19_C5orf22',
#  'YAF2_INO80B',
#  'TPO_TSPAN18',
#  'SREBF1_ICA1L',
#  'PDCD2_FAM117B',
#  'ITGB2_COL5A1',
#  'EGFR_PARVA',
#  'LANCL1_INPP5B',
#  'CTNND1_INSR',
#  'CDC40_KIF4B',
#  'PYCR1_ENDOG',
#  'GIT2_KAT2B',
#  'LSM3_PDCD6IP',
#  'OMG_ASB7',
#  'RPL37_MRPL23',
#  'SEMA5B_ZDHHC8',
#  'RHOA_TMEM115',
#  'OASL_GIMAP4',
#  'UCN_TLR9',
#  'BMS1_SLC4A1AP',
#  'IGHV1-46_IGHV1-38-4',
#  'ASAP2_DOK1',
#  'CRKL_SNAPC3',
#  'RAC3_GRTP1',
#  'FHL3_TAF15',
#  'VAV1_TLCD3B',
#  'NOL8_NDUFA13',
#  'TTI2_WDR36',
#  'CRTAP_MYO1A',
#  'LRRC30_NHERF2',
#  'DNAJC3_PDIA6',
#  'LRG1_CASP4',
#  'NDUFA2_RABGGTB',
#  'TGM2_TGM3',
#  'TIMM17B_C7orf50',
#  'MRC1_ADIPOR1',
#  'SPMAP1_ZNF735',
#  'PSMA7_SNRPA1',
#  'TCP11X2_DNAI3',
#  'IGLV5-52_CEACAM3',
#  'ACSM5_ENOSF1',
#  'UBALD1_MIPEP',
#  'ANKRD22_ANKRD29',
#  'SMPD2_HPS4',
#  'HNRNPCL1_POLR1D',
#  'FSTL3_PRSS3P2',
#  'TAF11L11_PGAM2',
#  'CLSTN3_PCDH12',
#  'STARD3_NANP',
#  'GPA33_GPRC5C',
#  'UGT2B10_NOTCH4',
#  'PRKY_DNAJC3',
#  'CFAP69_ZNHIT6',
#  'TLR5_BDKRB2',
#  'HLA-DRB1_OR6B3',
#  'FBXO8_TMEM184C',
#  'DIPK1B_MYO5A',
#  'CCL3_CLCA3P',
#  'PC_CRYZ',
#  'IGKV3D-20_IGLV3-25',
#  'FAP_SLC25A23',
#  'ADAT1_C11orf54',
#  'EFCAB6_MYO3B',
#  'AGFG2_CETN2',
#  'DOK3_EEF1AKMT1',
#  'SASH3_SEC31A',
#  'SLC16A2_TMX3',
#  'RCL1_N6AMT1',
#  'PAN2_DCLRE1A',
#  'LGR5_TMEM185A',
#  'EGFR_PAXIP1',
#  'HM13_RNF150',
#  'LRRC32_VAV3',
#  'NFX1_LRRFIP1',
#  'TAFAZZIN_SVIP',
#  'AOPEP_CCDC134',
#  'MBOAT7_MTG1',
#  'SERPIND1_XKR9',
#  'ARHGAP1_TSR2',
#  'SLC35E2B_YIPF6',
#  'PEX11G_RNF5',
#  'SMARCA1_ARHGAP23',
#  'DRD5_PTCHD1',
#  'MOB1A_MYO5C',
#  'DPH6_FBXO44',
#  'LRIG2_AGBL4',
#  'PITPNB_ATP6V0A4',
#  'GAS8_WASH2P',
#  'IGLV2-18_TRBV11-3',
#  'ACVR2B_LRIG1',
#  'RNF149_ZDHHC5',
#  'LGALS12_C11orf54',
#  'AP3B1_TRAPPC3',
#  'RS1_REG4',
#  'CHMP4BP1_TAF15',
#  'OR2T8_OR2T35',
#  'C11orf87_TMIGD1',
#  'SLC10A2_VKORC1L1',
#  'MAP3K11_MYO7B',
#  'ATP2B1_UQCRFS1',
#  'SOS1_VPS39',
#  'CIAO1_DCAF4',
#  'OR2F1_SRD5A3',
#  'EFCAB14_TMEM59',
#  'PF4_CXCL3',
#  'APOOL_OR2G3',
#  'IGKV3D-15_IGHV7-81',
#  'GRXCR2_LRRC4B',
#  'BPNT1_SPSB4',
#  'CYP2D7_LSS',
#  'GPR17_ENPP4',
#  'CHAD_NME6',
#  'FUOM_MXRA7',
#  'NAXE_NMRK2',
#  'CEBPG_SMG5',
#  'BHMT_ABI3',
#  'LRP6_AMHR2',
#  'RPL27_RPL7A',
#  'RRAGA_SREK1IP1',
#  'ATF5_TLN1',
#  'POLB_NFATC2IP',
#  'TCF15_TONSL',
#  'PDC_NUMBL',
#  'DYRK2_TSR2',
#  'ICMT_FRMD1',
#  'CENPVL2_PCYOX1',
#  'IGHV4OR15-8_IGHV3-9',
#  'CEBPZ_DNAJC17',
#  'KIF5B_TXLNA',
#  'LRIG2_TMEM165',
#  'C5AR1_GRIK5',
#  'CCT6A_WASF3',
#  'TOX_UBE2I',
#  'CDPF1_MED9',
#  'KDM4B_ABHD8',
#  'IGKV2-40_IGKV1D-37',
#  'KDELR3_TMEM230',
#  'TK1_PLAA',
#  'PROP1_PHF23',
#  'TKFC_PIGT',
#  'BTBD8_USP48',
#  'SLC47A1_FLVCR2',
#  'NME6_KLHL35',
#  'OR1I1_OR11H2',
#  'ARL6IP5_FAM210A',
#  'NSUN5P1_DCAF17',
#  'TTPAL_LRRC4C',
#  'GOLGA4_ARMT1',
#  'KCNK5_MARCHF4',
#  'STK19_MYH4',
#  'SMIM15_TMEM203',
#  'TENT4B_KLHDC3',
#  'COL5A2_BGN',
#  'CYB5A_RAB2B',
#  'CLNS1A_NFKBIZ',
#  'RHOH_ENPP6',
#  'SYNDIG1L_HTR5A',
#  'MINDY1_DNAJC2',
#  'SLC30A3_ADAM22',
#  'NUSAP1_DAXX',
#  'RAB30_SLC30A9',
#  'FOXR1_SNX20',
#  'SRI_JOSD2',
#  'BATF_PIM3',
#  'ZFYVE26_TMOD2',
#  'MEX3C_SAMM50',
#  'TRAFD1_GCLC',
#  'CAV2_LIPE',
#  'CDC25B_AZIN2',
#  'TCEA1_FBXL14',
#  'KCNAB3_UFL1',
#  'RUNX1T1_PPARGC1A',
#  'LUC7L_PRKAG2',
#  'COL3A1_SUV39H2',
#  'LLPH_NOC4L',
#  'TMEM258_HIGD1A',
#  'DAW1_RABGGTA',
#  'IQCF3_TIPIN',
#  'OR10X1_OR51M1',
#  'TMIGD1_USP32',
#  'OAZ1_DEF8',
#  'HNRNPC_UXS1',
#  'GSTZ1_SULT1C4',
#  'ATP6V1G2_VPS25',
#  'CDC42EP2_METTL23',
#  'RNF225_OR2V1',
#  'SURF4_CCDC25',
#  'TRAV6_IGHV1-3',
#  'POLR3D_FBXW4',
#  'GFM2_SMDT1',
#  'IBA57_EXOC6B',
#  'UPK2_CD151',
#  'UFM1_MYG1',
#  'PCID2_OTUB2',
#  'WASH2P_KLHL4',
#  'HOXC4_PTTG1IP',
#  'SNAPC1_TEX2',
#  'NAE1_SDSL',
#  'H3-3A; H3-3B_PRKRIP1',
#  'LARP1B_MRPL44',
#  'BFSP2_LRRC15',
#  'LRRC63_LRRC10',
#  'PSMA6_TAOK2',
#  'ALDH1L1_AMDHD1',
#  'STARD3_SRGAP1',
#  'RNF41_BATF3',
#  'EXD3_LRR1',
#  'FNTB_TMEM43',
#  'AP1S2_CDK3',
#  'BIRC5_C11orf68',
#  'LYZL6_CPB2',
#  'OR2A14_LRRC4',
#  'MKS1_DAAM1',
#  'PPP5C_NAA40',
#  'MERTK_ABCG5',
#  'SNAI2_SRSF2',
#  'PLXNA1_ASB3',
#  'MAPK12_RAI14',
#  'OR2AG2_OR5M8',
#  'SIK1B_ERBB3',
#  'SLC41A3_SLC52A3',
#  'FBXL19_NOB1',
#  'IGLV3-19_IGHV3-30',
#  'LINGO3_GIPR',
#  'KCNAB3_SMG6',
#  'RSBN1_N6AMT1',
#  'YBX3_PHF7',
#  'MRPL9_NDUFB9',
#  '_CD40',
#  'AP2A2_BPGM',
#  'LRRC3C_PLPP7',
#  'SLC49A3_MFSD9',
#  'TOB1_SNAP25',
#  'SCRN3_GK2',
#  'SPATA6L_LTO1',
#  'NDUFA3_COA6',
#  'LEUTX_RGS10',
#  'LRG1_CRKL',
#  'PLCD3_SPHK1',
#  'DPP4_SERPINF1',
#  'LRP6_CDK5',
#  'NKX2-6_JADE2',
#  'FABP4_THYN1',
#  'ANKRD49_SDSL',
#  'C18orf63_METTL22',
#  'URI1_SLC25A48',
#  'MT-CO2_CLEC7A',
#  'CA12_BRS3',
#  'ARL6IP4_AMMECR1',
#  'FAM13C_TSR2',
#  'CNIH2_ZDHHC9',
#  'UEVLD_RAB24',
#  'SYTL5_VPS37B',
#  'MVK_EARS2',
#  'MAST4_DTX1',
#  'GCLM_TNFAIP8L3',
#  'SPTY2D1_WDR82',
#  'HOXA10_POLDIP3',
#  'CENPX_CAV2',
#  'HMOX1_ATG14',
#  'ZNHIT1_POLH',
#  'RND2_KLHL20',
#  'MAFK_GTF2E2',
#  'CDK9_SPTY2D1',
#  'GPATCH1_NUP85',
#  'KIF28P_GK5',
#  'RPS6KB1_HSPBAP1',
#  'KPNA5_NRF1',
#  'TM7SF2_FN3K',
#  'MPZL1_SELPLG',
#  'CA5A_GGACT',
#  'MT-ND3_USP32',
#  'IGHV3-49_IGHV4-38-2',
#  'DISP2_ALK',
#  'PPP5C_RAB39B',
#  'BLCAP_TMEM161A',
#  'QARS1_FN3KRP',
#  'IQCA1_THAP6',
#  'LCLAT1_LRTM2',
#  'SCRT1_NCKIPSD',
#  'ALDOB_CKMT1A; CKMT1B',
#  'METTL23_FKBPL',
#  'DPH3P1_NLK',
#  'CDKN2B_RPEL1',
#  'TMEM238L_MLANA',
#  'WDR36_BAZ1B',
#  'TRBV6-9_IGKV2D-40',
#  'RPLP2_GALK2',
#  'GTPBP6_GDPD3',
#  'ZBTB8A_REV1',
#  'PLOD3_SMYD3',
#  'SSU72L2_TNFAIP8L2',
#  'UBE2C_UBTD2',
#  'SYPL2_DERL3',
#  'SLC26A6_COQ6',
#  'STRADA_SDCBP2',
#  'SEMA3F_SEMA3G',
#  'EIF3G_DDC',
#  'SNRPA1_RPL36',
#  'TAS1R3_MXRA8',
#  'IDH3B_PANK2',
#  'RHOC_RALA',
#  'THOC5_TBRG1',
#  'PPIL4_SSU72',
#  'TOMM40_AP3S1',
#  'POLR3D_RPIA',
#  'KAT2A_RNF181',
#  'CSF1R_FLT3',
#  'NDUFB3_HDDC3',
#  'BUD23_ARHGDIB',
#  'SLC30A4_ACVR1B',
#  'CA7_ANKRD2',
#  'BSG_STUM',
#  'IGLV5-45_IGHV3-72',
#  'SUMO1_ARPC1A',
#  'SHTN1_LRRC49',
#  'GGT3P_AMBP',
#  'NNMT_PLA2G2E',
#  'KCNJ1_KCNG1',
#  'UQCRC1_COPA',
#  'ABCD4_TPTE',
#  'ASAP2_FAM13A',
#  'ADRB1_DNAJC4',
#  'FUNDC1_SAYSD1',
#  'DGKZ_TSPYL4',
#  'NFKBIB_TNFAIP8L3',
#  'DPYSL3_PPIL6',
#  'OR11H12_TRDN',
#  'DLG5_NEURL2',
#  'MANF_UBE2G1',
#  'PTK2B_LNPK',
#  'SNAP25_SLC25A39',
#  'AIFM1_CIAO2A',
#  'FASLG_OR1L6',
#  'PEX5L_SLC4A9',
#  'CDX2_CIAO2B',
#  'MYLK_TXN2',
#  'SAMD10_NT5DC2',
#  'CDC25A_EIF3A',
#  'ARL1_RAC3',
#  'IGHV2-26_IGKV6D-41',
#  'PRRX1_TONSL',
#  'ADH1B_RABGGTA',
#  'GABPB1_RALY',
#  'CEBPA_PHF20',
#  'AQP10_HACD3',
#  'OR2G3_OR6F1',
#  'OR14I1_TSPAN4',
#  'METTL18_GSKIP',
#  'RBM11_NABP1',
#  'MRPL49_UQCR10',
#  'NIPA1_PCDH10',
#  'LRIG2_RNF122',
#  'UQCC4_DPM3',
#  'NCAPG_SPEF2',
#  'PUS10_FLAD1',
#  'BCL7A_SYNE3',
#  'NEIL1_FBXL15',
#  'SUPV3L1_GATAD1',
#  'BMP1_ZDHHC15',
#  'COX10_FBXO7',
#  'CHST13_RMDN2',
#  'VKORC1L1_CMTM7',
#  'CD2BP2_SP9',
#  'EIF4G1_DCP1B',
#  'ALAS2_CZIB',
#  'C1QA_ANKRD42',
#  'OR2A1; OR2A42_DNAJC4',
#  'CMPK1_THYN1',
#  'RACGAP1_PHRF1',
#  'ARHGAP21_LINGO4',
#  'NUP42_C6orf52',
#  'CSTB_SLBP',
#  'FAM210A_LGR4',
#  'GATA5_KAT8',
#  'IRX3_NEUROG2',
#  'EIF4B_ING2',
#  'TNFAIP8L2_CA10',
#  'FECH_PPM1K',
#  'ALDOB_BCKDHB',
#  'RNF181_ATP5IF1',
#  'PIGM_GRHPR',
#  'DUS4L_SKP1',
#  'ITGA6_TAFAZZIN',
#  'PRRT1B_SMIM24',
#  'OR4C3_PCDHGC3',
#  'USP32_PGAM5',
#  'BTG2_OR12D3',
#  'IGHMBP2_RMI1',
#  'APP_RAP1GDS1',
#  'CFAP91_IQCG',
#  'HIP1R_ATP6V1E1',
#  'OR4K1_OR4F4',
#  'EXT2_ARMT1',
#  'UBAP1_ASB3',
#  'OR7C1_OR51F2',
#  'CAPN5_PCYOX1L',
#  'CKS1B_PARP2',
#  'RPL14_PLAA',
#  'RNF130_RNF24',
#  'FOLH1_GDE1',
#  'CDCA4_AK6',
#  'TFPI2_KLK7',
#  'OR10G8_OR5H6',
#  'CCND1_FAF2',
#  'SLC1A7_RNF122',
#  'SARS2_ASAH2',
#  'SOAT2_RNF150',
#  'GPR88_CA14',
#  'UQCC6_MRPL11',
#  'HIGD1C_PET100',
#  'PGD_CNDP1',
#  'HBG2_ARL9',
#  'CXorf65_RAMAC',
#  'CDH6_KCNIP2',
#  'TATDN2_RNPEPL1',
#  'HNRNPH3_TBC1D19',
#  'DOHH_TPPP3',
#  'PDIA5_METAP1D',
#  'TAF1_NFX1',
#  'LRRC39_INCENP',
#  'CHST6_TRMT9B',
#  'POLR3G_INPP5E',
#  'PXDNL_GLRX',
#  'BCL2L1_WDR36',
#  'MPDZ_B3GNT2',
#  'GRIA1_SAMM50',
#  'NTMT1_EXO5',
#  'PHGDH_FNIP1',
#  'PTK7_SEMA5B',
#  'ATP6AP2_SLC25A4',
#  'CYP2B6_DYDC2',
#  'BIRC5_SNRNP25',
#  'KLHL5_HYPK',
#  'AASDH_AMDHD2',
#  'SYT5_FOLH1',
#  'SLC8B1_SH3BGRL3',
#  'PAQR4_ATP6V0B',
#  'PIN1P1_TGM1',
#  'AMD1_PIM3',
#  'PPM1F_ALDH5A1',
#  'SULT2B1_PLCB1',
#  'SAT1_DPP4',
#  'CENPVL2_LRGUK',
#  'KPNA7_UBALD1',
#  'NMT2_CAPNS1',
#  'IGHV3-43D_TRA',
#  'STX10_VAMP2',
#  'INPP5J_FGGY',
#  'BRIX1_UBTD1',
#  'DLEU7_ZNF669',
#  'MCF2L2_LRRC15',
#  'EFNA1_EPHA2',
#  'CACNB4_EOGT',
#  'OR2T7_SEMA5B',
#  'TTLL4_FNBP1L',
#  'SLC9A4_ANKRA2',
#  'AAMP_LAMTOR1',
#  'CD200_TMEM107',
#  'EVX2_SCRT2',
#  'IGKV2-28_IGHV3-7',
#  'NBAS_FBXL13',
#  'RNF151_LMBR1L',
#  'FAHD2A_DNAAF6',
#  'GALNT15_NMUR1',
#  'OR2T2_OR5D16',
#  'TMEM141_DPM3',
#  'ADRA2B_HGH1',
#  'RNF113B_CRIPT',
#  'LRRTM2_CARMIL3',
#  'SPAG7_PAXIP1',
#  'EDF1_RPL36',
#  'TIMM23B_TEX261',
#  'DUSP13B_SLC25A15',
#  'C7orf50_RDH14',
#  'SLC25A3_MKRN4P',
#  'PDPK2P_STRAP',
#  'MTERF4_TRMT2A',
#  'HYPK_TRMT9B',
#  'TRPM6_LNPK',
#  'SRSF5_NUDT5',
#  'ATP5MF_HIGD2B',
#  'SPTLC2_LRIG1',
#  'HOXD8_CTDSPL2',
#  'HSPA4L_RPS29',
#  'DDX55_SSU72',
#  'SGCB_OR5M1',
#  'PLS1_GSKIP',
#  'ACKR3_MDGA1',
#  'KIF5B_ELOVL2',
#  'LRRC38_CMTM7',
#  'HSFX3_KDM8',
#  'FAM240A_FAM240B',
#  'BAG4_PHACTR4',
#  'HSPA12B_NME7',
#  'LITAFD_RHOF',
#  'POLR2H_CDC73',
#  'H2AB2; H2AB3_H2BC13',
#  'CYBRD1_FADS3',
#  'SLC9A4_TTL',
#  'OR4X2_OR5W2',
#  'AKR7A3_LBR',
#  'DGKE_KLHDC1',
#  'ADH1C_GSR',
#  'ABCF1_GMCL1',
#  'DBH_CLIP4',
#  'CDK3_CIAPIN1',
#  'CDK3_CHKB',
#  'SREBF2_',
#  'P2RY10_CYBRD1',
#  'FMO6P_SCAI',
#  'MAP3K7CL_TACC3',
#  'RPAP2_G3BP2',
#  'SLC23A3_LRTM2',
#  'OR2A1_SLC52A1',
#  'DFFB_MAP4K1',
#  'MRPS34_ABHD16B',
#  'TBC1D22A_REEP4',
#  'ZC2HC1B_H2AC14',
#  'ESCO2_KCTD9',
#  'DHCR24_TMEM222',
#  'OR4K17_OR6Y1',
#  'COG6_MYO5A',
#  'TKFC_GPA33',
#  'PIN1_',
#  'TLR4_CASP9',
#  'CX3CL1_CCL4L1; CCL4L2',
#  'SDHAF1_OSGIN2',
#  'GNA12_FNIP1',
#  'GAD1_ING1',
#  'POP7_RPL13',
#  'AIFM1_VAV1',
#  'KDELR2_GALR1',
#  'STRADA_FBXL4',
#  'TP53INP2_BCAS3',
#  'SLC16A10_SLC39A3',
#  'NCALD_ARL6',
#  'ZNF729_ZNF511',
#  'GRID2_GRIN1',
#  'ISCA2_OSGIN1',
#  'MOCOS_RRN3',
#  'ANK1_OMG',
#  'CDIPT_FZD3',
#  'SCAMP3_ADGRA1',
#  'TRAV38-2DV8_IGHV1-38-4',
#  'OPCML_TNFAIP8L3',
#  'PLSCR5_LSM6',
#  'LYRM9_AURKA',
#  'ATP5MGL_HIGD1A',
#  'CFAP100_WASF3',
#  'CFAP65_PFN4',
#  'OR2G6_OR10T2',
#  'TNFAIP8L3_ATP6V1G3',
#  'ZNF776_RANBP3',
#  'C1QTNF8_C1QTNF3',
#  'NXNL2_MDP1',
#  'SKIC3_MYH14',
#  'CHAC2_COMMD4',
#  'PPIL2_SMIM12',
#  'MBTPS2_HTRA4',
#  'MEIOC_FRG1',
#  'PPP6R3_ATXN10',
#  'JUNB_ATP23',
#  'OR13C2_PCDHGA8',
#  'DHODH_SLC2A8',
#  'DHH_TINAGL1',
#  'PRMT3_NSMAF',
#  'GLCE_DPAGT1',
#  'PRPF3_DEF8',
#  'MTPN_HHEX',
#  'UGT2B10_ITFG1',
#  'PIM1_LHX9',
#  'LRIG2_FZD8',
#  'POU2F2_ZRSR2P1',
#  'PHF3_EIF3L',
#  'PDCL2_FMO2',
#  'LANCL1_RCAN1',
#  'PNRC1_CCDC102A',
#  'HNRNPA1L3_MLLT10',
#  'SLC35E2B_COX16',
#  'IDH3G_FN3KRP',
#  'C2orf76_ZDHHC9',
#  'GADD45G_CMC2',
#  'RGS20_FEM1A',
#  'DNAJA1_SEC23B',
#  'TXNDC5_SDF2L1',
#  'JADE1_PCMTD1',
#  'SLC25A1_PTK7',
#  'VAMP2_PPP2R2B',
#  'GPR4_SLC35A3',
#  'SCO2_COX6B1',
#  'KPNA3_MED6',
#  'PSMA1_FCF1',
#  'PCP4L1_SLIT1',
#  'LOC122513141_CYP46A1',
#  'DOK2_B4GALT4',
#  'PIP4P1_TMEM135',
#  'TLR4_LRRC4',
#  'SEC61G_PARP16',
#  'SLC32A1_PTCH2',
#  'KHK_MYO1A',
#  'LYSMD1_CYP4F11',
#  'LMO1_EVX2',
#  'RRP8_DPH6',
#  'TEX30_CHCHD10',
#  'ASIC1_DDR2',
#  'HVCN1_PCDHA12',
#  'PITX2_RNF11',
#  'RHOT2_SPRING1',
#  'RNF223_OR11A1',
#  'HIP1R_STEEP1',
#  'MARK2_ELMOD1',
#  'GAK_PANK4',
#  'SRGAP2B_ATXN2L',
#  'EGFR_SP9',
#  'PEX13_WSB2',
#  'CDH2_DHFR2',
#  'PDK1_COQ6',
#  'ASPDH_TRMT12',
#  'SCAMP3_SLC16A7',
#  'SPTB_SRM',
#  'CCNA2_CPLX2',
#  'UBAP1L_CHMP1B',
#  'TMEM50A_ZDHHC3',
#  'IGFBP6_PXDN',
#  'GEN1_CREB3L2',
#  'SLC28A1_GPR21',
#  'UBE2G1_SHOC2',
#  'RPEL1_UQCC1',
#  'MCF2L2_ASB8',
#  'CHADL_NOL4L',
#  'GABRR3_GABRE',
#  'NR0B2_POLK',
#  'YIPF6_OR52A1',
#  'TMEM220_TMEM216',
#  'PPIH_HSPA12B',
#  'SLC5A1_NAA60',
#  'CPN2_TRIM74',
#  'ID4_NHLH2',
#  'LEO1_TSPYL4',
#  'DHCR24_SUGCT',
#  'SDC4_TMEM98',
#  'RSU1_TTC33',
#  'PTP4A2_CHKB',
#  'VPS41_IFT43',
#  'ALAD_NABP1',
#  'EAPP_TBC1D10C',
#  'IBA57_DDX49',
#  'GRM1_GK2',
#  'BCL2_SCOC',
#  'ARL16_DDX21',
#  'FNTB_SYMPK',
#  'PAPSS1_PAICS',
#  'ARFGAP2_RABGEF1',
#  'MTX3_LCLAT1',
#  'NHERF2_TEX264',
#  'GRIN2C_NPTN',
#  'SMIM1_MS4A8',
#  'DCAF5_MYO5C',
#  'KLHL2_CDK20',
#  'CLIC3_TOMM22',
#  'TFEC_ATOH1',
#  'WDR53_MYOT',
#  'STX1A_MRPL40',
#  'SNAPC3_WDR76',
#  'ETFDH_PIGU',
#  'SPTLC2_SEL1L',
#  'FSTL3_CD74',
#  'TCEA1_STK38',
#  'TNFAIP8L3_GEMIN8',
#  'KAT2A_POLR3K',
#  'CSNK2A3_TM9SF3',
#  'SLC24A1_CRB3',
#  'PET117_BAD',
#  'TIMM23B_OSGIN2',
#  'CYGB_ANKRD19P',
#  'FOS_RALB',
#  'GP1BB_DERL1',
#  'EGFR_TSKU',
#  'MT-ND5_CD3D',
#  'OSBPL2_SLC17A7',
#  'INAFM1_CNIH3',
#  'FN3KRP_INO80',
#  'STMN1_RACGAP1',
#  'AZIN1_CDK14',
#  'AK1_ETFBKMT',
#  'OR8B2_TOMM22',
#  'TPO_HIGD2B',
#  'SLC25A20_RGPD1',
#  'XNDC1N_ENPP6',
#  'ARMC3_JPT1',
#  'RHOG_ELMOD2',
#  'ACADVL_UBE2M',
#  'ANKRD63_TATDN2',
#  'NDUFB3_SLC45A2',
#  'PCP4_TIMM8B',
#  'SON_WBP11',
#  'GPR137C_SPO11',
#  'RDH13_ESAM',
#  'LRRC56_ETNK2',
#  'ATG14_OSGIN1',
#  'TAF11L9_YTHDF2',
#  'GNA15_RGS17',
#  'GMNN_CFAP58',
#  'MRPL44_AAR2',
#  'CCND1_TLCD5',
#  'HLA-DPB1_TMEM252',
#  'BPGM_SKIC8',
#  'SDHAF1_VSNL1',
#  'OR10S1_OR2G2',
#  'NPR2_PCSK7',
#  'BLVRA_TSR2',
#  'H1-1_CABLES2',
#  'MOB3C_MIXL1',
#  'FHIT_ATAD5',
#  'FZD7_EEF1AKMT4',
#  'GYPA_ITGA6',
#  'OR2T7_AGMO',
#  'JUNB_BATF',
#  'DGKI_LMF2',
#  'RCC1_MYOT',
#  'GMPR_COQ5',
#  'DNMBP_ARL15',
#  'RAD52_USP48',
#  'SUPT20HL2_GRIP1',
#  'SUMO1_CRLS1',
#  'MT-CO3_COA3',
#  'CLTB_CXCR2',
#  'TIMM17A_DERL2',
#  'MRPS5_UEVLD',
#  'TLX2_MED14',
#  'ISLR_LSAMP',
#  'ZNF367_REX1BD',
#  'OR1C1_AWAT1',
#  'UBE2B_PRMT1',
#  'MED22_SRA1',
#  'PPP6R3_NAA80',
#  'PATJ_MOV10L1',
#  'LRIG2_MTCH1',
#  'INSR_SLC17A5',
#  'KCNJ12_GAPVD1',
#  'P2RY4_ENPP4',
#  'UQCRFS1_SIRT2',
#  'SOX12_CCDC59',
#  'PLSCR1_TNFAIP8L3',
#  'SNRNP27_UROC1',
#  'ALKBH6_CEP41',
#  'LRRC15_PPME1',
#  'EFCAB14_MARCHF2',
#  'FOLH1_PPAT',
#  'FNIP1_TOMM40L',
#  'HCN1_GABRA4',
#  'SREBF1_DAG1',
#  'SPCS2_ITSN1',
#  'OR51F1_TSPAN18',
#  'ARL4A_UBTD2',
#  'SRP19_IQGAP3',
#  'KDELR1_GOLGA7B',
#  'IGHV1-69D_IGLV3-19',
#  'PSMG2_AMDHD1',
#  'SDS_SDHAF2',
#  'GIGYF2_MIGA2',
#  'DAP3_MRPS9',
#  'DHFR2_RBKS',
#  'TVP23A_SCAMP1',
#  'PRKAG1_RNF181',
#  'ARPC5_AMD1',
#  'TAF11L12_MTPN',
#  'LRRC10_SCRT1',
#  'PC_NOS3',
#  'PPFIA1_RCAN2',
#  'STARD3_TM7SF3',
#  'PDCD2_CDO1',
#  'TTC33_RCE1',
#  'MPV17_TXNDC15',
#  'ROR2_CNTN4',
#  'C5AR1_ADGRA1',
#  'RBMXL3_RBKS',
#  'NEMP1_TNFAIP8L3',
#  'NDUFV3_FBXO44',
#  'DIRAS1_EPN2',
#  'YPEL4_RBM42',
#  'ACOT7_ASPSCR1',
#  'SPEF2_CNOT11',
#  'STAMBP_DNTT',
#  'AKR7A2_OTUD1',
#  'NARS1_PGD',
#  'TMUB1_PIAS3',
#  'SDR16C5_OR4F6',
#  'CDK2_MTREX',
#  'ADK_PAFAH1B2',
#  'FDX1_TRMO',
#  'ITGA7_TMIE',
#  'RAB35_SENP8',
#  'SLC36A2_OR10G7',
#  'STRIP1_DCLK2',
#  'POLR3C_BCAS3',
#  'SLCO1B7_UGT2B7',
#  'OR8D4_GPA33',
#  'SLC7A1_YIPF1',
#  'POP5_VPS25',
#  'SH3BGRL_MMGT1',
#  'RPEL1_EPYC',
#  'DCUN1D3_NEUROD4',
#  'COX6C_MRPL9',
#  'PHF1_GLCCI1',
#  'GPR107_SEC63',
#  'GNPNAT1_ABCB10',
#  'GSR_ACAD8',
#  'UQCRB_MRPL20',
#  'CCR8_SVOPL',
#  'HOXB6_GPATCH4',
#  'PGAP3_CMTM6',
#  'KIF4B_DDX46',
#  'LRIG1_WIF1',
#  'ITGB1_FKBP9P1',
#  'PKDCC_FAM184A',
#  'TMEM131L_LGR6',
#  'DESI1_KDM4C',
#  'PPP1R27_TTC9B',
#  'OR10G9_PGAP3',
#  'PNLIPRP3_NTN4',
#  'TRGV2_TRAV8-6',
#  'PET117_NGRN',
#  'TNFSF11_FFAR4',
#  'KPNA3_TIPIN',
#  'D2HGDH_TOMM22',
#  'MRPS10_C3orf38',
#  'COG1_VPS50',
#  'NME6_RNF11',
#  'TMA7B_C7orf50',
#  'CYB5B_RAB21',
#  'FITM1_PEX2',
#  'TRIM42_DDX56',
#  'NRP2_ICMT',
#  'KIF21B_COPA',
#  'LRIG2_MAD1L1',
#  'GNMT_PABPN1',
#  'GCLC_PPP1R42',
#  'ATG14_SIRT6',
#  'STMN1_ALKBH3',
#  'ACY1_OTUB1',
#  'AMD1_FAM185A',
#  'SSU72L6_PKN2',
#  'SLIT3_NEGR1',
#  'PDCD2_BZW1',
#  'ERI3_SRA1',
#  'TRMT1L_WRAP53',
#  'TCF4_DMAP1',
#  'ALG14_STRADB',
#  'TSPAN1_HRH3',
#  'CIB4_SEC31A',
#  'P2RY2_HACD3',
#  'SRRM3_B3GNT3',
#  'CCL11_CCL17',
#  'ECM2_TTI2',
#  'LEPR_OR2AP1',
#  'MMP1_BCHE',
#  'TRB_HLA-G',
#  'ANKRD63_CASKIN2',
#  'HOXB6_SAT1',
#  'TRBV27_TRBV10-3',
#  'ZNF839_HHAT',
#  'LRTM2_PIGC',
#  'FNTB_RPGR',
#  'DSCC1_CDT1',
#  'TPO_HACD3',
#  'ACSL4_ATP5PO',
#  'PECR_FN3KRP',
#  'IGHV2OR16-5_IGLV1-51',
#  'LRRC53_ASAH2',
#  'SULT1C4_TST',
#  'DDX53_PRMT6',
#  'PLXNA2_PCDH1',
#  'PIM1_HESX1',
#  'ALDH4A1_FBXL4',
#  'NHLH2_RRP15',
#  'LIMS4_MYB',
#  'HYI_BBS2',
#  'MBOAT4_ELOVL2',
#  'OSGEPL1_PUS1',
#  'FXN_HYI',
#  'TMEM238_KLRD1',
#  'TYW1B_ALX4',
#  'TLR3_RAB34',
#  'ORMDL3_TM2D1',
#  'SHH_PEX16',
#  'TOX_GRB2',
#  'RANBP6_DLX4',
#  'NOTCH4_LGR6',
#  'ETF1_GNB4',
#  'COX19_ETFRF1',
#  'ZNF845_C7orf50',
#  'CD82_AVPR1A',
#  'ENO1_ABCG4',
#  'FAXC_SLC49A3',
#  'DNAI3_PGPEP1',
#  ...}

# %%
! uv pip install venn

# %%
from venn import venn
import matplotlib.pyplot as plt

sets = {
    # "OmniPath": omni_s,
    # "CollecTRI": collectri_s,
    "GWPS": gwps_s,
    "Human Interactome": humaninter_s,
    "CellMap": cellmap_s,
}

fig, ax = plt.subplots(figsize=(8, 8))
venn(sets, ax=ax)

# Increase all text sizes in the venn plot
for txt in ax.texts:
    txt.set_fontsize(18)

ax.set_title("Network overlap", fontsize=22)
plt.show()

# %%
sets = {
    "OmniPath": omni_s,
    #"CollecTRI": collectri_s,
    "GWPS": gwps_s,
    "Human Interactome": humaninter_s,
    "CellMap": cellmap_s,
}

fig, ax = plt.subplots(figsize=(8, 8))
venn(sets, ax=ax)

for txt in ax.texts:
    txt.set_fontsize(18)
    
plt.show()

# %%
sets = {
    "OmniPath": omni_s,
    # "CollecTRI": collectri_s,
    "GWPS": gwps_s,
    'Human Interactome': humaninter,
    'CellMap': cellmap
}

venn(sets)
# Out:
# <Axes: >

# %%
del res

# %%
# Load gene names
genes = load_genes("NCBITaxon:9606")

# Create empty anndata with gene names
empty_adata = ad.AnnData(X=np.zeros((1, len(genes))), var=genes)
print(f"Created empty AnnData with {len(genes)} genes")
empty_adata.var["ensembl_id"] = empty_adata.var.index
empty_adata.var.set_index("symbol", inplace=True, drop=False)
gt_cm = from_adata_and_longform(empty_adata, cellmap.iloc[:, [2, 4]])
gt_cm = gt_cm[:, (gt_cm.varp["GRN"].sum(1) != 0) | (gt_cm.varp["GRN"].sum(0) != 0)]
gt_cm.varp["GRN"] = scipy.sparse.csr_matrix(gt_cm.varp["GRN"].astype(np.float32))
gt_cm.varp["GRN"] = scipy.sparse.csr_matrix(gt_cm.varp["GRN"].astype(np.float32))

gt_inter = from_adata_and_longform(
    empty_adata,
    res[res["RF2-PPI_interaction_probability"] > THRESHOLD][
        ["geneA", "geneB", "RF2-PPI_interaction_probability"]
    ],
    has_weight=True,
)


gt_cm.var.index.name = "index"
gt_inter.var.index.name = "index"

# %%
gt_cm.write_h5ad(LOC + "/gt_cellmap.h5ad")
gt_inter.write_h5ad(LOC + "/gt_humaninter.h5ad")

# %% [markdown]
# ## Use scPRINT-2 to generate a gene network

# %%
LOC3 = "../../models/"  # "../../../"
# "../models/ogvvg2z7-v1.ckpt"
# "../models/ji9krimq.ckpt"
ckpt_path = os.path.join(LOC3, "ogvvg2z7-v1.ckpt")
if not os.path.exists(ckpt_path):
    url = "https://huggingface.co/jkobject/scPRINT/resolve/main/other_ckpts/ogvvg2z7-v1.ckpt"
    urllib.request.urlretrieve(url, ckpt_path)

model = scPRINT2.load_from_checkpoint(
    ckpt_path, precpt_gene_emb=None, gene_pos_file=None
)
if not torch.cuda.is_available():
    model = model.to(torch.float32)

model = model.to("cuda" if torch.cuda.is_available() else "cpu")
missing = set(model.genes) - set(load_genes(model.organisms).index)
if len(missing) > 0:
    print(
        "Warning: some genes missmatch exist between model and ontology: solving...",
    )
    model._rm_genes(missing)
# Out:
# FYI: scPrint is not attached to a `Trainer`.

# %%
LOC2 = "/pasteur/appa/scratch/jkalfon/data/"

# %%
# see the cross-species-embedding notebook to see how we download the normalize_log folder
adata = sc.read(LOC2 + "/task4_human_preprocessed.h5ad")
# mouse = sc.read(LOC2+"/task4_mouse_preprocessed.h5ad")

# %%
adata = adata[(adata.X.sum(1) > 500)]
adata = adata[
    adata.obs.celltype.isin(
        [k for k, v in adata.obs.celltype.value_counts().items() if v > 1000]
    )
]
adata.obs.celltype.value_counts()
# Out:
# celltype
# Loop of Henle                  5985
# Epithelial cell                3751
# Intercalated cell              3416
# Endothelial cell (APC)         2676
# Monocyte                       2361
# Macrophage                     2157
# Smooth muscle cell             2156
# Dendritic cell                 1828
# Sinusoidal endothelial cell    1244
# Name: count, dtype: int64

# %%
model.mask_zeros = True

# %%
grn_inferer = GNInfer(
    how="most var within",  # most expr
    preprocess="softmax",
    head_agg="mean",
    filtration="none",
    num_genes=4000,
    max_cells=1024,
    num_workers=8,
    batch_size=16,
    precomp_attn=True,
    cell_type_col="celltype",
)
grn = grn_inferer(model, adata, cell_type=celltype)
grn.varp["GRN"][np.isnan(grn.varp["GRN"])] = 0
grn.var.index = make_index_unique(grn.var["symbol"].astype(str))

# %% [markdown]
# # run on multiple cell types in a dataset and test using our ground truths

# %%
gwps = get_perturb_gt(
    filename_adata="/pasteur/appa/homes/jkalfon/benGRN/data/ess_perturb_sc.h5ad",
    filename_bh="/pasteur/appa/homes/jkalfon/benGRN/data/BH-corrected.csv.gz",
)
gwps.var.index = gwps.var.gene_name
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 gwps = get_perturb_gt(
#       2     filename_adata="/pasteur/appa/homes/jkalfon/benGRN/data/ess_perturb_sc.h5ad",
#       3     filename_bh="/pasteur/appa/homes/jkalfon/benGRN/data/BH-corrected.csv.gz",
#       4 )
#       5 gwps.var.index = gwps.var.gene_name
#
# File ~/scPRINT/.venv/lib/python3.11/site-packages/bengrn/base.py:671, in get_perturb_gt(filename_adata, filename_bh, url_adata, url_bh)
#     667 pert = pert.reindex(columns=pert.columns.union(missing_indices), fill_value=False)
#     669 pert = pert.loc[adata_sc.var.index].loc[:, adata_sc.var.index]
#     670 return GRNAnnData(
# --> 671     X=csr_matrix(adata_sc.X.toarray()),
#     672     var=adata_sc.var,
#     673     obs=adata_sc.obs,
#     674     grn=csr_matrix(pert.values),
#     675 )
#
# File ~/scPRINT/.venv/lib/python3.11/site-packages/anndata/_core/anndata.py:562, in AnnData.X(self)
#     559     X = None
#     560 elif self.is_view:
#     561     X = as_view(
# --> 562         _subset(self._adata_ref.X, (self._oidx, self._vidx)),
#     563         ElementRef(self, "X"),
#     564     )
#     565 else:
#     566     X = self._X
#
# File ~/.local/share/uv/python/cpython-3.11.11-linux-x86_64-gnu/lib/python3.11/functools.py:909, in singledispatch.<locals>.wrapper(*args, **kw)
#     905 if not args:
#     906     raise TypeError(f'{funcname} requires at least '
#     907                     '1 positional argument')
# --> 909 return dispatch(args[0].__class__)(*args, **kw)
#
# KeyboardInterrupt:

# %%
gt_cm = read_h5ad(LOC2 + "/gt_cellmap.h5ad")
gt_inter = read_h5ad(LOC2 + "/gt_humaninter.h5ad")

# %%
gt_inter_high_qual = gt_inter.copy()
gt_inter_high_qual.varp["GRN"] = (gt_inter_high_qual.varp["GRN"] > 0.7).astype(
    np.float32
)

# %%
metrics = {}
shapes = []
for celltype in adata.obs.celltype.value_counts().keys().tolist():
    grn_inferer = GNInfer(
        how="most var within",  # most expr
        preprocess="softmax",
        head_agg="mean",
        filtration="none",
        num_genes=4000,
        max_cells=1024,
        num_workers=8,
        batch_size=16,
        precomp_attn=True,
        cell_type_col="celltype",
    )
    grn = grn_inferer(model, adata, cell_type=celltype)
    grn.varp["GRN"][np.isnan(grn.varp["GRN"])] = 0
    grn.var.index = make_index_unique(grn.var["symbol"].astype(str))
    metrics[celltype + "_collectri"] = BenGRN(grn).compare_to(to="collectri")
    metrics[celltype + "_omnipath"] = BenGRN(grn).compare_to(to="omnipath")
    metrics[celltype + "_cellmap"] = BenGRN(grn).compare_to(gt_cm)
    grn.varp["GRN"] = grn.varp["GRN"].T
    metrics[celltype + "_gwps"] = BenGRN(grn).compare_to(gwps)
    metrics[celltype + "_interact"] = BenGRN(grn).compare_to(gt_inter)
    metrics[celltype + "_interact_hq"] = BenGRN(grn).compare_to(gt_inter_high_qual)
    del grn
# grn.varp["all"] = grn.varp["GRN"]
# grn.varp["GRN"] = grn.varp["GRN"][:, :, :].mean(-1)
# metrics[celltype + "_scprint_mean"] = BenGRN(grn).scprint_benchmark()
# Out:
# number of expressed genes in this cell type: 15492
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 16
#       3 for celltype in adata.obs.celltype.value_counts().keys().tolist():
#       4     grn_inferer = GNInfer(
#       5         how="most var within",  # most expr
#       6         preprocess="softmax",
#    (...)     14         cell_type_col="celltype",
#      15     )
# ---> 16     grn = grn_inferer(model, adata, cell_type=celltype)
#      17     grn.varp["GRN"][np.isnan(grn.varp["GRN"])] = 0
#      18     grn.var.index = make_index_unique(grn.var["symbol"].astype(str))
#
# File ~/scPRINT/scprint/tasks/grn.py:139, in GNInfer.__call__(self, model, adata, cell_type)
#     137     self.layer = list(range(model.nlayers))
#     138 self.n_cell_embs = model.attn.additional_tokens
# --> 139 subadata = self.predict(model, adata, self.layer, cell_type)
#     140 adjacencies = self.aggregate(model)
#     141 model.attn.data = None
#
# File ~/scPRINT/scprint/tasks/grn.py:217, in GNInfer.predict(self, model, adata, layer, cell_type)
#     215 if len(subadata) == 0:
#     216     raise ValueError("no cells in the dataset")
# --> 217 adataset = SimpleAnnDataset(
#     218     subadata,
#     219     obs_to_output=["organism_ontology_term_id"],
#     220     get_knn_cells=model.expr_emb_style == "metacell",
#     221 )
#     222 col = Collator(
#     223     organisms=model.organisms,
#     224     valid_genes=model.genes,
#    (...)    228     n_bins=model.n_input_bins if model.expr_emb_style == "binned" else 0,
#     229 )
#     230 dataloader = DataLoader(
#     231     adataset,
#     232     collate_fn=col,
#    (...)    235     shuffle=False,
#     236 )
#
# File ~/scPRINT/.venv/lib/python3.11/site-packages/scdataloader/data.py:348, in __init__(self, adata, obs_to_output, layer, get_knn_cells, encoder)
#
# ValueError: neighbors key not found in adata.obsm

# %% [markdown]
# ## gathering multiple scores

# %%
# most var across, full
for k, v in metrics.items():
    print(k.split("_")[1], float(v["epr"]), float(v["auprc"]))
# Out:
# collectri 4.320847454189799 0.001650089507826676
# omnipath 2.161961011485835 0.0022005348151650124
# cellmap 0.7579036152773526 0.00279858487990163
# gwps 4.393426476008669 0.05303653714649336
# interact 0.7885126112275245 0.0032431919506751674
# interact 1.3165039188215408 0.0007380336918651627

# %%
# no zero expr most var across, full
for k, v in metrics.items():
    print(k.split("_")[1], float(v["epr"]), float(v["auprc"]))
# Out:
# collectri 2.946032355129409 0.002094824186664233
# omnipath 2.7240708744721527 0.002766940004414173
# cellmap 0.5052690768515684 0.0028969264816182203
# gwps 6.255797196027438 0.07189889987374425
# interact 2.3880667654319314 0.003625986726765378
# interact 9.654362071357966 0.0010260613477399562

# %%
# no zero expr second trial, full
for k, v in metrics.items():
    print(k.split("_")[1], float(v["epr"]), float(v["auprc"]))
# Out:
# collectri 6.391822622152974 0.0026499323091102815
# omnipath 11.786240962326248 0.002825303653759943
# cellmap 1.5208244405146656 0.0029901568828903415
# gwps 1.9368401547916452 0.02477496894268167
# interact 1.3093877841006418 0.003950697092027391
# interact 11.32344314936535 0.0005978302259696873

# %%
# no zero expr, full
for k, v in metrics.items():
    print(k.split("_")[1], float(v["epr"]), float(v["auprc"]))
# Out:
# collectri 6.015833056143975 0.002604055862554985
# omnipath 11.092932670424705 0.002789710383641038
# cellmap 1.6898049339051837 0.0030508892757604446
# gwps 3.365786084209938 0.03307093983753216
# interact 1.3778525048379302 0.004175442762947657
# interact 15.31995249620018 0.0006296682248338563

# %%
# max most var within, full
for k, v in metrics.items():
    print(k.split("_")[1], float(v["epr"]), float(v["auprc"]))
# Out:
# collectri 2.4223730795878544 0.0017729955048933004
# omnipath 1.314072511477024 0.002161736784490282
# cellmap 1.0378315416535224 0.0025352133717579115
# gwps 3.2769448126414873 0.05856635319675267
# interact 1.5962985773386713 0.0038399127586959555
# interact 2.567721870436926 0.0008905285981570997

# %%
# mean full
for k, v in metrics.items():
    print(k.split("_")[1], float(v["epr"]), float(v["auprc"]))
# Out:
# collectri 6.7678121881619715 0.002635528851595563
# omnipath 12.01734372629343 0.0028207894582880063
# cellmap 1.5208244405146656 0.0030141050792928887
# gwps 3.3460492619804034 0.032997567275140895
# interact 1.3607363246536082 0.004176705484362731
# interact 15.31995249620018 0.0006371698945342159

# %%
# less cells
for k, v in metrics.items():
    print(k.split("_")[1], float(v["epr"]), float(v["auprc"]))
# Out:
# collectri 1.695661155711498 0.00181250742174925
# omnipath 1.415155012359872 0.0023906906948043326
# cellmap 1.0378315416535224 0.0026622182250509623
# gwps 5.032339607614996 0.07293228734948903
# interact 2.7441986778968173 0.004182887096974328
# interact 3.2096523380461575 0.001013204125433611

# %%
# more genes
for k, v in metrics.items():
    print(k.split("_")[1], float(v["epr"]), float(v["auprc"]))
# Out:
# collectri 0.7795931067176785 0.001626955095128026
# omnipath 1.4136550849371263 0.0021280710909285278
# cellmap 0.9890787726587984 0.0025631016217331727
# gwps 5.039374243159614 0.060350320698679814
# interact 2.1219004919374047 0.003919617245090371
# interact 5.927645002142037 0.0008990599629006808

# %%
# most expr
for k, v in metrics.items():
    print(k.split("_")[1], float(v["epr"]), float(v["auprc"]))
# Out:
# collectri 0.9918788577397826 0.002050403690883833
# omnipath 1.1160264447330215 0.003021266229591356
# cellmap 1.4443264095621609 0.0027797259350693768
# gwps 2.7120910456155856 0.06918387763206227
# interact 1.5280781386541193 0.004826298411995087
# interact 1.9205865623689202 0.0012705638404502053

# %%
interact best #(most expr AUPRC) # (mean full #EPR)
interact #(most expr) # (most var across)
gwps # (most var across)
cellmap #(most var within) # (mean full)
omnipath # (mean full)
collectri #(mean full)

# %%
# within
for k, v in metrics.items():
    print(k.split("_")[1], float(v["epr"]), float(v["auprc"]))
# Out:
# collectri 2.89554375 0.0023501150639435595
# omnipath 5.016505190311419 0.002239796342907146
# cellmap 2.4469455895622545 0.002954973537836676
# gwps 3.219736432055241 0.032151210471834335
# interact 1.286258947175577 0.003832185953245134
# interact 0.0 0.0005739554645104968

# %%
# across
for k, v in metrics.items():
    print(k.split("_")[1], float(v["epr"]), float(v["auprc"]))
# Out:
# collectri 1.2111865397939272 0.0018516594378383262
# omnipath 1.364613761918448 0.002451264598245648
# cellmap 1.383775388871363 0.0026919804270312195
# gwps 4.8764430894113096 0.06884667790676557
# interact 2.3496080183299544 0.004083259545637848
# interact 5.135443740873852 0.0009764047028928342

# %%
metrics_v1 = {
    "Loop of Henle_collectri": {
        "precision": 0.0016351735562295604,
        "rand_precision": 0.0016360646589849987,
        "auprc": 0.002501024287817965,
        "ap": 0.0025052068378218248,
        "epr": 1.774231601298447,
        "odd_ratio": 1.7787460617116801,
    },
    "Loop of Henle_omnipath": {
        "precision": 0.001963606529092425,
        "rand_precision": 0.001964338671720722,
        "auprc": 0.003089559023179079,
        "ap": 0.003094483024053828,
        "epr": 1.872798980071019,
        "odd_ratio": 1.8792563169522223,
    },
    "Loop of Henle_cellmap": {
        "precision": 0.002768556216724084,
        "rand_precision": 0.0027703435351338476,
        "auprc": 0.002832137484865851,
        "ap": 0.002893705694786363,
        "epr": 1.2249979525398744,
        "odd_ratio": 1.2265328971695306,
    },
    "Loop of Henle_gwps": {
        "precision": 0.01769601420573712,
        "rand_precision": 0.01770759536686653,
        "auprc": 0.03931138205956882,
        "ap": 0.041163393033549524,
        "epr": 3.930948408742879,
        "odd_ratio": 4.385913870846728,
    },
    "Loop of Henle_interact": {
        "precision": 0.002988486995568852,
        "rand_precision": 0.00298950626125629,
        "auprc": 0.0035740191356482248,
        "ap": 0.003578799193481954,
        "epr": 2.798147255991484,
        "odd_ratio": 2.828612270953828,
    },
    "Loop of Henle_interact_hq": {
        "precision": 0.0005347732521561882,
        "rand_precision": 0.0005349556441248636,
        "auprc": 0.0008291974093972697,
        "ap": 0.0008298397382536897,
        "epr": 7.243242974318198,
        "odd_ratio": 7.291908452744588,
    },
    "Epithelial cell_collectri": {
        "precision": 0.0014307207836572373,
        "rand_precision": 0.0014315147463562702,
        "auprc": 0.002222724029474912,
        "ap": 0.002237226521176974,
        "epr": 2.7035246857161823,
        "odd_ratio": 2.716787371109826,
    },
    "Epithelial cell_omnipath": {
        "precision": 0.0015545019752171024,
        "rand_precision": 0.0015550850592288116,
        "auprc": 0.002508869850817089,
        "ap": 0.0025136519921734385,
        "epr": 2.0936835573651753,
        "odd_ratio": 2.1008402424581605,
    },
    "Epithelial cell_cellmap": {
        "precision": 0.0025700488783087618,
        "rand_precision": 0.0025714878754410737,
        "auprc": 0.0025860332230780705,
        "ap": 0.0025966506823457505,
        "epr": 1.3563325570269875,
        "odd_ratio": 1.35883125,
    },
    "Epithelial cell_gwps": {
        "precision": 0.020576408515634702,
        "rand_precision": 0.02058742962357023,
        "auprc": 0.03852224643061224,
        "ap": 0.03977372329288779,
        "epr": 3.4979993031122327,
        "odd_ratio": 3.9007495036136106,
    },
    "Epithelial cell_interact": {
        "precision": 0.003325516866811766,
        "rand_precision": 0.0033266205896351356,
        "auprc": 0.00376181621917231,
        "ap": 0.0037774050966210004,
        "epr": 2.360328143865214,
        "odd_ratio": 2.3819447724913605,
    },
    "Epithelial cell_interact_hq": {
        "precision": 0.0005029854669496383,
        "rand_precision": 0.0005031524053721241,
        "auprc": 0.0007432074289854531,
        "ap": 0.0007550450546496432,
        "epr": 9.452886476520648,
        "odd_ratio": 9.533871752818067,
    },
    "Intercalated cell_collectri": {
        "precision": 0.0016556420841934072,
        "rand_precision": 0.0016565876250752994,
        "auprc": 0.002592782157361332,
        "ap": 0.002599925773062286,
        "epr": 1.3066028815733657,
        "odd_ratio": 1.307934488613104,
    },
    "Intercalated cell_omnipath": {
        "precision": 0.0017150386922127202,
        "rand_precision": 0.0017156803078850781,
        "auprc": 0.0028015218921272618,
        "ap": 0.002802831091185767,
        "epr": 1.9011960200947766,
        "odd_ratio": 1.9071040335818337,
    },
    "Intercalated cell_cellmap": {
        "precision": 0.0022007547734210786,
        "rand_precision": 0.0022020663078510076,
        "auprc": 0.00218205597766263,
        "ap": 0.002197481269201786,
        "epr": 0.5511152087849939,
        "odd_ratio": 0.5500236960177403,
    },
    "Intercalated cell_gwps": {
        "precision": 0.021055155319672985,
        "rand_precision": 0.021066944320411885,
        "auprc": 0.044367317258721325,
        "ap": 0.045368043625614876,
        "epr": 3.805185380247522,
        "odd_ratio": 4.315434181013659,
    },
    "Intercalated cell_interact": {
        "precision": 0.0033202743561688963,
        "rand_precision": 0.0033214075556078615,
        "auprc": 0.003836522817276675,
        "ap": 0.0038568003464906028,
        "epr": 2.6990477280317364,
        "odd_ratio": 2.7299250042723058,
    },
    "Intercalated cell_interact_hq": {
        "precision": 0.000577479560761717,
        "rand_precision": 0.000577676652761977,
        "auprc": 0.0008630355797273662,
        "ap": 0.000871223401494808,
        "epr": 8.99627242648995,
        "odd_ratio": 9.080037079571015,
    },
    "Endothelial cell (APC)_collectri": {
        "precision": 0.001200845478618044,
        "rand_precision": 0.0012015312841455242,
        "auprc": 0.0018456758693261121,
        "ap": 0.0018450135281207851,
        "epr": 1.3547552308171964,
        "odd_ratio": 1.3559129844045368,
    },
    "Endothelial cell (APC)_omnipath": {
        "precision": 0.0014393562374743463,
        "rand_precision": 0.001439881549969775,
        "auprc": 0.002276469359825681,
        "ap": 0.0022761081573660614,
        "epr": 2.2477857426732686,
        "odd_ratio": 2.255902155046973,
    },
    "Endothelial cell (APC)_cellmap": {
        "precision": 0.0024410482902542468,
        "rand_precision": 0.0024424021717241603,
        "auprc": 0.00249353527335202,
        "ap": 0.002507143116804185,
        "epr": 2.0745107241492637,
        "odd_ratio": 2.08548268175583,
    },
    "Endothelial cell (APC)_gwps": {
        "precision": 0.02184326416342992,
        "rand_precision": 0.02185454684120029,
        "auprc": 0.04377246518181342,
        "ap": 0.04594163705274328,
        "epr": 3.801445802812914,
        "odd_ratio": 4.332101853299244,
    },
    "Endothelial cell (APC)_interact": {
        "precision": 0.003367953925015091,
        "rand_precision": 0.003369066930277819,
        "auprc": 0.0037719648225747965,
        "ap": 0.003787886448380204,
        "epr": 2.2724588494065783,
        "odd_ratio": 2.292168970209985,
    },
    "Endothelial cell (APC)_interact_hq": {
        "precision": 0.0005464326552273234,
        "rand_precision": 0.0005466132344260104,
        "auprc": 0.000709931619135055,
        "ap": 0.0007213409022709268,
        "epr": 7.879180000326058,
        "odd_ratio": 7.938820404102992,
    },
    "Monocyte_collectri": {
        "precision": 0.0016847018347605363,
        "rand_precision": 0.0016856870405118584,
        "auprc": 0.0027055378996639094,
        "ap": 0.002715114095030862,
        "epr": 3.247609089456018,
        "odd_ratio": 3.272421513340628,
    },
    "Monocyte_omnipath": {
        "precision": 0.0016860794417895132,
        "rand_precision": 0.00168670951631933,
        "auprc": 0.002851691508934519,
        "ap": 0.0028603980179683257,
        "epr": 5.053847745375651,
        "odd_ratio": 5.123854636692763,
    },
    "Monocyte_cellmap": {
        "precision": 0.00243065695919019,
        "rand_precision": 0.002432002837905135,
        "auprc": 0.0024335701470472922,
        "ap": 0.002503028590822885,
        "epr": 1.5378540653213184,
        "odd_ratio": 1.5418999678716523,
    },
    "Monocyte_gwps": {
        "precision": 0.027794338292417717,
        "rand_precision": 0.02780808425596491,
        "auprc": 0.05084426840394064,
        "ap": 0.05285314850254981,
        "epr": 3.446004963094797,
        "odd_ratio": 3.9919481975819466,
    },
    "Monocyte_interact": {
        "precision": 0.0037083348454805495,
        "rand_precision": 0.0037095591224186415,
        "auprc": 0.004199570581257989,
        "ap": 0.00423747843446854,
        "epr": 2.2704318833910975,
        "odd_ratio": 2.2921052267760365,
    },
    "Monocyte_interact_hq": {
        "precision": 0.000681921525485882,
        "rand_precision": 0.0006821466563955834,
        "auprc": 0.0009090961596790301,
        "ap": 0.0009637160308985133,
        "epr": 11.036484137634218,
        "odd_ratio": 11.18932734075388,
    },
    "Macrophage_collectri": {
        "precision": 0.001525422824805722,
        "rand_precision": 0.0015263040627172214,
        "auprc": 0.002407516313008484,
        "ap": 0.002424732647266113,
        "epr": 2.8635377952467116,
        "odd_ratio": 2.879934881189775,
    },
    "Macrophage_omnipath": {
        "precision": 0.0016541599379445494,
        "rand_precision": 0.0016547829737027205,
        "auprc": 0.0027926793403765934,
        "ap": 0.0027943066180829107,
        "epr": 4.143003530826712,
        "odd_ratio": 4.186546224914573,
    },
    "Macrophage_cellmap": {
        "precision": 0.002460724720713958,
        "rand_precision": 0.00246215371300241,
        "auprc": 0.0024978322783110116,
        "ap": 0.0025422744696205106,
        "epr": 1.0256274869911235,
        "odd_ratio": 1.0257574106713667,
    },
    "Macrophage_gwps": {
        "precision": 0.02257643062451006,
        "rand_precision": 0.022589121142005567,
        "auprc": 0.037755352277540025,
        "ap": 0.038820887047525614,
        "epr": 3.2146712403311235,
        "odd_ratio": 3.575079422907708,
    },
    "Macrophage_interact": {
        "precision": 0.003513577168753223,
        "rand_precision": 0.003514752278174211,
        "auprc": 0.003858058239635541,
        "ap": 0.0038708651958536365,
        "epr": 1.8907387091723038,
        "odd_ratio": 1.9026965443311548,
    },
    "Macrophage_interact_hq": {
        "precision": 0.0006291519485994214,
        "rand_precision": 0.0006293623673113276,
        "auprc": 0.0007270419610041921,
        "ap": 0.0007294694414440774,
        "epr": 3.441681763088272,
        "odd_ratio": 3.4522939132656587,
    },
    "Smooth muscle cell_collectri": {
        "precision": 0.0015214809524205,
        "rand_precision": 0.001522358392416129,
        "auprc": 0.0024352013065892407,
        "ap": 0.002452439127830983,
        "epr": 3.2987199900840944,
        "odd_ratio": 3.3219826556062193,
    },
    "Smooth muscle cell_omnipath": {
        "precision": 0.0019526530612244898,
        "rand_precision": 0.001953397212543554,
        "auprc": 0.0029418679729150427,
        "ap": 0.002941384775408097,
        "epr": 3.462319379143576,
        "odd_ratio": 3.4959670821313313,
    },
    "Smooth muscle cell_cellmap": {
        "precision": 0.002630950135194617,
        "rand_precision": 0.0026325227294176864,
        "auprc": 0.0028085359261413086,
        "ap": 0.002830400787936774,
        "epr": 1.6342131455896816,
        "odd_ratio": 1.6397054637719473,
    },
    "Smooth muscle cell_gwps": {
        "precision": 0.02033723565503044,
        "rand_precision": 0.020349487001810582,
        "auprc": 0.03470059891919177,
        "ap": 0.03605819921456768,
        "epr": 3.3089231911661696,
        "odd_ratio": 3.6543489993759946,
    },
    "Smooth muscle cell_interact": {
        "precision": 0.0032318697180226475,
        "rand_precision": 0.0032329761438076605,
        "auprc": 0.0037180167679680626,
        "ap": 0.0037687775741136586,
        "epr": 2.4438166884012067,
        "odd_ratio": 2.4669045625465555,
    },
    "Smooth muscle cell_interact_hq": {
        "precision": 0.000547190603250755,
        "rand_precision": 0.0005473779331388929,
        "auprc": 0.0007418425977381517,
        "ap": 0.0008776930318661791,
        "epr": 8.976055665074009,
        "odd_ratio": 9.055014535294475,
    },
    "Dendritic cell_collectri": {
        "precision": 0.001863522261857577,
        "rand_precision": 0.0018645938675285704,
        "auprc": 0.0027259047673809404,
        "ap": 0.0027314137898254544,
        "epr": 1.9961903940932197,
        "odd_ratio": 2.0036478133170332,
    },
    "Dendritic cell_omnipath": {
        "precision": 0.0017944319338525608,
        "rand_precision": 0.0017951121582399196,
        "auprc": 0.002798594452030419,
        "ap": 0.0028004763985389814,
        "epr": 3.6106688618791756,
        "odd_ratio": 3.644843146200197,
    },
    "Dendritic cell_cellmap": {
        "precision": 0.0025644517066085695,
        "rand_precision": 0.0025660240252514933,
        "auprc": 0.0025314380326634015,
        "ap": 0.0025608717435735653,
        "epr": 0.8114689528407494,
        "odd_ratio": 0.8106813566341732,
    },
    "Dendritic cell_gwps": {
        "precision": 0.020591396571621734,
        "rand_precision": 0.020603552059562477,
        "auprc": 0.03864175414963547,
        "ap": 0.03999370373757901,
        "epr": 3.4559598150887267,
        "odd_ratio": 3.8469613010301305,
    },
    "Dendritic cell_interact": {
        "precision": 0.003302037721925473,
        "rand_precision": 0.003303175178943015,
        "auprc": 0.0036112244642770284,
        "ap": 0.0036262598227583933,
        "epr": 1.9380935049311543,
        "odd_ratio": 1.9502209284176317,
    },
    "Dendritic cell_interact_hq": {
        "precision": 0.0005689515475611732,
        "rand_precision": 0.0005691475350043566,
        "auprc": 0.0006875793699458869,
        "ap": 0.0006959668442221671,
        "epr": 5.504742348193061,
        "odd_ratio": 5.533102367346939,
    },
    "Sinusoidal endothelial cell_collectri": {
        "precision": 0.0011663718726676602,
        "rand_precision": 0.0011670711363802905,
        "auprc": 0.0018216943896828925,
        "ap": 0.001821697893649995,
        "epr": 2.373534068441259,
        "odd_ratio": 2.3811754115226336,
    },
    "Sinusoidal endothelial cell_omnipath": {
        "precision": 0.0015512639937125918,
        "rand_precision": 0.0015518634002016616,
        "auprc": 0.002382655775429879,
        "ap": 0.002385135497641302,
        "epr": 3.0986084478272544,
        "odd_ratio": 3.118937772625131,
    },
    "Sinusoidal endothelial cell_cellmap": {
        "precision": 0.0025586115193505492,
        "rand_precision": 0.002560163133370774,
        "auprc": 0.0025710453750921,
        "ap": 0.0025806307361208123,
        "epr": 1.7094096691868288,
        "odd_ratio": 1.7156599444511533,
    },
    "Sinusoidal endothelial cell_gwps": {
        "precision": 0.021321176929374845,
        "rand_precision": 0.021333416410964614,
        "auprc": 0.02788843442348146,
        "ap": 0.028375431250626994,
        "epr": 2.454220051678204,
        "odd_ratio": 2.6193492244310512,
    },
    "Sinusoidal endothelial cell_interact": {
        "precision": 0.0033618192206767007,
        "rand_precision": 0.0033629697406016416,
        "auprc": 0.003756156180402775,
        "ap": 0.003760701507275269,
        "epr": 1.6201566184222929,
        "odd_ratio": 1.6269701467749818,
    },
    "Sinusoidal endothelial cell_interact_hq": {
        "precision": 0.0005267574511549654,
        "rand_precision": 0.0005269377240677494,
        "auprc": 0.0006514168870591008,
        "ap": 0.0006574398220037912,
        "epr": 5.152282713294158,
        "odd_ratio": 5.17492119591174,
    },
}

# %%
metrics_v2 = {
    "Loop of Henle_collectri": {
        "rand_precision": 0.0016359932992993681,
        "auprc": 0.002282662116444059,
        "ap": 0.0022636083902423357,
        "epr": 3.4909235200106004,
        "odd_ratio": 3.5196210921397633,
    },
    "Loop of Henle_omnipath": {
        "rand_precision": 0.0019456495169911713,
        "auprc": 0.0025424094236147898,
        "ap": 0.0025309289314268553,
        "epr": 4.606905494127075,
        "odd_ratio": 4.672445812790847,
    },
    "Loop of Henle_cellmap": {
        "rand_precision": 0.002762858587135094,
        "auprc": 0.002910773015478242,
        "ap": 0.0028734215469562218,
        "epr": 2.0694337791978494,
        "odd_ratio": 2.0817685535730877,
    },
    "Loop of Henle_gwps": {
        "rand_precision": 0.017565207265952492,
        "auprc": 0.043945148073361515,
        "ap": 0.04660718289243268,
        "epr": 5.083100525593068,
        "odd_ratio": 5.922953959346351,
    },
    "Loop of Henle_interact": {
        "rand_precision": 0.0029842561668897995,
        "auprc": 0.003151896793700687,
        "ap": 0.00317994310590997,
        "epr": 2.1296802501654257,
        "odd_ratio": 2.1441777028526037,
    },
    "Loop of Henle_interact_hq": {
        "rand_precision": 0.0005284844575252994,
        "auprc": 0.000739821068978216,
        "ap": 0.0007987103469400719,
        "epr": 18.477419441351017,
        "odd_ratio": 18.82382007640058,
    },
    "Epithelial cell_collectri": {
        "rand_precision": 0.0014392279852820232,
        "auprc": 0.0020763286169975673,
        "ap": 0.002095233805878384,
        "epr": 3.946098889574066,
        "odd_ratio": 3.9798499124354074,
    },
    "Epithelial cell_omnipath": {
        "rand_precision": 0.0015432451033319371,
        "auprc": 0.0021542509409351977,
        "ap": 0.0022224151936037447,
        "epr": 3.654164529588358,
        "odd_ratio": 3.684354774233441,
    },
    "Epithelial cell_cellmap": {
        "rand_precision": 0.002557244744744745,
        "auprc": 0.0025522149153714407,
        "ap": 0.0026175593824335234,
        "epr": 1.7937884016496928,
        "odd_ratio": 1.8011212809785724,
    },
    "Epithelial cell_gwps": {
        "rand_precision": 0.02049057675736326,
        "auprc": 0.035173815210138897,
        "ap": 0.037285639545023036,
        "epr": 3.7121220355560283,
        "odd_ratio": 4.177056944982221,
    },
    "Epithelial cell_interact": {
        "rand_precision": 0.0033225144336255447,
        "auprc": 0.0033792674698514616,
        "ap": 0.003354588614012338,
        "epr": 1.9743529142428695,
        "odd_ratio": 1.987262957949657,
    },
    "Epithelial cell_interact_hq": {
        "rand_precision": 0.0004966417664830364,
        "auprc": 0.0006963549377337196,
        "ap": 0.0007864494371777102,
        "epr": 22.699689013365237,
        "odd_ratio": 23.197356701432334,
    },
    "Intercalated cell_collectri": {
        "rand_precision": 0.0016548209344465403,
        "auprc": 0.0021243696105543415,
        "ap": 0.002099706509615642,
        "epr": 2.17982160714214,
        "odd_ratio": 2.1883796242060933,
    },
    "Intercalated cell_omnipath": {
        "rand_precision": 0.0016980209078544424,
        "auprc": 0.002106678649936052,
        "ap": 0.0021528646843195116,
        "epr": 3.040224459078994,
        "odd_ratio": 3.0614534705630434,
    },
    "Intercalated cell_cellmap": {
        "rand_precision": 0.00221818397831229,
        "auprc": 0.0022861807346022367,
        "ap": 0.0022452605624009698,
        "epr": 1.920714931084084,
        "odd_ratio": 1.928610765717565,
    },
    "Intercalated cell_gwps": {
        "rand_precision": 0.020951043312194412,
        "auprc": 0.043274363616206415,
        "ap": 0.04590038816494998,
        "epr": 4.275600155922189,
        "odd_ratio": 4.951897452980428,
    },
    "Intercalated cell_interact": {
        "rand_precision": 0.0033230202664748486,
        "auprc": 0.003466839218478561,
        "ap": 0.0034824741404085387,
        "epr": 2.3517789459522334,
        "odd_ratio": 2.37315755885874,
    },
    "Intercalated cell_interact_hq": {
        "rand_precision": 0.0005751697252847194,
        "auprc": 0.0008640195072133508,
        "ap": 0.0009876908945003033,
        "epr": 23.612041223371566,
        "odd_ratio": 24.23896866067221,
    },
    "Endothelial cell (APC)_collectri": {
        "rand_precision": 0.001193937527490898,
        "auprc": 0.002652003848745912,
        "ap": 0.0027680621824955963,
        "epr": 7.633150267003192,
        "odd_ratio": 7.75572584012856,
    },
    "Endothelial cell (APC)_omnipath": {
        "rand_precision": 0.0014239943518067372,
        "auprc": 0.002758132167399729,
        "ap": 0.00295096117166068,
        "epr": 8.075643050719435,
        "odd_ratio": 8.24122894089045,
    },
    "Endothelial cell (APC)_cellmap": {
        "rand_precision": 0.002443312211577018,
        "auprc": 0.00253510616735883,
        "ap": 0.0025593472029325085,
        "epr": 1.3282166782837046,
        "odd_ratio": 1.330357382368848,
    },
    "Endothelial cell (APC)_gwps": {
        "rand_precision": 0.02169294439681621,
        "auprc": 0.03735717437689501,
        "ap": 0.03929518862818504,
        "epr": 3.687982981665,
        "odd_ratio": 4.175805455805216,
    },
    "Endothelial cell (APC)_interact": {
        "rand_precision": 0.0033766501922361885,
        "auprc": 0.0034652382465303793,
        "ap": 0.003501183689321972,
        "epr": 1.7311975690315762,
        "odd_ratio": 1.739821764259858,
    },
    "Endothelial cell (APC)_interact_hq": {
        "rand_precision": 0.0005470934291620644,
        "auprc": 0.000733396622511733,
        "ap": 0.0007981234310176039,
        "epr": 20.287356778386876,
        "odd_ratio": 20.722735566633187,
    },
    "Monocyte_collectri": {
        "rand_precision": 0.0016774573278399059,
        "auprc": 0.002820830742784856,
        "ap": 0.0029992246019477126,
        "epr": 4.921695363279198,
        "odd_ratio": 4.987260711992472,
    },
    "Monocyte_omnipath": {
        "rand_precision": 0.0016683976503728663,
        "auprc": 0.0026974754350269662,
        "ap": 0.0028621445783912577,
        "epr": 5.9755444493695,
        "odd_ratio": 6.076256236148104,
    },
    "Monocyte_cellmap": {
        "rand_precision": 0.0024328652377432866,
        "auprc": 0.002476956740609975,
        "ap": 0.0024723752746070343,
        "epr": 0.9635208032900711,
        "odd_ratio": 0.9633491771015885,
    },
    "Monocyte_gwps": {
        "rand_precision": 0.027718457180213554,
        "auprc": 0.04428533084726767,
        "ap": 0.04595792003895931,
        "epr": 3.2648846521549397,
        "odd_ratio": 3.7380309751124763,
    },
    "Monocyte_interact": {
        "rand_precision": 0.0037169012033989183,
        "auprc": 0.003937728117568566,
        "ap": 0.0040324321569094115,
        "epr": 2.1686516586732885,
        "odd_ratio": 2.18772214543833,
    },
    "Monocyte_interact_hq": {
        "rand_precision": 0.0006798637133146073,
        "auprc": 0.0009271903740390261,
        "ap": 0.0010766012765255895,
        "epr": 14.73766488191717,
        "odd_ratio": 15.017150243077113,
    },
    "Macrophage_collectri": {
        "rand_precision": 0.0015230719324728552,
        "auprc": 0.002618488300089903,
        "ap": 0.0026897946984723786,
        "epr": 4.525033802879833,
        "odd_ratio": 4.574129492957558,
    },
    "Macrophage_omnipath": {
        "rand_precision": 0.00164117153867888,
        "auprc": 0.0029258096232203787,
        "ap": 0.003009569832289106,
        "epr": 7.531051602035135,
        "odd_ratio": 7.695539115279812,
    },
    "Macrophage_cellmap": {
        "rand_precision": 0.002453174667042208,
        "auprc": 0.002571125262542654,
        "ap": 0.002604012278582286,
        "epr": 1.2536188383725204,
        "odd_ratio": 1.2551859953344215,
    },
    "Macrophage_gwps": {
        "rand_precision": 0.02248232363063858,
        "auprc": 0.032618568192184734,
        "ap": 0.03406044972530559,
        "epr": 3.0537422032728,
        "odd_ratio": 3.3676906472744124,
    },
    "Macrophage_interact": {
        "rand_precision": 0.003524620282424501,
        "auprc": 0.0036199484361328976,
        "ap": 0.0035976618223654755,
        "epr": 1.6559982827543882,
        "odd_ratio": 1.6637236694777184,
    },
    "Macrophage_interact_hq": {
        "rand_precision": 0.0006306205690455784,
        "auprc": 0.0006969204638996002,
        "ap": 0.0007229077696905029,
        "epr": 4.635535939208446,
        "odd_ratio": 4.656884770880116,
    },
    "Smooth muscle cell_collectri": {
        "rand_precision": 0.0015190397323092708,
        "auprc": 0.0024953667827766514,
        "ap": 0.0025891220592820265,
        "epr": 5.1122413971432845,
        "odd_ratio": 5.176862003209795,
    },
    "Smooth muscle cell_omnipath": {
        "rand_precision": 0.0019321307015964383,
        "auprc": 0.0028476364670979954,
        "ap": 0.0029443955153711514,
        "epr": 5.145389408504631,
        "odd_ratio": 5.229058346333281,
    },
    "Smooth muscle cell_cellmap": {
        "rand_precision": 0.0026352623810250927,
        "auprc": 0.002825630971687615,
        "ap": 0.0028624864964786937,
        "epr": 2.748446564162012,
        "odd_ratio": 2.774051982240458,
    },
    "Smooth muscle cell_gwps": {
        "rand_precision": 0.02020631731260093,
        "auprc": 0.03127455266287001,
        "ap": 0.0333780203864632,
        "epr": 3.4335297239580056,
        "odd_ratio": 3.8099005550787366,
    },
    "Smooth muscle cell_interact": {
        "rand_precision": 0.003235111067413639,
        "auprc": 0.003439767612444005,
        "ap": 0.003437955035785754,
        "epr": 2.302950482552473,
        "odd_ratio": 2.3225843721560633,
    },
    "Smooth muscle cell_interact_hq": {
        "rand_precision": 0.0005457001068709316,
        "auprc": 0.0007079224768676837,
        "ap": 0.000746780538948123,
        "epr": 10.732113297419662,
        "odd_ratio": 10.847115115575404,
    },
    "Dendritic cell_collectri": {
        "rand_precision": 0.001859760020588046,
        "auprc": 0.002644326858313376,
        "ap": 0.002696235252075711,
        "epr": 3.1971576333089846,
        "odd_ratio": 3.2235208924158782,
    },
    "Dendritic cell_omnipath": {
        "rand_precision": 0.0017775842044134727,
        "auprc": 0.0028246817130266385,
        "ap": 0.0029408391330979808,
        "epr": 5.421612874065301,
        "odd_ratio": 5.508086391476554,
    },
    "Dendritic cell_cellmap": {
        "rand_precision": 0.0025580495979632286,
        "auprc": 0.0027925742167534268,
        "ap": 0.002869180933434113,
        "epr": 1.231253022506045,
        "odd_ratio": 1.2327166455779919,
    },
    "Dendritic cell_gwps": {
        "rand_precision": 0.020454460395113214,
        "auprc": 0.03683359081169653,
        "ap": 0.03923740986789844,
        "epr": 4.0036993449148826,
        "odd_ratio": 4.563447335965374,
    },
    "Dendritic cell_interact": {
        "rand_precision": 0.003318854825111794,
        "auprc": 0.0034858634093732138,
        "ap": 0.0034477632158848356,
        "epr": 1.7525640659995996,
        "odd_ratio": 1.7613956307240393,
    },
    "Dendritic cell_interact_hq": {
        "rand_precision": 0.000569395041131537,
        "auprc": 0.0007010046221224446,
        "ap": 0.0007423847662944385,
        "epr": 4.551180349019614,
        "odd_ratio": 4.569657336563745,
    },
    "Sinusoidal endothelial cell_collectri": {
        "rand_precision": 0.0011599888046320834,
        "auprc": 0.0016858197221383652,
        "ap": 0.001822892450220629,
        "epr": 6.500111484106631,
        "odd_ratio": 6.5840013924850895,
    },
    "Sinusoidal endothelial cell_omnipath": {
        "rand_precision": 0.00153195683704817,
        "auprc": 0.0020892910129133254,
        "ap": 0.0021378577859509826,
        "epr": 5.790300757375202,
        "odd_ratio": 5.876429702496568,
    },
    "Sinusoidal endothelial cell_cellmap": {
        "rand_precision": 0.0025693352040020976,
        "auprc": 0.0026889458901017817,
        "ap": 0.00280352407697694,
        "epr": 1.50272485076677,
        "odd_ratio": 1.5066294951367964,
    },
    "Sinusoidal endothelial cell_gwps": {
        "rand_precision": 0.021422001822973387,
        "auprc": 0.028545874114740567,
        "ap": 0.03055632742549158,
        "epr": 2.7094199848864986,
        "odd_ratio": 2.9265707455498564,
    },
    "Sinusoidal endothelial cell_interact": {
        "rand_precision": 0.0033598258991705842,
        "auprc": 0.0035586341951844235,
        "ap": 0.003648945564631658,
        "epr": 2.3384129481286338,
        "odd_ratio": 2.359694331303643,
    },
    "Sinusoidal endothelial cell_interact_hq": {
        "rand_precision": 0.0005246842964451795,
        "auprc": 0.0006247460143123432,
        "ap": 0.0006927765389010225,
        "epr": 7.597915991364024,
        "odd_ratio": 7.650837518048242,
    },
}

# %% [markdown]
# # Plot of the scores

# %%
import pandas as pd

# %%
pd.DataFrame.from_dict(metrics_v2, orient="index")
# Out:
#                                          rand_precision     auprc        ap  \
# Loop of Henle_collectri                        0.001636  0.002283  0.002264
# Loop of Henle_omnipath                         0.001946  0.002542  0.002531
# Loop of Henle_cellmap                          0.002763  0.002911  0.002873
# Loop of Henle_gwps                             0.017565  0.043945  0.046607
# Loop of Henle_interact                         0.002984  0.003152  0.003180
# Loop of Henle_interact_hq                      0.000528  0.000740  0.000799
# Epithelial cell_collectri                      0.001439  0.002076  0.002095
# Epithelial cell_omnipath                       0.001543  0.002154  0.002222
# Epithelial cell_cellmap                        0.002557  0.002552  0.002618
# Epithelial cell_gwps                           0.020491  0.035174  0.037286
# Epithelial cell_interact                       0.003323  0.003379  0.003355
# Epithelial cell_interact_hq                    0.000497  0.000696  0.000786
# Intercalated cell_collectri                    0.001655  0.002124  0.002100
# Intercalated cell_omnipath                     0.001698  0.002107  0.002153
# Intercalated cell_cellmap                      0.002218  0.002286  0.002245
# Intercalated cell_gwps                         0.020951  0.043274  0.045900
# Intercalated cell_interact                     0.003323  0.003467  0.003482
# Intercalated cell_interact_hq                  0.000575  0.000864  0.000988
# Endothelial cell (APC)_collectri               0.001194  0.002652  0.002768
# Endothelial cell (APC)_omnipath                0.001424  0.002758  0.002951
# Endothelial cell (APC)_cellmap                 0.002443  0.002535  0.002559
# Endothelial cell (APC)_gwps                    0.021693  0.037357  0.039295
# Endothelial cell (APC)_interact                0.003377  0.003465  0.003501
# Endothelial cell (APC)_interact_hq             0.000547  0.000733  0.000798
# Monocyte_collectri                             0.001677  0.002821  0.002999
# Monocyte_omnipath                              0.001668  0.002697  0.002862
# Monocyte_cellmap                               0.002433  0.002477  0.002472
# Monocyte_gwps                                  0.027718  0.044285  0.045958
# Monocyte_interact                              0.003717  0.003938  0.004032
# Monocyte_interact_hq                           0.000680  0.000927  0.001077
# Macrophage_collectri                           0.001523  0.002618  0.002690
# Macrophage_omnipath                            0.001641  0.002926  0.003010
# Macrophage_cellmap                             0.002453  0.002571  0.002604
# Macrophage_gwps                                0.022482  0.032619  0.034060
# Macrophage_interact                            0.003525  0.003620  0.003598
# Macrophage_interact_hq                         0.000631  0.000697  0.000723
# Smooth muscle cell_collectri                   0.001519  0.002495  0.002589
# Smooth muscle cell_omnipath                    0.001932  0.002848  0.002944
# Smooth muscle cell_cellmap                     0.002635  0.002826  0.002862
# Smooth muscle cell_gwps                        0.020206  0.031275  0.033378
# Smooth muscle cell_interact                    0.003235  0.003440  0.003438
# Smooth muscle cell_interact_hq                 0.000546  0.000708  0.000747
# Dendritic cell_collectri                       0.001860  0.002644  0.002696
# Dendritic cell_omnipath                        0.001778  0.002825  0.002941
# Dendritic cell_cellmap                         0.002558  0.002793  0.002869
# Dendritic cell_gwps                            0.020454  0.036834  0.039237
# Dendritic cell_interact                        0.003319  0.003486  0.003448
# Dendritic cell_interact_hq                     0.000569  0.000701  0.000742
# Sinusoidal endothelial cell_collectri          0.001160  0.001686  0.001823
# Sinusoidal endothelial cell_omnipath           0.001532  0.002089  0.002138
# Sinusoidal endothelial cell_cellmap            0.002569  0.002689  0.002804
# Sinusoidal endothelial cell_gwps               0.021422  0.028546  0.030556
# Sinusoidal endothelial cell_interact           0.003360  0.003559  0.003649
# Sinusoidal endothelial cell_interact_hq        0.000525  0.000625  0.000693
#
#                                                epr  odd_ratio
# Loop of Henle_collectri                   3.490924   3.519621
# Loop of Henle_omnipath                    4.606905   4.672446
# Loop of Henle_cellmap                     2.069434   2.081769
# Loop of Henle_gwps                        5.083101   5.922954
# Loop of Henle_interact                    2.129680   2.144178
# Loop of Henle_interact_hq                18.477419  18.823820
# Epithelial cell_collectri                 3.946099   3.979850
# Epithelial cell_omnipath                  3.654165   3.684355
# Epithelial cell_cellmap                   1.793788   1.801121
# Epithelial cell_gwps                      3.712122   4.177057
# Epithelial cell_interact                  1.974353   1.987263
# Epithelial cell_interact_hq              22.699689  23.197357
# Intercalated cell_collectri               2.179822   2.188380
# Intercalated cell_omnipath                3.040224   3.061453
# Intercalated cell_cellmap                 1.920715   1.928611
# Intercalated cell_gwps                    4.275600   4.951897
# Intercalated cell_interact                2.351779   2.373158
# Intercalated cell_interact_hq            23.612041  24.238969
# Endothelial cell (APC)_collectri          7.633150   7.755726
# Endothelial cell (APC)_omnipath           8.075643   8.241229
# Endothelial cell (APC)_cellmap            1.328217   1.330357
# Endothelial cell (APC)_gwps               3.687983   4.175805
# Endothelial cell (APC)_interact           1.731198   1.739822
# Endothelial cell (APC)_interact_hq       20.287357  20.722736
# Monocyte_collectri                        4.921695   4.987261
# Monocyte_omnipath                         5.975544   6.076256
# Monocyte_cellmap                          0.963521   0.963349
# Monocyte_gwps                             3.264885   3.738031
# Monocyte_interact                         2.168652   2.187722
# Monocyte_interact_hq                     14.737665  15.017150
# Macrophage_collectri                      4.525034   4.574129
# Macrophage_omnipath                       7.531052   7.695539
# Macrophage_cellmap                        1.253619   1.255186
# Macrophage_gwps                           3.053742   3.367691
# Macrophage_interact                       1.655998   1.663724
# Macrophage_interact_hq                    4.635536   4.656885
# Smooth muscle cell_collectri              5.112241   5.176862
# Smooth muscle cell_omnipath               5.145389   5.229058
# Smooth muscle cell_cellmap                2.748447   2.774052
# Smooth muscle cell_gwps                   3.433530   3.809901
# Smooth muscle cell_interact               2.302950   2.322584
# Smooth muscle cell_interact_hq           10.732113  10.847115
# Dendritic cell_collectri                  3.197158   3.223521
# Dendritic cell_omnipath                   5.421613   5.508086
# Dendritic cell_cellmap                    1.231253   1.232717
# Dendritic cell_gwps                       4.003699   4.563447
# Dendritic cell_interact                   1.752564   1.761396
# Dendritic cell_interact_hq                4.551180   4.569657
# Sinusoidal endothelial cell_collectri     6.500111   6.584001
# Sinusoidal endothelial cell_omnipath      5.790301   5.876430
# Sinusoidal endothelial cell_cellmap       1.502725   1.506629
# Sinusoidal endothelial cell_gwps          2.709420   2.926571
# Sinusoidal endothelial cell_interact      2.338413   2.359694
# Sinusoidal endothelial cell_interact_hq   7.597916   7.650838

# %%
show = {}
for k, v in metrics_v1.items():
    gt = k.split("_")[-1]
    if gt + "_auprc" in show:
        show[gt + "_auprc"].append(v["auprc"] / v["rand_precision"])
    else:
        show[gt + "_auprc"] = [v["auprc"] / v["rand_precision"]]
    if gt + "_odd_ratio" in show:
        show[gt + "_odd_ratio"].append(v["odd_ratio"])
    else:
        show[gt + "_odd_ratio"] = [v["odd_ratio"]]
    print(k)
# Out:
# Loop of Henle_collectri
# Loop of Henle_omnipath
# Loop of Henle_cellmap
# Loop of Henle_gwps
# Loop of Henle_interact
# Loop of Henle_interact_hq
# Epithelial cell_collectri
# Epithelial cell_omnipath
# Epithelial cell_cellmap
# Epithelial cell_gwps
# Epithelial cell_interact
# Epithelial cell_interact_hq
# Intercalated cell_collectri
# Intercalated cell_omnipath
# Intercalated cell_cellmap
# Intercalated cell_gwps
# Intercalated cell_interact
# Intercalated cell_interact_hq
# Endothelial cell (APC)_collectri
# Endothelial cell (APC)_omnipath
# Endothelial cell (APC)_cellmap
# Endothelial cell (APC)_gwps
# Endothelial cell (APC)_interact
# Endothelial cell (APC)_interact_hq
# Monocyte_collectri
# Monocyte_omnipath
# Monocyte_cellmap
# Monocyte_gwps
# Monocyte_interact
# Monocyte_interact_hq
# Macrophage_collectri
# Macrophage_omnipath
# Macrophage_cellmap
# Macrophage_gwps
# Macrophage_interact
# Macrophage_interact_hq
# Smooth muscle cell_collectri
# Smooth muscle cell_omnipath
# Smooth muscle cell_cellmap
# Smooth muscle cell_gwps
# Smooth muscle cell_interact
# Smooth muscle cell_interact_hq
# Dendritic cell_collectri
# Dendritic cell_omnipath
# Dendritic cell_cellmap
# Dendritic cell_gwps
# Dendritic cell_interact
# Dendritic cell_interact_hq
# Sinusoidal endothelial cell_collectri
# Sinusoidal endothelial cell_omnipath
# Sinusoidal endothelial cell_cellmap
# Sinusoidal endothelial cell_gwps
# Sinusoidal endothelial cell_interact
# Sinusoidal endothelial cell_interact_hq

# %%
show
# Out:
# {'collectri_auprc': [1.5286830346727127,
#   1.552707742014226,
#   1.5651343268023497,
#   1.5361030492341072,
#   1.6050060507331025,
#   1.577350392897778,
#   1.5996241875241626,
#   1.4619294929860498,
#   1.5609111843284356],
#  'collectri_odd_ratio': [1.7787460617116801,
#   2.716787371109826,
#   1.307934488613104,
#   1.3559129844045368,
#   3.272421513340628,
#   2.879934881189775,
#   3.3219826556062193,
#   2.0036478133170332,
#   2.3811754115226336],
#  'omnipath_auprc': [1.5728240082310685,
#   1.613332875862927,
#   1.6328927243914704,
#   1.5810115490912895,
#   1.6906832393744753,
#   1.6876408476259162,
#   1.5060265029683253,
#   1.5590081317116133,
#   1.535351484621815],
#  'omnipath_odd_ratio': [1.8792563169522223,
#   2.1008402424581605,
#   1.9071040335818337,
#   2.255902155046973,
#   5.123854636692763,
#   4.186546224914573,
#   3.4959670821313313,
#   3.644843146200197,
#   3.118937772625131],
#  'cellmap_auprc': [1.022305518773511,
#   1.005656393629506,
#   0.9909129302251095,
#   1.0209355781860296,
#   1.0006444520202564,
#   1.0144907952416562,
#   1.0668610359016943,
#   0.9865215632247628,
#   1.0042506048069673],
#  'cellmap_odd_ratio': [1.2265328971695306,
#   1.35883125,
#   0.5500236960177403,
#   2.08548268175583,
#   1.5418999678716523,
#   1.0257574106713667,
#   1.6397054637719473,
#   0.8106813566341732,
#   1.7156599444511533],
#  'gwps_auprc': [2.2200293854198914,
#   1.8711537639700644,
#   2.1060157839660483,
#   2.0028996940487174,
#   1.828398818700875,
#   1.6713953606336687,
#   1.7052321228591318,
#   1.8754899173660273,
#   1.3072652727646472],
#  'gwps_odd_ratio': [4.385913870846728,
#   3.9007495036136106,
#   4.315434181013659,
#   4.332101853299244,
#   3.9919481975819466,
#   3.575079422907708,
#   3.6543489993759946,
#   3.8469613010301305,
#   2.6193492244310512],
#  'interact_auprc': [1.195521542124586,
#   1.13082214151296,
#   1.1550894471830453,
#   1.1195873815020212,
#   1.1320942577456103,
#   1.0976757205886685,
#   1.1500291380403265,
#   1.0932585372092152,
#   1.1169164369973759],
#  'interact_odd_ratio': [2.828612270953828,
#   2.3819447724913605,
#   2.7299250042723058,
#   2.292168970209985,
#   2.2921052267760365,
#   1.9026965443311548,
#   2.4669045625465555,
#   1.9502209284176317,
#   1.6269701467749818],
#  'hq_auprc': [1.5500302099882646,
#   1.4771020093519933,
#   1.4939769083639374,
#   1.2987823463157502,
#   1.332698989514414,
#   1.1552040585301555,
#   1.355265809646577,
#   1.20808635311163,
#   1.2362312609361534],
#  'hq_odd_ratio': [7.291908452744588,
#   9.533871752818067,
#   9.080037079571015,
#   7.938820404102992,
#   11.18932734075388,
#   3.4522939132656587,
#   9.055014535294475,
#   5.533102367346939,
#   5.17492119591174]}

# %%
df = pd.DataFrame(
    {i: v for i, v in show.items() if "_odd_ratio" in i},
    index=[
        "Loop of Henle",
        "Epithelial cell",
        "Intercalated cell",
        "Endothelial cell (APC)",
        "Monocyte",
        "Macrophage",
        "Smooth muscle cell",
        "Dendritic cell",
        "Sinusoidal endothelial cell",
    ],
)

# Clean column names (remove '_odd_ratio' suffix)
df.columns = [col.replace("_odd_ratio", "") for col in df.columns]

# Long format for seaborn
df_long = df.reset_index().melt(
    id_vars="index", var_name="Database", value_name="OR"
)
df_long = df_long.rename(columns={"index": "Cell Type"})
df_long["method"] = "scPRINT-V1"

# %%
df = pd.DataFrame(
    {i: v for i, v in show.items() if "_auprc" in i},
    index=[
        "Loop of Henle",
        "Epithelial cell",
        "Intercalated cell",
        "Endothelial cell (APC)",
        "Monocyte",
        "Macrophage",
        "Smooth muscle cell",
        "Dendritic cell",
        "Sinusoidal endothelial cell",
    ],
)

# Clean column names (remove '_auprc' suffix)
df.columns = [col.replace("_auprc", "") for col in df.columns]

# Long format for seaborn
df_long = df.reset_index().melt(
    id_vars="index", var_name="Database", value_name="AUPRC"
)
df_long = df_long.rename(columns={"index": "Cell Type"})
df_long["method"] = "scPRINT-V1"

# %%
show = {}
for k, v in metrics_v2.items():
    gt = k.split("_")[-1]
    if gt + "_auprc" in show:
        show[gt + "_auprc"].append(v["auprc"] / v["rand_precision"])
    else:
        show[gt + "_auprc"] = [v["auprc"] / v["rand_precision"]]
    if gt + "_odd_ratio" in show:
        show[gt + "_odd_ratio"].append(v["odd_ratio"])
    else:
        show[gt + "_odd_ratio"] = [v["odd_ratio"]]
    print(k)
# Out:
# Loop of Henle_collectri
# Loop of Henle_omnipath
# Loop of Henle_cellmap
# Loop of Henle_gwps
# Loop of Henle_interact
# Loop of Henle_interact_hq
# Epithelial cell_collectri
# Epithelial cell_omnipath
# Epithelial cell_cellmap
# Epithelial cell_gwps
# Epithelial cell_interact
# Epithelial cell_interact_hq
# Intercalated cell_collectri
# Intercalated cell_omnipath
# Intercalated cell_cellmap
# Intercalated cell_gwps
# Intercalated cell_interact
# Intercalated cell_interact_hq
# Endothelial cell (APC)_collectri
# Endothelial cell (APC)_omnipath
# Endothelial cell (APC)_cellmap
# Endothelial cell (APC)_gwps
# Endothelial cell (APC)_interact
# Endothelial cell (APC)_interact_hq
# Monocyte_collectri
# Monocyte_omnipath
# Monocyte_cellmap
# Monocyte_gwps
# Monocyte_interact
# Monocyte_interact_hq
# Macrophage_collectri
# Macrophage_omnipath
# Macrophage_cellmap
# Macrophage_gwps
# Macrophage_interact
# Macrophage_interact_hq
# Smooth muscle cell_collectri
# Smooth muscle cell_omnipath
# Smooth muscle cell_cellmap
# Smooth muscle cell_gwps
# Smooth muscle cell_interact
# Smooth muscle cell_interact_hq
# Dendritic cell_collectri
# Dendritic cell_omnipath
# Dendritic cell_cellmap
# Dendritic cell_gwps
# Dendritic cell_interact
# Dendritic cell_interact_hq
# Sinusoidal endothelial cell_collectri
# Sinusoidal endothelial cell_omnipath
# Sinusoidal endothelial cell_cellmap
# Sinusoidal endothelial cell_gwps
# Sinusoidal endothelial cell_interact
# Sinusoidal endothelial cell_interact_hq

# %%
df = pd.DataFrame(
    {i: v for i, v in show.items() if "_odd_ratio" in i},
    index=[
        "Loop of Henle",
        "Epithelial cell",
        "Intercalated cell",
        "Endothelial cell (APC)",
        "Monocyte",
        "Macrophage",
        "Smooth muscle cell",
        "Dendritic cell",
        "Sinusoidal endothelial cell",
    ],
)

# Clean column names (remove '_odd_ratio' suffix)
df.columns = [col.replace("_odd_ratio", "") for col in df.columns]

# Long format for seaborn
df_long2 = df.reset_index().melt(
    id_vars="index", var_name="Database", value_name="OR"
)
df_long2 = df_long2.rename(columns={"index": "Cell Type"})
df_long2["method"] = "scPRINT-V2"

# %%
df = pd.DataFrame(
    {i: v for i, v in show.items() if "_aupr" in i},
    index=[
        "Loop of Henle",
        "Epithelial cell",
        "Intercalated cell",
        "Endothelial cell (APC)",
        "Monocyte",
        "Macrophage",
        "Smooth muscle cell",
        "Dendritic cell",
        "Sinusoidal endothelial cell",
    ],
)

# Clean column names (remove '_aupr' suffix)
df.columns = [col.replace("_aupr", "") for col in df.columns]

# Long format for seaborn
df_long2 = df.reset_index().melt(
    id_vars="index", var_name="Database", value_name="AUPRC"
)
df_long2 = df_long2.rename(columns={"index": "Cell Type"})
df_long2["method"] = "scPRINT-V2"

# %%
df_long = pd.concat([df_long, df_long2])

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import ttest_1samp

# Font sizes
FS_TITLE = 20
FS_LABEL = 18
FS_TICK = 20
FS_LEGEND = 16
FS_PVAL = 13

plt.figure(figsize=(12, 7))
ax = sns.boxplot(
    data=df_long,
    x="Database",
    y="OR",
    hue="method",
    fliersize=0,
    palette="Set2",
    showmeans=True,
    meanprops={"marker": "d", "markerfacecolor": "white", "markeredgecolor": "black"},
)
sns.stripplot(
    data=df_long,
    x="Database",
    y="OR",
    hue="method",
    palette=["black", "black"],
    dodge=True,
    alpha=0.4,
    size=5,
    legend=False,
)

ax.axhline(1, ls="--", c="gray", lw=1)

max_y = df_long2["OR"].max()
min_y = df_long2["OR"].min()
span = max(max_y - min_y, 1e-6)
offset = 0.08 * span

for i, col in enumerate(df.columns):
    x = df[col].dropna().values
    stat, p = ttest_1samp(x, 1.0, nan_policy="omit")
    y = df[col].max() + offset
    ax.text(i, y, f"p={p:.2e}", ha="left", va="bottom", fontsize=FS_PVAL)

ax.set_ylim(min_y - offset, max_y + 3 * offset)
#ax.set_title("OR by Database (p-values vs 1)", fontsize=FS_TITLE)
ax.set_xlabel("Database", fontsize=FS_LABEL)
ax.set_ylabel("OR", fontsize=FS_LABEL)
ax.tick_params(axis="both", labelsize=FS_TICK)

leg = ax.get_legend()
if leg is not None:
    leg.set_title("method")
    leg.get_title().set_fontsize(FS_LEGEND)
    for t in leg.get_texts():
        t.set_fontsize(FS_LEGEND)

plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import ttest_1samp

# Font sizes
FS_TITLE = 20
FS_LABEL = 18
FS_TICK = 20
FS_LEGEND = 16
FS_PVAL = 13

plt.figure(figsize=(12, 7))
ax = sns.boxplot(
    data=df_long,
    x="Database",
    y="AUPRC",
    hue="method",
    fliersize=0,
    palette="Set2",
    showmeans=True,
    meanprops={"marker": "d", "markerfacecolor": "white", "markeredgecolor": "black"},
)
sns.stripplot(
    data=df_long,
    x="Database",
    y="AUPRC",
    hue="method",
    palette=["black", "black"],
    dodge=True,
    alpha=0.4,
    size=5,
    legend=False,
)

ax.axhline(1, ls="--", c="gray", lw=1)

max_y = df_long2["AUPRC"].max()
min_y = df_long2["AUPRC"].min()
span = max(max_y - min_y, 1e-6)
offset = 0.08 * span

for i, col in enumerate(df.columns):
    x = df[col].dropna().values
    stat, p = ttest_1samp(x, 1.0, nan_policy="omit")
    y = df[col].max() + offset
    ax.text(i, y, f"p={p:.2e}", ha="left", va="bottom", fontsize=FS_PVAL)

ax.set_ylim(min_y - offset, max_y + 3 * offset)
#ax.set_title("AUPRC by Database (p-values vs 1)", fontsize=FS_TITLE)
ax.set_xlabel("Database", fontsize=FS_LABEL)
ax.set_ylabel("AUPRC", fontsize=FS_LABEL)
ax.tick_params(axis="both", labelsize=FS_TICK)

leg = ax.get_legend()
if leg is not None:
    leg.set_title("method")
    leg.get_title().set_fontsize(FS_LEGEND)
    for t in leg.get_texts():
        t.set_fontsize(FS_LEGEND)

plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import ttest_1samp

df = pd.DataFrame(
    {i: v for i, v in show.items() if "_odd_ratio" in i},
    index=[
        "Loop of Henle",
        "Epithelial cell",
        "Intercalated cell",
        "Endothelial cell (APC)",
        "Monocyte",
        "Macrophage",
        "Smooth muscle cell",
        "Dendritic cell",
        "Sinusoidal endothelial cell",
    ],
)

# Clean column names (remove '_auprc' suffix)
df.columns = [col.replace("_odd_ratio", "") for col in df.columns]

# Long format for seaborn
df_long = df.reset_index().melt(id_vars="index", var_name="Database", value_name="OR")
df_long = df_long.rename(columns={"index": "Cell Type"})

plt.figure(figsize=(10, 6))
ax = sns.boxplot(data=df_long, x="Database", y="OR")
sns.stripplot(data=df_long, x="Database", y="OR", color="k", alpha=0.6, size=5)

# Reference line at 1
ax.axhline(1, ls="--", c="gray", lw=1)

# Compute and annotate p-values (one-sample test vs 0)
max_y = df_long["OR"].max()
min_y = df_long["OR"].min()
span = max(max_y - min_y, 1e-6)
offset = 0.08 * span

for i, col in enumerate(df.columns):
    x = df[col].dropna().values
    stat, p = ttest_1samp(x, 1.0, nan_policy="omit")
    y = df[col].max() + offset
    ax.text(i, y, f"p={p:.2e}", ha="center", va="bottom", fontsize=9)

ax.set_ylim(min_y - offset, max_y + 3 * offset)
plt.title("OR by Database (p-values vs 1)")
plt.xlabel("Database")
plt.ylabel("OR")
plt.tight_layout()
plt.show()

# %%
df = pd.DataFrame(
    {i: v for i, v in show.items() if "_auprc" in i},
    index=[
        "Loop of Henle",
        "Epithelial cell",
        "Intercalated cell",
        "Endothelial cell (APC)",
        "Monocyte",
        "Macrophage",
        "Smooth muscle cell",
        "Dendritic cell",
        "Sinusoidal endothelial cell",
    ],
)

# Long format for seaborn
df_long = df.reset_index().melt(
    id_vars="index", var_name="Database", value_name="DeltaAUPRC"
)
df_long = df_long.rename(columns={"index": "Cell Type"})

plt.figure(figsize=(10, 6))
ax = sns.boxplot(data=df_long, x="Database", y="DeltaAUPRC")
sns.stripplot(data=df_long, x="Database", y="DeltaAUPRC", color="k", alpha=0.6, size=5)

# Reference line at 1
ax.axhline(1, ls="--", c="gray", lw=1)

# Compute and annotate p-values (one-sample test vs 0)
max_y = df_long["DeltaAUPRC"].max()
min_y = df_long["DeltaAUPRC"].min()
span = max(max_y - min_y, 1e-6)
offset = 0.08 * span

for i, col in enumerate(df.columns):
    x = df[col].dropna().values
    stat, p = ttest_1samp(x, 1.0, nan_policy="omit")
    y = df[col].max() + offset
    ax.text(i, y, f"p={p:.2e}", ha="center", va="bottom", fontsize=9)

ax.set_ylim(min_y - offset, max_y + 3 * offset)
plt.title("Delta AUPRC by Database (p-values vs 1)")
plt.xlabel("Database")
plt.ylabel("Delta AUPRC (observed / random)")
plt.tight_layout()
plt.show()

# %%
df = pd.DataFrame(
    {i: v for i, v in show.items() if "_auprc" in i},
    index=[
        "Loop of Henle",
        "Epithelial cell",
        "Intercalated cell",
        "Endothelial cell (APC)",
        "Monocyte",
        "Macrophage",
        "Smooth muscle cell",
        "Dendritic cell",
        "Sinusoidal endothelial cell",
    ],
)

# Long format for seaborn
df_long = df.reset_index().melt(
    id_vars="index", var_name="Database", value_name="DeltaAUPRC"
)
df_long = df_long.rename(columns={"index": "Cell Type"})

plt.figure(figsize=(10, 6))
ax = sns.boxplot(data=df_long, x="Database", y="DeltaAUPRC")
sns.stripplot(data=df_long, x="Database", y="DeltaAUPRC", color="k", alpha=0.6, size=5)

# Reference line at 1
ax.axhline(1, ls="--", c="gray", lw=1)

# Compute and annotate p-values (one-sample test vs 0)
max_y = df_long["DeltaAUPRC"].max()
min_y = df_long["DeltaAUPRC"].min()
span = max(max_y - min_y, 1e-6)
offset = 0.08 * span

for i, col in enumerate(df.columns):
    x = df[col].dropna().values
    stat, p = ttest_1samp(x, 1.0, nan_policy="omit")
    y = df[col].max() + offset
    ax.text(i, y, f"p={p:.2e}", ha="center", va="bottom", fontsize=9)

ax.set_ylim(min_y - offset, max_y + 3 * offset)
plt.title("Delta AUPRC by Database (p-values vs 1)")
plt.xlabel("Database")
plt.ylabel("Delta AUPRC (observed / random)")
plt.tight_layout()
plt.show()
